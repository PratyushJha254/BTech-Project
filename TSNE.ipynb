# %% [markdown]
# <a href="https://colab.research.google.com/github/PratyushJha254/BTP/blob/main/TSNE.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
from matplotlib import pyplot as plt
import tensorflow as tf
from tensorflow import keras
from sklearn.model_selection import train_test_split
from keras.utils import to_categorical
import pickle
from sklearn.manifold import TSNE
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.colors as mcol
import matplotlib.cm as cm
from keras.utils import to_categorical
import keras.layers as layers
from keras import Sequential
from sklearn.decomposition import PCA

# %%
def full_file_loader(file_name, Tc = 2.27):
    data = np.load(file_name)
    X = data['X']
    Y = data['y']
    # Tc = 2.27 # For a square lattice following Ising Model
    y = Y > Tc
    y = to_categorical(y.astype(int))
    return X, y, Y

# %%
X1, y1, Y1 = full_file_loader("data_64NNN_anti_noshuffle_R000_2.npz")
X2, y2, Y1 = full_file_loader("data_64NNN_anti_noshuffle_Rplus2_best4.npz")

# %%
X3, y3, Y3 = full_file_loader("data_onlyferro.npz")

# %%
X3.shape
# Out:
# (13000, 64, 64)

# %%
size = X1.shape[1]
X1_2d = X1.reshape(X1.shape[0],size*size)
x_t = TSNE(n_components=2).fit_transform(X1_2d)

# %%
size = X2.shape[1]
X2_2d = X2.reshape(X2.shape[0],size*size)
x2_t = TSNE(n_components=2).fit_transform(X2_2d)

# %%
size = X1.shape[1]
X1_2d = X1.reshape(X1.shape[0],size*size)
x_t = TSNE(n_components=2).fit_transform(X1_2d)

size = X2.shape[1]
X2_2d = X2.reshape(X2.shape[0],size*size)
x2_t = TSNE(n_components=2).fit_transform(X2_2d)

# %%
size = X3.shape[1]
X3_2d = X3.reshape(X3.shape[0],size*size)
x3_t = TSNE(n_components=2).fit_transform(X3_2d[:2000])

# %%
plt.scatter(x_t.T[0], x_t.T[1], label="Antiferromagnetic phase")
plt.legend()
plt.show()
plt.scatter(x3_t.T[0], x3_t.T[1], label="Ferromagnetic Phase")
plt.legend()

# %%
plt.scatter(x_t.T[0], x_t.T[1], label="R=0")
plt.legend()
plt.show()
plt.scatter(x2_t.T[0], x2_t.T[1], label="R=+2")
plt.legend()
