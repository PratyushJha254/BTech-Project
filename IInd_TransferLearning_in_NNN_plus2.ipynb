# %% [markdown]
# <a href="https://colab.research.google.com/github/PratyushJha254/BTP/blob/main/IInd_TransferLearning_in_NNN_plus2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # BTP

# %%
import numpy as np
from matplotlib import pyplot as plt
import tensorflow as tf
from tensorflow import keras
from sklearn.model_selection import train_test_split
from keras.utils import to_categorical
import pickle
from sklearn.manifold import TSNE
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.colors as mcol
import matplotlib.cm as cm
from keras.utils import to_categorical
import keras.layers as layers
from keras import Sequential
from numba import jit

import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
import torchvision.utils as vutils
import matplotlib.pyplot as plt
import sys
from torch.autograd import Variable
from torch.autograd import grad as torch_grad
import seaborn as sns

# %%
nu_G = 10
Ny = 64
Nx = 64
nc = 1
nz = 100
ngf = 64
ndf = 64
num_epochs = 50
lr = 0.001
beta1 = 0.5
ngpu = 1
N = Ny * Nx
device = torch.device('cuda:0' if (torch.cuda.is_available() and ngpu > 0) else 'cpu')

# %% [markdown]
# ### Plot function

# %%
def avg_prob(unique_temperatures, predictions, temperatures):
  # Initialize an array to store average prediction probabilities for each unique temperature
  average_probabilities = np.zeros_like(unique_temperatures, dtype=float)

  # Calculate average prediction probability for each unique temperature
  for i, temp in enumerate(unique_temperatures):
      # Find indices corresponding to the current unique temperature
      temp_indices = np.where(temperatures == temp)
      # Extract prediction probabilities for these indices
      temp_predictions = predictions[temp_indices]
      # Calculate average prediction probability
      average_prob = np.mean(temp_predictions)
      # Store the average probability
      average_probabilities[i] = average_prob
  return average_probabilities

# %%
import numpy as np
import matplotlib.pyplot as plt

# Assuming 'predictions' is the array containing prediction probabilities
# and 'temperatures' is the array containing corresponding temperatures
def plot_proba(temperatures, predictions1, predictions2, label1 = 'Ordered state', label2 = 'Disordered state'):
# Calculate unique temperature values and their corresponding indices
  unique_temperatures, indices = np.unique(temperatures, return_inverse=True)
  avg_proba1 = avg_prob(unique_temperatures, predictions1, temperatures)
  avg_proba2 = avg_prob(unique_temperatures, predictions2, temperatures)

  # Plot the average prediction probabilities against temperature
  plt.figure(figsize=(8, 6))
  plt.plot(unique_temperatures, avg_proba1, marker='o', linestyle='-', label = label1)
  plt.plot(unique_temperatures, avg_proba2, marker='o', linestyle='-', label = label2)
  plt.legend()
  plt.xlabel('Temperature')
  plt.ylabel('Average Prediction Probability')
  plt.title('Average Prediction Probability per Temperature')

  plt.grid(True)
  plt.show()

# %% [markdown]
# ### Concatenate npz files

# %%
def combine_npz_files(file1, file2, combined_file):
    # Load data and labels from the first .npz file
    data1 = np.load(file1)['X']
    labels1 = np.load(file1)['y']

    # Load data and labels from the second .npz file
    data2 = np.load(file2)['X']
    labels2 = np.load(file2)['y']

    # Concatenate data and labels along the appropriate axis
    combined_data = np.concatenate((data1, data2), axis=0)
    combined_labels = np.concatenate((labels1, labels2), axis=0)

    # Save the combined data and labels into a new .npz file
    np.savez(combined_file, X=combined_data, y=combined_labels)

# %% [markdown]
# ### Model

# %% [markdown]
# #### Accuracy, train and test functions

# %%
def calculate_accuracy(outputs, labels):
    # Threshold the outputs at 0.5 to get binary predictions: below 0.5 becomes 0, above becomes 1
    predicted = (outputs > 0.5).float()

    # The labels need to have the same dimensions as the predictions for comparison
    # Assuming labels are already in the correct shape (batch_size, 1) or (batch_size,)
    # If not, you might need to adjust labels' shape, e.g., labels = labels.view(-1, 1)

    # Calculate the number of correct predictions
    correct = (predicted == labels).float().sum().item()/2

    # Calculate the total number of labels (which is also the batch size)
    total = labels.size(0)

    # Calculate accuracy as the percentage of correct predictions
    accuracy = correct / total
    return accuracy

# %%
import numpy as np

def calculate_accuracy_np(outputs, labels):
    # Threshold the outputs at 0.5 to get binary predictions: below 0.5 becomes 0, above becomes 1
    predicted = (outputs > 0.5).astype(float)

    # The labels need to have the same dimensions as the predictions for comparison
    # Assuming labels are already in the correct shape (batch_size, 1) or (batch_size,)
    # If not, you might need to adjust labels' shape

    # Calculate the number of correct predictions
    correct = np.sum(predicted == labels).astype(float) / 2

    # Calculate the total number of labels (which is also the batch size)
    total = labels.shape[0]

    # Calculate accuracy as the percentage of correct predictions
    accuracy = correct / total
    return accuracy

# %%
def train(model, num_epochs, criterion, optimizer, train_dataloader):
  model.train()
  for epoch in range(num_epochs):
    for i, (x, label) in enumerate(train_dataloader):
      x = x.to(device).float()
      label = label.to(device).float()
      b_size = x.size(0)
      model.zero_grad()
      output = model(x)
      # if(epoch==0 and i==0):
      #   print(output)
      error = criterion(output, label)
      error.backward()
      optimizer.step()
      acc_train = calculate_accuracy(output, label)
      if i % 20 == 0:
        print('Loss:', error.item(),',Train accuracy:', acc_train)

# %%
def test(model, criterion, test_dataloader):
    for i, (x, label) in enumerate(test_dataloader):
      x = x.to(device).float()
      label = label.to(device).float()
      output = model(x)
      error = criterion(output, label)
      acc_train = calculate_accuracy(output, label)
      # if i % 20 == 0:
      print(i,':: Loss:', error.item(),',Test accuracy:', acc_train)

# %%
def get_predictions(test_loader, model):
    # Assuming `test_loader` is your DataLoader for the test dataset
    # Initialize lists to store predictions for each class
    predictions_class_1 = []
    predictions_class_2 = []

    with torch.no_grad():  # Disable gradient tracking during inference
        for inputs, _ in test_loader:
            inputs = inputs.to(device).float()  # Move inputs to the device (e.g., GPU)
            outputs = model(inputs)  # Forward pass to get predictions

            # Assuming the output is softmax probabilities
            # Separate the probabilities for class-1 and class-2
            class_1_probs = outputs[:, 0].cpu().numpy()  # Probabilities for class-1
            class_2_probs = outputs[:, 1].cpu().numpy()  # Probabilities for class-2

            predictions_class_1.extend(class_1_probs)
            predictions_class_2.extend(class_2_probs)

    # `predictions_class_1` contains the probabilities for class-1 for all test samples
    # `predictions_class_2` contains the probabilities for class-2 for all test samples
    # You can further process or save these predictions as needed
    return predictions_class_1, predictions_class_2

# %%
def get_predictions_np(input_matrix, model, device):
    # Convert numpy matrix to PyTorch tensor
    inputs = torch.tensor(input_matrix).to(device).float()

    # Forward pass to get predictions
    with torch.no_grad():  # Disable gradient tracking during inference
        outputs = model(inputs)  # Forward pass to get predictions

        # Assuming the output is softmax probabilities
        # Separate the probabilities for class-1 and class-2
        class_1_probs = outputs[:, 0].cpu().numpy()  # Probabilities for class-1
        class_2_probs = outputs[:, 1].cpu().numpy()  # Probabilities for class-2

    # `class_1_probs` contains the probabilities for class-1 for all samples
    # `class_2_probs` contains the probabilities for class-2 for all samples
    # You can further process or save these predictions as needed
    return class_1_probs, class_2_probs

# %% [markdown]
# #### File loaders

# %%
import torch
from torch.utils.data import DataLoader, ConcatDataset
from torchvision import transforms

# Define a function to generate rotated data
def rotate_data(X):
    rotated_X = torch.rot90(X, k=1, dims=(0, 1))  # Rotate data by 90 degrees clockwise
    return rotated_X

# Modify the dataset to include both original and rotated data
def create_combined_dataset_with_augmentation(original_dataset):
    combined_dataset = []
    for X, Y in original_dataset:
        rotated_X = rotate_data(X)
        combined_dataset.append((X, Y))  # Add original data
        combined_dataset.append((rotated_X, Y))  # Add rotated data
    return combined_dataset

# %%
def create_combined_dataset(dataset1, dataset2):
    combined_dataset = []
    for X, Y in dataset1:
        combined_dataset.append((X, Y))  # Add original data
    for X, Y in dataset2:
        combined_dataset.append((X, Y))  # Add original data
    return combined_dataset

# %%
def file_loader(file_name, Tc = 2.27):
    data = np.load(file_name)
    X = data['X']
    y = data['y']
    X_train, X_test, Y_train, Y_test = train_test_split(X, y, test_size=0.15)
    Tc = 2.27 # For a square lattice following Ising Model
    y_train = Y_train > Tc
    y_test = Y_test > Tc
    y_train = to_categorical(y_train.astype(int))
    y_test = to_categorical(y_test.astype(int))
    return X_train, X_test, y_train, y_test, Y_train, Y_test

# %%
def full_file_loader(file_name, Tc = 2.27):
    data = np.load(file_name)
    X = data['X']
    Y = data['y']
    # Tc = 2.27 # For a square lattice following Ising Model
    y = Y > Tc
    y = to_categorical(y.astype(int))
    return X, y, Y

# %% [markdown]
# #### Dataset and DataLoader

# %%
class IsingDataset(Dataset):
    def __init__(self, x, y, anti_ferro=False):
        self.n_samples = x.shape[0]
        self.x = torch.tensor(torch.from_numpy(x))
        self.y = torch.tensor(torch.from_numpy(y))
        self.anti_ferro = anti_ferro

    def __getitem__(self, index):
        if self.anti_ferro:
            x_transformed = self._apply_anti_ferro(self.x[index])
            return x_transformed, self.y[index]
        else:
            return self.x[index], self.y[index]

    def __len__(self):
        return self.n_samples

    def _apply_anti_ferro(self, x):
        # Apply anti-ferromagnetic transformation
        return (-1) ** torch.arange(x.size(0)).unsqueeze(1) + (-1) ** torch.arange(x.size(1))

# # Example usage
# x = ...  # Your input data
# y = ...  # Your target labels
# anti_ferro = True  # Set to True to apply the anti-ferromagnetic transformation
# dataset = IsingDataset(x, y, anti_ferro=anti_ferro)

# %%
import torch
from torch.utils.data import DataLoader

# Assuming you have a DataLoader named original_dataloader
# Define a new DataLoader class to subset the original DataLoader
class SubsetDataLoader(DataLoader):
    def __init__(self, dataloader, num_batches):
        super(SubsetDataLoader, self).__init__(dataloader.dataset, batch_size=dataloader.batch_size)
        self.dataloader = dataloader
        self.num_batches = num_batches
        self.current_batch = 0

    def __iter__(self):
        self.current_batch = 0
        self.dataloader_iter = iter(self.dataloader)
        return self

    def __next__(self):
        if self.current_batch >= self.num_batches:
            raise StopIteration
        self.current_batch += 1
        return next(self.dataloader_iter)

# %% [markdown]
# Train and test data:

# %%
# # Anti-ferromagnetic dataset: train and test

# X_train, X_test, y_train, y_test, Y_train, Y_test = file_loader('data.npz')

# %%
# training_dataset = IsingDataset(X_train, y_train)
# testing_dataset = IsingDataset(X_test, y_test)
# batch_size = 128
# train_dataloader = DataLoader(dataset = training_dataset, batch_size = batch_size, shuffle = False)
# test_dataloader = DataLoader(dataset = testing_dataset, batch_size = batch_size, shuffle = False)

# %%
# Anti-ferromagnetic dataset: train and test

X_train_anti, X_test_anti, y_train_anti, y_test_anti, Y_train_anti, Y_test_anti = file_loader('data_anti.npz')

# %%
training_dataset_anti = IsingDataset(X_train_anti, y_train_anti)
testing_dataset_anti = IsingDataset(X_test_anti, y_test_anti)
batch_size = 128
train_dataloader_anti = DataLoader(dataset = training_dataset_anti, batch_size = batch_size, shuffle = False)
test_dataloader_anti = DataLoader(dataset = testing_dataset_anti, batch_size = batch_size, shuffle = False)
# Out:
# <ipython-input-16-2d1bccbc4b53>:4: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   self.x = torch.tensor(torch.from_numpy(x))
# <ipython-input-16-2d1bccbc4b53>:5: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   self.y = torch.tensor(torch.from_numpy(y))

# %%
plt.imshow(X_train_anti[30])
print("Class:", y_train_anti[30])
print("Temperature:", Y_train_anti[30])
# Out:
# Class: [1. 0.]
# Temperature: 2.2

# %% [markdown]
# #### Fully Connected Neural Network

# %%
class neural_network(nn.Module):
  def __init__(self):
    super(neural_network, self).__init__()
    self.main = nn.Sequential(
        nn.Flatten(start_dim=1,end_dim=-1),
        nn.Linear(Nx*Ny, 100),
        nn.Sigmoid(),
        nn.Linear(100, 2),
        nn.Sigmoid()
    )
  def forward(self, input):
      return self.main(input)

# %%
FCNN = neural_network().to(device)
criterion_FCNN = nn.BCELoss()
optimizer_FCNN = optim.Adam(FCNN.parameters(), lr=lr, betas=(0.9, 0.999))

# %%
# # Dataset 1, NN -> antiFe, NNN -> Fe
# X_anti, y_anti, Y_anti = full_file_loader('data_anti.npz')
# dataset_anti = IsingDataset(X_anti, y_anti)
# batch_size = 128
# dataloader_anti = DataLoader(dataset = dataset_anti, batch_size = batch_size, shuffle = False)

# %%
train(FCNN, 10, criterion_FCNN, optimizer_FCNN, train_dataloader_anti)
# Out:
# Loss: 0.694808840751648 ,Train accuracy: 0.6015625
# Loss: 0.6998928785324097 ,Train accuracy: 0.4765625
# Loss: 0.6956212520599365 ,Train accuracy: 0.703125
# Loss: 0.6933309435844421 ,Train accuracy: 0.5390625
# Loss: 0.6729944348335266 ,Train accuracy: 0.546875
# Loss: 0.6664677858352661 ,Train accuracy: 0.79296875
# Loss: 0.7108287215232849 ,Train accuracy: 0.49609375
# Loss: 0.6884220838546753 ,Train accuracy: 0.75
# Loss: 0.6801477670669556 ,Train accuracy: 0.57421875
# Loss: 0.6276676654815674 ,Train accuracy: 0.8671875
# Loss: 0.6431004405021667 ,Train accuracy: 0.7734375
# Loss: 0.6468219757080078 ,Train accuracy: 0.75390625
# Loss: 0.6360934972763062 ,Train accuracy: 0.7890625
# Loss: 0.601184606552124 ,Train accuracy: 0.8125
# Loss: 0.566032886505127 ,Train accuracy: 0.8671875
# Loss: 0.6966426372528076 ,Train accuracy: 0.79296875
# Loss: 0.6068639159202576 ,Train accuracy: 0.80859375
# Loss: 0.5976171493530273 ,Train accuracy: 0.8203125
# Loss: 0.570264995098114 ,Train accuracy: 0.83203125
# Loss: 0.5279619693756104 ,Train accuracy: 0.796875
# Loss: 0.5636724829673767 ,Train accuracy: 0.81640625
# Loss: 0.5221796631813049 ,Train accuracy: 0.859375
# Loss: 0.4802488088607788 ,Train accuracy: 0.8671875
# Loss: 0.44180285930633545 ,Train accuracy: 0.89453125
# Loss: 0.6269868016242981 ,Train accuracy: 0.796875
# Loss: 0.47137391567230225 ,Train accuracy: 0.875
# Loss: 0.49112609028816223 ,Train accuracy: 0.86328125
# Loss: 0.44165870547294617 ,Train accuracy: 0.87890625
# Loss: 0.36897826194763184 ,Train accuracy: 0.90234375
# Loss: 0.42659881711006165 ,Train accuracy: 0.875
# Loss: 0.37995195388793945 ,Train accuracy: 0.87890625
# Loss: 0.34179431200027466 ,Train accuracy: 0.9140625
# Loss: 0.3227998614311218 ,Train accuracy: 0.92578125
# Loss: 0.4922146797180176 ,Train accuracy: 0.8515625
# Loss: 0.3242245018482208 ,Train accuracy: 0.92578125
# Loss: 0.3547118306159973 ,Train accuracy: 0.8984375
# Loss: 0.29217949509620667 ,Train accuracy: 0.9453125
# Loss: 0.22920536994934082 ,Train accuracy: 0.9609375
# Loss: 0.26776599884033203 ,Train accuracy: 0.8984375
# Loss: 0.24032923579216003 ,Train accuracy: 0.94921875
# Loss: 0.2064826786518097 ,Train accuracy: 0.9609375
# Loss: 0.1991012990474701 ,Train accuracy: 0.96484375
# Loss: 0.32160982489585876 ,Train accuracy: 0.91796875
# Loss: 0.18882489204406738 ,Train accuracy: 0.96875
# Loss: 0.19641061127185822 ,Train accuracy: 0.9609375
# Loss: 0.18576395511627197 ,Train accuracy: 0.953125
# Loss: 0.12857592105865479 ,Train accuracy: 0.97265625
# Loss: 0.15979322791099548 ,Train accuracy: 0.97265625
# Loss: 0.13275007903575897 ,Train accuracy: 0.98828125
# Loss: 0.11412951350212097 ,Train accuracy: 0.98828125
# Loss: 0.12322948127985 ,Train accuracy: 0.984375
# Loss: 0.1825394183397293 ,Train accuracy: 0.9609375
# Loss: 0.09921310842037201 ,Train accuracy: 0.984375
# Loss: 0.09963170439004898 ,Train accuracy: 0.98828125
# Loss: 0.10528916120529175 ,Train accuracy: 0.984375
# Loss: 0.07014623284339905 ,Train accuracy: 1.0
# Loss: 0.09425726532936096 ,Train accuracy: 0.984375
# Loss: 0.08386458456516266 ,Train accuracy: 0.9921875
# Loss: 0.06847625970840454 ,Train accuracy: 1.0
# Loss: 0.07742321491241455 ,Train accuracy: 0.9921875
# Loss: 0.10917915403842926 ,Train accuracy: 0.984375
# Loss: 0.06084713712334633 ,Train accuracy: 0.9921875
# Loss: 0.0570172443985939 ,Train accuracy: 0.9921875
# Loss: 0.0689384788274765 ,Train accuracy: 0.9921875
# Loss: 0.046703025698661804 ,Train accuracy: 0.99609375
# Loss: 0.04777780920267105 ,Train accuracy: 1.0
# Loss: 0.05742655694484711 ,Train accuracy: 0.9921875
# Loss: 0.04579426348209381 ,Train accuracy: 1.0
# Loss: 0.046251457184553146 ,Train accuracy: 1.0
# Loss: 0.0568104013800621 ,Train accuracy: 0.9921875
# Loss: 0.035966381430625916 ,Train accuracy: 1.0
# Loss: 0.038475438952445984 ,Train accuracy: 1.0
# Loss: 0.04854930192232132 ,Train accuracy: 0.9921875
# Loss: 0.031001046299934387 ,Train accuracy: 1.0
# Loss: 0.030961234122514725 ,Train accuracy: 1.0
# Loss: 0.04769279062747955 ,Train accuracy: 0.9921875
# Loss: 0.02779308147728443 ,Train accuracy: 1.0
# Loss: 0.025199690833687782 ,Train accuracy: 1.0
# Loss: 0.03818298131227493 ,Train accuracy: 0.99609375
# Loss: 0.024920454248785973 ,Train accuracy: 1.0
# Loss: 0.02413669228553772 ,Train accuracy: 1.0
# Loss: 0.03358534723520279 ,Train accuracy: 0.9921875
# Loss: 0.01868477649986744 ,Train accuracy: 1.0
# Loss: 0.019133538007736206 ,Train accuracy: 1.0
# Loss: 0.02932651713490486 ,Train accuracy: 0.9921875
# Loss: 0.019059069454669952 ,Train accuracy: 1.0
# Loss: 0.018792327493429184 ,Train accuracy: 1.0
# Loss: 0.027678199112415314 ,Train accuracy: 1.0
# Loss: 0.016014251857995987 ,Train accuracy: 1.0
# Loss: 0.017899468541145325 ,Train accuracy: 1.0

# %%
test(FCNN, criterion_FCNN, test_dataloader_anti)
# Out:
# 0 :: Loss: 0.1944330930709839 ,Test accuracy: 0.9296875
# 1 :: Loss: 0.3490474820137024 ,Test accuracy: 0.87890625
# 2 :: Loss: 0.2394697368144989 ,Test accuracy: 0.93359375
# 3 :: Loss: 0.3447885811328888 ,Test accuracy: 0.90625
# 4 :: Loss: 0.3742731213569641 ,Test accuracy: 0.890625
# 5 :: Loss: 0.1726294755935669 ,Test accuracy: 0.9375
# 6 :: Loss: 0.37815940380096436 ,Test accuracy: 0.89453125
# 7 :: Loss: 0.35600364208221436 ,Test accuracy: 0.890625
# 8 :: Loss: 0.22086834907531738 ,Test accuracy: 0.90625
# 9 :: Loss: 0.38123810291290283 ,Test accuracy: 0.875
# 10 :: Loss: 0.22011587023735046 ,Test accuracy: 0.9375
# 11 :: Loss: 0.39048415422439575 ,Test accuracy: 0.8671875
# 12 :: Loss: 0.5222269296646118 ,Test accuracy: 0.8671875
# 13 :: Loss: 0.22922751307487488 ,Test accuracy: 0.91015625
# 14 :: Loss: 0.31962859630584717 ,Test accuracy: 0.875
# 15 :: Loss: 0.3035730719566345 ,Test accuracy: 0.9296875
# 16 :: Loss: 0.4342727065086365 ,Test accuracy: 0.86328125
# 17 :: Loss: 0.3147673010826111 ,Test accuracy: 0.8984375
# 18 :: Loss: 0.17969167232513428 ,Test accuracy: 0.92578125
# 19 :: Loss: 0.2734311521053314 ,Test accuracy: 0.8671875
# 20 :: Loss: 0.32886141538619995 ,Test accuracy: 0.89453125
# 21 :: Loss: 0.3506907820701599 ,Test accuracy: 0.875
# 22 :: Loss: 0.3218614459037781 ,Test accuracy: 0.91796875
# 23 :: Loss: 0.31264400482177734 ,Test accuracy: 0.875
# 24 :: Loss: 0.2927728295326233 ,Test accuracy: 0.8984375
# 25 :: Loss: 0.3218671977519989 ,Test accuracy: 0.87890625
# 26 :: Loss: 0.3200051486492157 ,Test accuracy: 0.88671875
# 27 :: Loss: 0.265186607837677 ,Test accuracy: 0.921875
# 28 :: Loss: 0.18450629711151123 ,Test accuracy: 0.9375
# 29 :: Loss: 0.24362459778785706 ,Test accuracy: 0.9140625
# 30 :: Loss: 0.09636522084474564 ,Test accuracy: 0.9583333333333334

# %% [markdown]
# #### CNN:

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import matplotlib.pyplot as plt

class ConvNet(nn.Module):
    def __init__(self, Nx, Ny):
        super(ConvNet, self).__init__()
        self.conv1 = nn.Conv2d(1, 64, kernel_size=2, padding=0)
        self.out_conv1 = self._calculate_output_size((Nx, Ny), kernel_size=2, padding=0)
        self.fc1 = nn.Linear(64 * self.out_conv1[0] * self.out_conv1[1], 64)
        self.dropout = nn.Dropout(p=0.5)
        self.fc2 = nn.Linear(64, 2)
        self.flatten = nn.Flatten()

    def forward(self, x, return_feature_maps=False):
        x = x.view(-1, 1, x.size(1), x.size(2))
        x = F.relu(self.conv1(x))
        if return_feature_maps:
            return x
        x = self.flatten(x)
        x = F.relu(self.fc1(x))
        x = self.dropout(x)
        return F.softmax(self.fc2(x), dim=1)

    def _calculate_output_size(self, input_size, kernel_size, padding):
        out_size = [(input_size[0] - kernel_size + 2 * padding) + 1,
                    (input_size[1] - kernel_size + 2 * padding) + 1]
        return out_size

## Example Usage:
# model = ConvNet(40, 40)
# x = torch.randn(1, 40, 40)
# feature_maps = model(x, return_feature_maps=True)

## Plotting the first feature map from the first sample in the batch
# plt.imshow(feature_maps[0, 0].detach().numpy(), cmap='gray')
# plt.colorbar()
# plt.title('Feature Map from Conv1')
# plt.show()

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import matplotlib.pyplot as plt

class ConvNet_for(nn.Module):
    def __init__(self, Nx, Ny):
        super(ConvNet, self).__init__()
        self.conv1 = nn.Conv2d(1, 64, kernel_size=2, padding=0)
        self.out_conv1 = self._calculate_output_size((Nx, Ny), kernel_size=2, padding=0)
        self.fc1 = nn.Linear(64 * self.out_conv1[0] * self.out_conv1[1], 64)
        self.dropout = nn.Dropout(p=0.5)
        self.fc2 = nn.Linear(64, 2)
        self.flatten = nn.Flatten()

    def forward(self, x, return_feature_maps=False):
        x = x.view(-1, 1, x.size(1), x.size(2))
        x = F.relu(self.conv1(x))
        if return_feature_maps:
            return x
        x = self.flatten(x)
        x = F.relu(self.fc1(x))
        x = self.dropout(x)
        return F.softmax(self.fc2(x), dim=1)

    def _calculate_output_size(self, input_size, kernel_size, padding):
        out_size = [(input_size[0] - kernel_size + 2 * padding) + 1,
                    (input_size[1] - kernel_size + 2 * padding) + 1]
        return out_size

## Example Usage:
# model = ConvNet(40, 40)
# x = torch.randn(1, 40, 40)
# feature_maps = model(x, return_feature_maps=True)

## Plotting the first feature map from the first sample in the batch
# plt.imshow(feature_maps[0, 0].detach().numpy(), cmap='gray')
# plt.colorbar()
# plt.title('Feature Map from Conv1')
# plt.show()

# %%
CNN = ConvNet(Nx, Ny).to(device)
criterion_CNN = nn.BCELoss()
optimizer_CNN = optim.Adam(CNN.parameters(), lr=1e-4, betas=(0.9, 0.999))

# %%
train(CNN, 10, criterion_CNN, optimizer_CNN, train_dataloader_anti)
# Out:
# Loss: 0.7100217342376709 ,Train accuracy: 0.484375
# Loss: 0.057843998074531555 ,Train accuracy: 0.9765625
# Loss: 0.012487726286053658 ,Train accuracy: 1.0
# Loss: 0.03287152573466301 ,Train accuracy: 0.9921875
# Loss: 0.04040445759892464 ,Train accuracy: 0.984375
# Loss: 0.030561193823814392 ,Train accuracy: 0.9921875
# Loss: 0.034744761884212494 ,Train accuracy: 0.9921875
# Loss: 0.04713290184736252 ,Train accuracy: 0.984375
# Loss: 0.009999068453907967 ,Train accuracy: 1.0
# Loss: 0.08652787655591965 ,Train accuracy: 0.9765625
# Loss: 0.02554647997021675 ,Train accuracy: 0.9921875
# Loss: 0.010590054094791412 ,Train accuracy: 1.0
# Loss: 0.04072888195514679 ,Train accuracy: 0.9765625
# Loss: 0.033530235290527344 ,Train accuracy: 0.984375
# Loss: 0.05009687319397926 ,Train accuracy: 0.984375
# Loss: 0.025378115475177765 ,Train accuracy: 0.984375
# Loss: 0.030058570206165314 ,Train accuracy: 0.9921875
# Loss: 0.03169341757893562 ,Train accuracy: 0.9921875
# Loss: 0.04334889352321625 ,Train accuracy: 0.9765625
# Loss: 0.017019931226968765 ,Train accuracy: 0.9921875
# Loss: 0.009367018006742 ,Train accuracy: 0.9921875
# Loss: 0.029487699270248413 ,Train accuracy: 0.984375
# Loss: 0.035234563052654266 ,Train accuracy: 0.9921875
# Loss: 0.008451752364635468 ,Train accuracy: 1.0
# Loss: 0.0630466565489769 ,Train accuracy: 0.984375
# Loss: 0.04900825768709183 ,Train accuracy: 0.984375
# Loss: 0.015917222946882248 ,Train accuracy: 0.9921875
# Loss: 0.05175628140568733 ,Train accuracy: 0.9921875
# Loss: 0.01833324506878853 ,Train accuracy: 0.984375
# Loss: 0.0035985999274998903 ,Train accuracy: 1.0
# Loss: 0.03297482803463936 ,Train accuracy: 0.9921875
# Loss: 0.03472623974084854 ,Train accuracy: 0.984375
# Loss: 0.010464721359312534 ,Train accuracy: 1.0
# Loss: 0.017345745116472244 ,Train accuracy: 0.9921875
# Loss: 0.07533207535743713 ,Train accuracy: 0.9765625
# Loss: 0.0035222359001636505 ,Train accuracy: 1.0
# Loss: 0.017871318385004997 ,Train accuracy: 0.9921875
# Loss: 0.013655791990458965 ,Train accuracy: 0.984375
# Loss: 0.0043374584056437016 ,Train accuracy: 1.0
# Loss: 0.016723154112696648 ,Train accuracy: 0.9921875
# Loss: 0.009876484982669353 ,Train accuracy: 1.0
# Loss: 0.015238448977470398 ,Train accuracy: 0.9921875
# Loss: 0.015957217663526535 ,Train accuracy: 0.9921875
# Loss: 0.03698396682739258 ,Train accuracy: 0.984375
# Loss: 0.0005702301859855652 ,Train accuracy: 1.0
# Loss: 0.013640565797686577 ,Train accuracy: 0.984375
# Loss: 0.002348777139559388 ,Train accuracy: 1.0
# Loss: 0.0020282757468521595 ,Train accuracy: 1.0
# Loss: 0.01508162822574377 ,Train accuracy: 0.9921875
# Loss: 0.009145124815404415 ,Train accuracy: 1.0
# Loss: 0.003127401228994131 ,Train accuracy: 1.0
# Loss: 0.013342311605811119 ,Train accuracy: 0.9921875
# Loss: 0.009330959990620613 ,Train accuracy: 0.9921875
# Loss: 0.008693335577845573 ,Train accuracy: 0.9921875
# Loss: 0.006110058166086674 ,Train accuracy: 1.0
# Loss: 0.0019493079744279385 ,Train accuracy: 1.0
# Loss: 0.005017722025513649 ,Train accuracy: 1.0
# Loss: 0.0077192820608615875 ,Train accuracy: 1.0
# Loss: 0.02406931482255459 ,Train accuracy: 0.9921875
# Loss: 0.012261034920811653 ,Train accuracy: 0.9921875
# Loss: 0.006582066882401705 ,Train accuracy: 1.0
# Loss: 0.01700977236032486 ,Train accuracy: 0.9921875
# Loss: 0.0019717146642506123 ,Train accuracy: 1.0
# Loss: 0.012319519184529781 ,Train accuracy: 0.9921875
# Loss: 0.0037575229071080685 ,Train accuracy: 1.0
# Loss: 0.025213666260242462 ,Train accuracy: 0.984375
# Loss: 0.012361599132418633 ,Train accuracy: 0.9921875
# Loss: 0.029173795133829117 ,Train accuracy: 0.984375
# Loss: 0.0004324335022829473 ,Train accuracy: 1.0
# Loss: 0.005333038046956062 ,Train accuracy: 1.0
# Loss: 0.029038656502962112 ,Train accuracy: 0.9921875
# Loss: 0.0024210840929299593 ,Train accuracy: 1.0
# Loss: 0.007467246614396572 ,Train accuracy: 0.9921875
# Loss: 0.010864591225981712 ,Train accuracy: 0.9921875
# Loss: 0.0011416994966566563 ,Train accuracy: 1.0
# Loss: 0.01456575095653534 ,Train accuracy: 0.9921875
# Loss: 0.007530145347118378 ,Train accuracy: 1.0
# Loss: 0.004441218450665474 ,Train accuracy: 1.0
# Loss: 0.0033255554735660553 ,Train accuracy: 1.0
# Loss: 0.0029801400378346443 ,Train accuracy: 1.0
# Loss: 0.0014258273877203465 ,Train accuracy: 1.0
# Loss: 0.01450724434107542 ,Train accuracy: 0.9921875
# Loss: 0.0019082638900727034 ,Train accuracy: 1.0
# Loss: 0.0006484955665655434 ,Train accuracy: 1.0
# Loss: 0.004707124084234238 ,Train accuracy: 1.0
# Loss: 0.018469735980033875 ,Train accuracy: 0.9921875
# Loss: 0.0010828519007191062 ,Train accuracy: 1.0
# Loss: 0.009043766185641289 ,Train accuracy: 1.0
# Loss: 0.004547190386801958 ,Train accuracy: 1.0
# Loss: 0.001698350184597075 ,Train accuracy: 1.0

# %%
test(CNN, criterion_CNN, test_dataloader_anti)
# Out:
# 0 :: Loss: 0.013246769085526466 ,Test accuracy: 1.0
# 1 :: Loss: 0.006145419552922249 ,Test accuracy: 1.0
# 2 :: Loss: 0.10438580811023712 ,Test accuracy: 0.96875
# 3 :: Loss: 0.013369170017540455 ,Test accuracy: 0.9921875
# 4 :: Loss: 0.055634912103414536 ,Test accuracy: 0.9765625
# 5 :: Loss: 0.03210558369755745 ,Test accuracy: 0.9921875
# 6 :: Loss: 0.026198744773864746 ,Test accuracy: 0.9921875
# 7 :: Loss: 0.0072803618386387825 ,Test accuracy: 1.0
# 8 :: Loss: 0.05747205391526222 ,Test accuracy: 0.9921875
# 9 :: Loss: 0.016055766493082047 ,Test accuracy: 0.9921875
# 10 :: Loss: 0.020776154473423958 ,Test accuracy: 0.9921875
# 11 :: Loss: 0.005502460524439812 ,Test accuracy: 1.0
# 12 :: Loss: 0.015774372965097427 ,Test accuracy: 0.984375
# 13 :: Loss: 0.014016851782798767 ,Test accuracy: 0.9921875
# 14 :: Loss: 0.004771659150719643 ,Test accuracy: 1.0
# 15 :: Loss: 0.0187583826482296 ,Test accuracy: 0.9921875
# 16 :: Loss: 0.01748012937605381 ,Test accuracy: 0.984375
# 17 :: Loss: 0.18451344966888428 ,Test accuracy: 0.9609375
# 18 :: Loss: 0.041823096573352814 ,Test accuracy: 0.9921875
# 19 :: Loss: 0.0884251520037651 ,Test accuracy: 0.984375
# 20 :: Loss: 0.0006890418590046465 ,Test accuracy: 1.0
# 21 :: Loss: 0.06306449323892593 ,Test accuracy: 0.984375
# 22 :: Loss: 0.02429083362221718 ,Test accuracy: 0.9921875
# 23 :: Loss: 0.042486608028411865 ,Test accuracy: 0.984375
# 24 :: Loss: 0.0018823487916961312 ,Test accuracy: 1.0
# 25 :: Loss: 0.006613182835280895 ,Test accuracy: 0.9921875
# 26 :: Loss: 0.09649595618247986 ,Test accuracy: 0.9765625
# 27 :: Loss: 0.03099820762872696 ,Test accuracy: 0.984375
# 28 :: Loss: 0.03303070738911629 ,Test accuracy: 0.984375
# 29 :: Loss: 0.06570997834205627 ,Test accuracy: 0.9765625
# 30 :: Loss: 0.019771190360188484 ,Test accuracy: 0.9833333333333333

# %%
torch.save(CNN.state_dict(), 'CNN_anti.pth')

# %% [markdown]
# ### CNN 2

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import matplotlib.pyplot as plt

class ConvNet2(nn.Module):
    def __init__(self, Nx, Ny):
        super(ConvNet2, self).__init__()
        self.conv1 = nn.Conv2d(1, 32, kernel_size=3, padding=0)
        self.out_conv1 = self._calculate_output_size((Nx, Ny), kernel_size=2, padding=0)
        self.conv2 = nn.Conv2d(32, 64, kernel_size=3, padding=0)
        self.conv3 = nn.Conv2d(64, 64, kernel_size=3, padding=0)
        self.max_pool_layer = nn.MaxPool2d(kernel_size=2, stride=2)
        # self.out_conv2 = self._calculate_output_size(self.out_conv1, kernel_size=2, padding=0)
        self.fc1 = nn.Linear(9216, 64)  # Adjusted input size for fc1
        self.fc2 = nn.Linear(64, 2)
        self.dropout = nn.Dropout(p=0.5)
        self.flatten = nn.Flatten()

    def forward(self, x, return_feature_maps=False):
        x = x.view(-1, 1, x.size(1), x.size(2))
        x = self.max_pool_layer(F.relu(self.conv1(x)))
        x = self.max_pool_layer(F.relu(self.conv2(x)))
        x = F.relu(self.conv3(x))
        if return_feature_maps:
            return x
        x = self.flatten(x)
        x = F.relu(self.fc1(x))
        x = self.dropout(x)
        return F.softmax(self.fc2(x), dim=1)

    def _calculate_output_size(self, input_size, kernel_size, padding):
        out_size = [(input_size[0] - kernel_size + 2 * padding) + 1,
                    (input_size[1] - kernel_size + 2 * padding) + 1]
        return out_size

# Example Usage:
# model = ConvNet(40, 40)
# x = torch.randn(1, 40, 40)
# feature_maps = model(x, return_feature_maps=True)

# Plotting the first feature map from the first sample in the batch
# plt.imshow(feature_maps[0, 0].detach().numpy(), cmap='gray')
# plt.colorbar()
# plt.title('Feature Map from Conv1')
# plt.show()

# %%
CNN_2 = ConvNet2(Nx, Ny).to(device)
criterion_CNN_2 = nn.BCELoss()
optimizer_CNN_2 = optim.Adam(CNN_2.parameters(), lr=1e-4, betas=(0.9, 0.999))

# %%
train(CNN_2, 10, criterion_CNN_2, optimizer_CNN_2, train_dataloader_anti)
# Out:
# Loss: 0.7168821096420288 ,Train accuracy: 0.3984375
# Loss: 0.36896973848342896 ,Train accuracy: 0.9453125
# Loss: 0.06387653201818466 ,Train accuracy: 1.0
# Loss: 0.060284633189439774 ,Train accuracy: 0.9921875
# Loss: 0.07027247548103333 ,Train accuracy: 0.96875
# Loss: 0.01832224428653717 ,Train accuracy: 0.9921875
# Loss: 0.02653094194829464 ,Train accuracy: 0.9921875
# Loss: 0.026200830936431885 ,Train accuracy: 0.9921875
# Loss: 0.00790325552225113 ,Train accuracy: 1.0
# Loss: 0.011764061637222767 ,Train accuracy: 0.9921875
# Loss: 0.008189396932721138 ,Train accuracy: 1.0
# Loss: 0.00761816743761301 ,Train accuracy: 1.0
# Loss: 0.03752874583005905 ,Train accuracy: 0.9921875
# Loss: 0.03546338528394699 ,Train accuracy: 0.984375
# Loss: 0.0018826620653271675 ,Train accuracy: 1.0
# Loss: 0.017355136573314667 ,Train accuracy: 0.9921875
# Loss: 0.011657326482236385 ,Train accuracy: 0.9921875
# Loss: 0.003046018537133932 ,Train accuracy: 1.0
# Loss: 0.004044950939714909 ,Train accuracy: 1.0
# Loss: 0.009651491418480873 ,Train accuracy: 0.9921875
# Loss: 0.02419196628034115 ,Train accuracy: 0.9921875
# Loss: 0.030513595789670944 ,Train accuracy: 0.9921875
# Loss: 0.07092714309692383 ,Train accuracy: 0.9765625
# Loss: 0.0024350881576538086 ,Train accuracy: 1.0
# Loss: 0.013638509437441826 ,Train accuracy: 0.9921875
# Loss: 0.0037349481135606766 ,Train accuracy: 1.0
# Loss: 0.0014265170320868492 ,Train accuracy: 1.0
# Loss: 0.00386417331174016 ,Train accuracy: 1.0
# Loss: 0.00772171700373292 ,Train accuracy: 1.0
# Loss: 0.006719235796481371 ,Train accuracy: 1.0
# Loss: 0.03339894488453865 ,Train accuracy: 0.9921875
# Loss: 0.026576416566967964 ,Train accuracy: 0.984375
# Loss: 0.0009331039618700743 ,Train accuracy: 1.0
# Loss: 0.02203303761780262 ,Train accuracy: 0.9921875
# Loss: 0.003887889441102743 ,Train accuracy: 1.0
# Loss: 0.00330535601824522 ,Train accuracy: 1.0
# Loss: 0.002219945192337036 ,Train accuracy: 1.0
# Loss: 0.002750169252976775 ,Train accuracy: 1.0
# Loss: 0.0010647602612152696 ,Train accuracy: 1.0
# Loss: 0.03179186210036278 ,Train accuracy: 0.9921875
# Loss: 0.023952530696988106 ,Train accuracy: 0.984375
# Loss: 0.0019643704872578382 ,Train accuracy: 1.0
# Loss: 0.0158679261803627 ,Train accuracy: 0.9921875
# Loss: 0.01596670411527157 ,Train accuracy: 0.9921875
# Loss: 0.003537203650921583 ,Train accuracy: 1.0
# Loss: 0.002604988869279623 ,Train accuracy: 1.0
# Loss: 0.02039760909974575 ,Train accuracy: 0.9921875
# Loss: 0.003968569450080395 ,Train accuracy: 1.0
# Loss: 0.03129681944847107 ,Train accuracy: 0.9921875
# Loss: 0.009693795815110207 ,Train accuracy: 1.0
# Loss: 0.002000552834942937 ,Train accuracy: 1.0
# Loss: 0.020738162100315094 ,Train accuracy: 0.984375
# Loss: 0.016048980876803398 ,Train accuracy: 0.9921875
# Loss: 0.002985341940075159 ,Train accuracy: 1.0
# Loss: 0.007192559540271759 ,Train accuracy: 0.9921875
# Loss: 0.003856096649542451 ,Train accuracy: 1.0
# Loss: 0.0015040735015645623 ,Train accuracy: 1.0
# Loss: 0.050820644944906235 ,Train accuracy: 0.9921875
# Loss: 0.012404649518430233 ,Train accuracy: 0.9921875
# Loss: 0.0003493117983452976 ,Train accuracy: 1.0
# Loss: 0.011619786731898785 ,Train accuracy: 0.9921875
# Loss: 0.011410025879740715 ,Train accuracy: 0.9921875
# Loss: 0.0014222919708117843 ,Train accuracy: 1.0
# Loss: 0.004260645713657141 ,Train accuracy: 1.0
# Loss: 0.007156791631132364 ,Train accuracy: 1.0
# Loss: 0.0011624983744695783 ,Train accuracy: 1.0
# Loss: 0.03150913119316101 ,Train accuracy: 0.9921875
# Loss: 0.020172828808426857 ,Train accuracy: 0.9921875
# Loss: 0.0003281619865447283 ,Train accuracy: 1.0
# Loss: 0.015110556036233902 ,Train accuracy: 0.9921875
# Loss: 0.016882069408893585 ,Train accuracy: 0.9921875
# Loss: 0.004349499009549618 ,Train accuracy: 1.0
# Loss: 0.0018614203436300159 ,Train accuracy: 1.0
# Loss: 0.00530976103618741 ,Train accuracy: 1.0
# Loss: 0.0010069244308397174 ,Train accuracy: 1.0
# Loss: 0.04246979579329491 ,Train accuracy: 0.9921875
# Loss: 0.03460261598229408 ,Train accuracy: 0.9921875
# Loss: 0.000963054015301168 ,Train accuracy: 1.0
# Loss: 0.009178799577057362 ,Train accuracy: 0.9921875
# Loss: 0.004983498714864254 ,Train accuracy: 1.0
# Loss: 0.0007473398000001907 ,Train accuracy: 1.0
# Loss: 0.003418970387428999 ,Train accuracy: 1.0
# Loss: 0.005559473764151335 ,Train accuracy: 1.0
# Loss: 0.0006122175836935639 ,Train accuracy: 1.0
# Loss: 0.04209853336215019 ,Train accuracy: 0.9921875
# Loss: 0.0273868590593338 ,Train accuracy: 0.9921875
# Loss: 0.0006304287235252559 ,Train accuracy: 1.0
# Loss: 0.01744893565773964 ,Train accuracy: 0.984375
# Loss: 0.009323343634605408 ,Train accuracy: 0.9921875
# Loss: 0.001625776058062911 ,Train accuracy: 1.0

# %%
test(CNN_2, criterion_CNN_2, test_dataloader_anti)
# Out:
# 0 :: Loss: 0.0032722498290240765 ,Test accuracy: 1.0
# 1 :: Loss: 0.012424340471625328 ,Test accuracy: 0.9921875
# 2 :: Loss: 0.016427651047706604 ,Test accuracy: 0.9921875
# 3 :: Loss: 0.0033397236838936806 ,Test accuracy: 1.0
# 4 :: Loss: 0.03973354771733284 ,Test accuracy: 0.9921875
# 5 :: Loss: 0.012417104095220566 ,Test accuracy: 0.9921875
# 6 :: Loss: 0.011403960175812244 ,Test accuracy: 0.9921875
# 7 :: Loss: 0.00408575963228941 ,Test accuracy: 1.0
# 8 :: Loss: 0.0022109674755483866 ,Test accuracy: 1.0
# 9 :: Loss: 0.006072656251490116 ,Test accuracy: 1.0
# 10 :: Loss: 0.001976446248590946 ,Test accuracy: 1.0
# 11 :: Loss: 0.000466781435534358 ,Test accuracy: 1.0
# 12 :: Loss: 0.00372714689001441 ,Test accuracy: 1.0
# 13 :: Loss: 0.007336121052503586 ,Test accuracy: 1.0
# 14 :: Loss: 0.0020149771589785814 ,Test accuracy: 1.0
# 15 :: Loss: 0.0006037766579538584 ,Test accuracy: 1.0
# 16 :: Loss: 0.02781914547085762 ,Test accuracy: 0.984375
# 17 :: Loss: 0.013317417353391647 ,Test accuracy: 0.9921875
# 18 :: Loss: 0.03530995175242424 ,Test accuracy: 0.9765625
# 19 :: Loss: 0.014916829764842987 ,Test accuracy: 0.9921875
# 20 :: Loss: 0.013637291267514229 ,Test accuracy: 0.9921875
# 21 :: Loss: 0.013667462393641472 ,Test accuracy: 0.9921875
# 22 :: Loss: 0.011922590434551239 ,Test accuracy: 0.9921875
# 23 :: Loss: 0.0049490733072161674 ,Test accuracy: 1.0
# 24 :: Loss: 0.0017930592875927687 ,Test accuracy: 1.0
# 25 :: Loss: 0.016904884949326515 ,Test accuracy: 0.9921875
# 26 :: Loss: 0.013197491876780987 ,Test accuracy: 0.9921875
# 27 :: Loss: 0.008011882193386555 ,Test accuracy: 1.0
# 28 :: Loss: 0.0023169342894107103 ,Test accuracy: 1.0
# 29 :: Loss: 0.00689848605543375 ,Test accuracy: 1.0
# 30 :: Loss: 0.012080277316272259 ,Test accuracy: 0.9833333333333333

# %%
torch.save(CNN_2.state_dict(), 'CNN_anti.pth')

# %% [markdown]
# ### Feature Maps

# %%
# Example Usage:
# model = ConvNet(40, 40)
def plot_feature_map(model, x, y, print_data = False):
  x = torch.from_numpy(x).unsqueeze(0).float().to(device)
  feature_maps = model(x, return_feature_maps=True)

  # Plotting the first feature map from the first sample in the batch
  data = feature_maps[0, 0].cpu().detach().numpy()
  print(data)
  plt.imshow(data)
  plt.colorbar()
  plt.title(f'Temperature={y}')
  plt.show()

# %%
plt.imshow(X_train_anti[0])
plt.title(f"Temperature={Y_train_anti[0]}")
# Out:
# Text(0.5, 1.0, 'Temperature=1.0')

# %%
plot_feature_map(CNN, X_train_anti[2000], Y_train_anti[2000])
# Out:
# [[1.0353074  0.         0.         ... 0.         1.0353074  0.5947193 ]
#  [0.         0.         1.0353074  ... 1.0353074  0.         0.12124181]
#  [1.0353074  0.5947193  0.         ... 0.         1.0353074  0.        ]
#  ...
#  [1.0353074  0.         1.0353074  ... 0.43821007 0.5947193  0.12593082]
#  [0.27775103 0.43821007 0.         ... 0.12124181 0.         0.56651884]
#  [0.         0.         1.0353074  ... 0.         0.56651884 1.1918166 ]]

# %% [markdown]
# ### Test on the R = +2 data

# %% [markdown]
# ###### Loading the datasets and the trained model

# %%
X2, y2, Y2 = full_file_loader('data_64NNN_anti_noshuffle_Rplus2.npz', 4.5)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-27-51af78a5bec2> in <cell line: 1>()
# ----> 1 X2, y2, Y2 = full_file_loader('data_64NNN_anti_noshuffle_Rplus2.npz', 4.5)
#
# <ipython-input-11-4253358cefd0> in full_file_loader(file_name, Tc)
#       1 def full_file_loader(file_name, Tc = 2.27):
# ----> 2     data = np.load(file_name)
#       3     X = data['X']
#       4     Y = data['y']
#       5     # Tc = 2.27 # For a square lattice following Ising Model
#
# /usr/local/lib/python3.10/dist-packages/numpy/lib/npyio.py in load(file, mmap_mode, allow_pickle, fix_imports, encoding, max_header_size)
#     425             own_fid = False
#     426         else:
# --> 427             fid = stack.enter_context(open(os_fspath(file), "rb"))
#     428             own_fid = True
#     429
#
# FileNotFoundError: [Errno 2] No such file or directory: 'data_64NNN_anti_noshuffle_Rplus2.npz'

# %%
dataset2 = IsingDataset(X2, y2)
batch_size = 128
dataloader2 = DataLoader(dataset = dataset2, batch_size = batch_size, shuffle = False)

# %% [markdown]
# ###### CNN

# %%
dataset2.__len__()

# %%
test(CNN, criterion_CNN, dataloader2)

# %%
pred_class1, pred_class2 = get_predictions(dataloader2, CNN)

# %%
plt.scatter(Y2, pred_class1, label='Antiferromagnetic')
plt.scatter(Y2, pred_class2, label='Paramagnetic')
plt.legend()

# %% [markdown]
# ###### Visualization

# %%
plt.imshow(X2[1600])
plt.title(f"Temperature={Y2[1600]}")

# %%
plot_feature_map(CNN, X2[1600], Y2[1600])

# %%
plt.imshow(X2[0])
plt.title(f"Temperature={Y2[0]}")

# %%
  x = X2[8]
  x = torch.from_numpy(x).unsqueeze(0).float().to(device)
  feature_maps = CNN(x, return_feature_maps=True)

  # Plotting the first feature map from the first sample in the batch
  data = feature_maps[0, 0].cpu().detach().numpy()
  data

# %%
plot_feature_map(CNN, X2[0], Y2[0], print_data = True)

# %% [markdown]
# ### Testing on the second (best) R=+2 data

# %% [markdown]
# ###### Loading the datasets and the trained model

# %%
X1, y1, Y1 = full_file_loader('data_64NNN_anti_noshuffle_Rplus2_best.npz', 4.5)

# %%
dataset1 = IsingDataset(X1, y1)
batch_size = 128
dataloader1 = DataLoader(dataset = dataset1, batch_size = batch_size, shuffle = False)
# Out:
# <ipython-input-13-2d1bccbc4b53>:4: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   self.x = torch.tensor(torch.from_numpy(x))
# <ipython-input-13-2d1bccbc4b53>:5: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   self.y = torch.tensor(torch.from_numpy(y))

# %% [markdown]
# ###### CNN

# %%
dataset1.__len__()
# Out:
# 1200

# %%
test(CNN, criterion_CNN, dataloader1)
# Out:
# 0 :: Loss: 80.99919891357422 ,Test accuracy: 0.0
# 1 :: Loss: 79.13746643066406 ,Test accuracy: 0.0
# 2 :: Loss: 79.6487808227539 ,Test accuracy: 0.0
# 3 :: Loss: 68.9416275024414 ,Test accuracy: 0.09375
# 4 :: Loss: 8.086458169742627e-10 ,Test accuracy: 1.0
# 5 :: Loss: 5.413834745088275e-12 ,Test accuracy: 1.0
# 6 :: Loss: 2.4169603818346985e-11 ,Test accuracy: 1.0
# 7 :: Loss: 1.1480339026093134e-06 ,Test accuracy: 1.0
# 8 :: Loss: 5.048984235145326e-07 ,Test accuracy: 1.0
# 9 :: Loss: 2.1734255020722237e-12 ,Test accuracy: 1.0

# %%
pred_class1, pred_class2 = get_predictions(dataloader1, CNN)

# %%
plt.scatter(Y1, pred_class1, label='Antiferromagnetic')
plt.scatter(Y1, pred_class2, label='Paramagnetic')
plt.legend()

# %%
plot_proba(np.array(Y1), np.array(pred_class1), np.array(pred_class2), 'Super Antiferromagnetic', 'Paramagnetic')

# %% [markdown]
# ### Transfer Learning

# %% [markdown]
# #### Loading the Dataset

# %% [markdown]
# Full Data

# %%
file1 = 'data_64NNN_anti_noshuffle_Rplus2_best3.npz'
file2 = 'data_64NNN_anti_noshuffle_Rplus2_best4.npz'
combined_file = 'data_64NNN_anti_noshuffle_Rplus2_best34.npz'

combine_npz_files(file1, file2, combined_file)

# %%
X1, y1, Y1 = full_file_loader('data_64NNN_anti_noshuffle_Rplus2_best.npz', 4.5)

# %%
dataset1 = IsingDataset(X1, y1)
batch_size = 128
dataloader1 = DataLoader(dataset = dataset1, batch_size = batch_size, shuffle = False)
# Out:
# <ipython-input-16-2d1bccbc4b53>:4: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   self.x = torch.tensor(torch.from_numpy(x))
# <ipython-input-16-2d1bccbc4b53>:5: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   self.y = torch.tensor(torch.from_numpy(y))

# %%
X2, y2, Y2 = full_file_loader('data_64NNN_anti_noshuffle_Rplus2_best2.npz', 4.5)

# %%
dataset2 = IsingDataset(X2, y2)
batch_size = 128
dataloader2 = DataLoader(dataset = dataset2, batch_size = batch_size, shuffle = False)
# Out:
# <ipython-input-16-2d1bccbc4b53>:4: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   self.x = torch.tensor(torch.from_numpy(x))
# <ipython-input-16-2d1bccbc4b53>:5: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   self.y = torch.tensor(torch.from_numpy(y))

# %%
X3, y3, Y3 = full_file_loader('data_64NNN_anti_noshuffle_Rplus2_best3.npz', 4.5)

# %%
dataset3 = IsingDataset(X3, y3)
batch_size = 128
dataloader3 = DataLoader(dataset = dataset3, batch_size = batch_size, shuffle = False)
# Out:
# <ipython-input-16-2d1bccbc4b53>:4: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   self.x = torch.tensor(torch.from_numpy(x))
# <ipython-input-16-2d1bccbc4b53>:5: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   self.y = torch.tensor(torch.from_numpy(y))

# %%
X34, y34, Y34 = full_file_loader('data_64NNN_anti_noshuffle_Rplus2_best34.npz', 4.5)

# %%
dataset34 = IsingDataset(X34, y34)
batch_size = 128
dataloader34 = DataLoader(dataset = dataset34, batch_size = batch_size, shuffle = False)
# Out:
# <ipython-input-16-2d1bccbc4b53>:4: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   self.x = torch.tensor(torch.from_numpy(x))
# <ipython-input-16-2d1bccbc4b53>:5: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   self.y = torch.tensor(torch.from_numpy(y))

# %% [markdown]
# Train and test data

# %%
X_train1, X_test1, y_train1, y_test1, Y_train1, Y_test1 = file_loader('data_64NNN_anti_noshuffle_Rplus2_best.npz', 4.5)

# %%
training_dataset1 = IsingDataset(X_train1, y_train1)
testing_dataset1 = IsingDataset(X_test1, y_test1)
batch_size = 128
train_dataloader1 = DataLoader(dataset = training_dataset1, batch_size = batch_size, shuffle = False)
test_dataloader1 = DataLoader(dataset = testing_dataset1, batch_size = batch_size, shuffle = False)
# Out:
# <ipython-input-16-2d1bccbc4b53>:4: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   self.x = torch.tensor(torch.from_numpy(x))
# <ipython-input-16-2d1bccbc4b53>:5: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   self.y = torch.tensor(torch.from_numpy(y))

# %%
X_train2, X_test2, y_train2, y_test2, Y_train2, Y_test2 = file_loader('data_64NNN_anti_noshuffle_Rplus2_best2.npz', 4.5)

# %%
training_dataset2 = IsingDataset(X_train2, y_train2)
testing_dataset2 = IsingDataset(X_test2, y_test2)
batch_size = 128
train_dataloader2 = DataLoader(dataset = training_dataset2, batch_size = batch_size, shuffle = False)
test_dataloader2 = DataLoader(dataset = testing_dataset2, batch_size = batch_size, shuffle = False)
# Out:
# <ipython-input-16-2d1bccbc4b53>:4: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   self.x = torch.tensor(torch.from_numpy(x))
# <ipython-input-16-2d1bccbc4b53>:5: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   self.y = torch.tensor(torch.from_numpy(y))

# %% [markdown]
# Combined Data

# %%
# Create the combined dataset
combined_dataset_wo_aug12 = create_combined_dataset(dataset1, dataset2)

# Create a new DataLoader for the combined dataset
combined_dataloader_wo_aug12 = DataLoader(dataset = combined_dataset_wo_aug12, batch_size=batch_size, shuffle=False)

# %%
# Create the combined dataset
combined_dataset_wo_aug123 = create_combined_dataset(combined_dataset_wo_aug12, dataset3)

# Create a new DataLoader for the combined dataset
combined_dataloader_wo_aug123 = DataLoader(dataset = combined_dataset_wo_aug123, batch_size=batch_size, shuffle=False)

# %%
# Create the combined dataset
combined_dataset_wo_aug1234 = create_combined_dataset(combined_dataset_wo_aug12, dataset34)

# Create a new DataLoader for the combined dataset
combined_dataloader_wo_aug1234 = DataLoader(dataset = combined_dataset_wo_aug1234, batch_size=batch_size, shuffle=False)

# %% [markdown]
# Augmented data

# %%
# Assuming you already have an original DataLoader named original_dataloader
# You can get the original dataset from original_dataloader.dataset
original_dataset1 = dataloader1.dataset

# Create the combined dataset
combined_dataset1 = create_combined_dataset_with_augmentation(original_dataset1)


# Create a new DataLoader for the combined dataset
combined_dataloader1 = DataLoader(dataset = combined_dataset1, batch_size=dataloader1.batch_size, shuffle=False)

# Now, new_dataloader contains both the original data and the 90-degree rotated data, with labels unchanged

# %%
# Assuming you already have an original DataLoader named original_dataloader
# You can get the original dataset from original_dataloader.dataset
original_dataset2 = dataloader2.dataset

# Create the combined dataset
combined_dataset2 = create_combined_dataset_with_augmentation(original_dataset2)


# Create a new DataLoader for the combined dataset
combined_dataloader2 = DataLoader(dataset = combined_dataset2, batch_size=dataloader2.batch_size, shuffle=False)

# Now, new_dataloader contains both the original data and the 90-degree rotated data, with labels unchanged

# %%
# Assuming you already have an original DataLoader named original_dataloader
# You can get the original dataset from original_dataloader.dataset
comb_dataset1 = combined_dataloader1.dataset
comb_dataset2 = combined_dataloader2.dataset

# Create the combined dataset
combined_dataset = create_combined_dataset(comb_dataset2, comb_dataset1)

# Create a new DataLoader for the combined dataset
combined_dataloader = DataLoader(dataset = combined_dataset, batch_size=combined_dataloader2.batch_size, shuffle=False)

# Now, new_dataloader contains both the original data and the 90-degree rotated data, with labels unchanged

# %% [markdown]
# #### Training a model to compare the results

# %%
import torch
import torch.nn as nn
import torch.optim as optim

CNN2 = ConvNet2(Nx, Ny)
CNN2.to(device)

# Setup optimizer
optimizer = optim.Adam(CNN2.parameters(), lr=1e-4, betas=[0.9,0.999])

# Define the loss function
criterion = nn.BCELoss()

# Example usage of the training function with dataloader8
train(CNN2, num_epochs=10, criterion=criterion, optimizer=optimizer, train_dataloader=combined_dataloader_wo_aug1234)
# train(CNN2, num_epochs=10, criterion=criterion, optimizer=optimizer, train_dataloader=dataset34)
# Out:
# Loss: 0.7087637186050415 ,Train accuracy: 0.3515625
# Loss: 0.71278977394104 ,Train accuracy: 0.3046875
# Loss: 0.6556894183158875 ,Train accuracy: 1.0
# Loss: 0.7358809113502502 ,Train accuracy: 0.0
# Loss: 0.2921105623245239 ,Train accuracy: 1.0
# Loss: 0.7430962324142456 ,Train accuracy: 0.265625
# Loss: 0.581832766532898 ,Train accuracy: 1.0
# Loss: 0.7369952201843262 ,Train accuracy: 0.0
# Loss: 0.06315867602825165 ,Train accuracy: 1.0
# Loss: 0.5313315987586975 ,Train accuracy: 1.0
# Loss: 0.4114747941493988 ,Train accuracy: 1.0
# Loss: 0.20065195858478546 ,Train accuracy: 1.0
# Loss: 0.0004465975216589868 ,Train accuracy: 1.0
# Loss: 0.39341509342193604 ,Train accuracy: 1.0
# Loss: 0.4250044822692871 ,Train accuracy: 1.0
# Loss: 0.08020617812871933 ,Train accuracy: 1.0
# Loss: 0.004462680779397488 ,Train accuracy: 1.0
# Loss: 0.4195833206176758 ,Train accuracy: 1.0
# Loss: 0.4059644341468811 ,Train accuracy: 1.0
# Loss: 0.007048087194561958 ,Train accuracy: 1.0
# Loss: 0.0013013442512601614 ,Train accuracy: 1.0
# Loss: 0.3867885172367096 ,Train accuracy: 1.0
# Loss: 0.3221932053565979 ,Train accuracy: 1.0
# Loss: 0.01630479469895363 ,Train accuracy: 1.0
# Loss: 0.0024085529148578644 ,Train accuracy: 1.0
# Loss: 0.4237886667251587 ,Train accuracy: 1.0
# Loss: 0.37301182746887207 ,Train accuracy: 1.0
# Loss: 0.0012971326941624284 ,Train accuracy: 1.0
# Loss: 0.0003477754653431475 ,Train accuracy: 1.0
# Loss: 0.32426655292510986 ,Train accuracy: 1.0
# Loss: 0.3158901035785675 ,Train accuracy: 1.0
# Loss: 0.00027822423726320267 ,Train accuracy: 1.0
# Loss: 7.858761091483757e-05 ,Train accuracy: 1.0
# Loss: 0.35590073466300964 ,Train accuracy: 1.0
# Loss: 0.2951411008834839 ,Train accuracy: 1.0
# Loss: 0.0001889156410470605 ,Train accuracy: 1.0
# Loss: 7.755166006973013e-05 ,Train accuracy: 1.0
# Loss: 0.29621461033821106 ,Train accuracy: 1.0
# Loss: 0.4131629467010498 ,Train accuracy: 1.0
# Loss: 0.0015030887443572283 ,Train accuracy: 1.0

# %%
test(CNN2, criterion, combined_dataloader_wo_aug1234)
# Out:
# 0 :: Loss: 0.0005503655411303043 ,Test accuracy: 1.0
# 1 :: Loss: 0.0006276446511037648 ,Test accuracy: 1.0
# 2 :: Loss: 0.0008073901990428567 ,Test accuracy: 1.0
# 3 :: Loss: 1.027132272720337 ,Test accuracy: 0.328125
# 4 :: Loss: 0.3165457844734192 ,Test accuracy: 1.0
# 5 :: Loss: 0.37014660239219666 ,Test accuracy: 1.0
# 6 :: Loss: 0.32302558422088623 ,Test accuracy: 1.0
# 7 :: Loss: 0.3260456323623657 ,Test accuracy: 1.0
# 8 :: Loss: 0.3700413107872009 ,Test accuracy: 1.0
# 9 :: Loss: 0.11213425546884537 ,Test accuracy: 1.0
# 10 :: Loss: 0.0007285010069608688 ,Test accuracy: 1.0
# 11 :: Loss: 0.00024430511984974146 ,Test accuracy: 1.0
# 12 :: Loss: 0.00030260597122833133 ,Test accuracy: 1.0
# 13 :: Loss: 0.00034434255212545395 ,Test accuracy: 1.0
# 14 :: Loss: 0.002982686273753643 ,Test accuracy: 1.0
# 15 :: Loss: 0.43893787264823914 ,Test accuracy: 0.6875
# 16 :: Loss: 0.9646375179290771 ,Test accuracy: 0.3359375
# 17 :: Loss: 0.4450211524963379 ,Test accuracy: 0.875
# 18 :: Loss: 0.3259856402873993 ,Test accuracy: 1.0
# 19 :: Loss: 0.33753126859664917 ,Test accuracy: 1.0
# 20 :: Loss: 0.3596309423446655 ,Test accuracy: 1.0
# 21 :: Loss: 0.38283586502075195 ,Test accuracy: 1.0
# 22 :: Loss: 0.2929324805736542 ,Test accuracy: 1.0
# 23 :: Loss: 0.3217570185661316 ,Test accuracy: 1.0
# 24 :: Loss: 0.3016159236431122 ,Test accuracy: 1.0
# 25 :: Loss: 0.34057873487472534 ,Test accuracy: 1.0
# 26 :: Loss: 0.3204430341720581 ,Test accuracy: 1.0
# 27 :: Loss: 0.3002696931362152 ,Test accuracy: 1.0
# 28 :: Loss: 0.045811593532562256 ,Test accuracy: 1.0
# 29 :: Loss: 0.0003578933537937701 ,Test accuracy: 1.0
# 30 :: Loss: 0.000323524116538465 ,Test accuracy: 1.0
# 31 :: Loss: 0.00036580648156814277 ,Test accuracy: 1.0
# 32 :: Loss: 0.0012904650066047907 ,Test accuracy: 1.0
# 33 :: Loss: 0.001231625908985734 ,Test accuracy: 1.0
# 34 :: Loss: 0.6694784164428711 ,Test accuracy: 0.5625
# 35 :: Loss: 1.2229945659637451 ,Test accuracy: 0.171875
# 36 :: Loss: 0.3370751738548279 ,Test accuracy: 1.0
# 37 :: Loss: 0.35220056772232056 ,Test accuracy: 1.0
# 38 :: Loss: 0.34271129965782166 ,Test accuracy: 1.0
# 39 :: Loss: 0.35896947979927063 ,Test accuracy: 1.0
# 40 :: Loss: 0.3482573926448822 ,Test accuracy: 1.0
# 41 :: Loss: 0.36191609501838684 ,Test accuracy: 1.0
# 42 :: Loss: 0.321587473154068 ,Test accuracy: 1.0
# 43 :: Loss: 0.3360658884048462 ,Test accuracy: 1.0
# 44 :: Loss: 0.2809484601020813 ,Test accuracy: 1.0
# 45 :: Loss: 0.29048919677734375 ,Test accuracy: 1.0
# 46 :: Loss: 0.2946128845214844 ,Test accuracy: 1.0
# 47 :: Loss: 0.0018978534499183297 ,Test accuracy: 1.0
# 48 :: Loss: 0.002567621413618326 ,Test accuracy: 1.0
# 49 :: Loss: 0.0021615223959088326 ,Test accuracy: 1.0
# 50 :: Loss: 0.0017635920085012913 ,Test accuracy: 1.0
# 51 :: Loss: 0.0016830405220389366 ,Test accuracy: 1.0
# 52 :: Loss: 0.001325179124251008 ,Test accuracy: 1.0
# 53 :: Loss: 0.0022041911724954844 ,Test accuracy: 1.0
# 54 :: Loss: 0.0019183792173862457 ,Test accuracy: 1.0
# 55 :: Loss: 0.0021166792139410973 ,Test accuracy: 1.0
# 56 :: Loss: 0.0027875620871782303 ,Test accuracy: 1.0
# 57 :: Loss: 0.0028449930250644684 ,Test accuracy: 1.0
# 58 :: Loss: 0.0023076452780514956 ,Test accuracy: 1.0
# 59 :: Loss: 0.00199328176677227 ,Test accuracy: 1.0
# 60 :: Loss: 0.0014895318308845162 ,Test accuracy: 1.0
# 61 :: Loss: 0.0016706557944417 ,Test accuracy: 1.0
# 62 :: Loss: 0.0019942736253142357 ,Test accuracy: 1.0
# 63 :: Loss: 0.0026657087728381157 ,Test accuracy: 1.0
# 64 :: Loss: 0.0019177644280716777 ,Test accuracy: 1.0
# 65 :: Loss: 0.002269672928377986 ,Test accuracy: 1.0
# 66 :: Loss: 0.004661443177610636 ,Test accuracy: 1.0
# 67 :: Loss: 0.004339178092777729 ,Test accuracy: 1.0
# 68 :: Loss: 0.005605924874544144 ,Test accuracy: 1.0
# 69 :: Loss: 0.012887184508144855 ,Test accuracy: 1.0
# 70 :: Loss: 0.011471034958958626 ,Test accuracy: 1.0

# %%
pred_class1, pred_class2 = get_predictions(combined_dataloader_wo_aug1234, CNN2)

# %%
Y_comb12 = np.append(Y1, Y2)
Y_comb1234 = np.append(Y_comb12, Y34)
Y_comb1234.shape
# Out:
# (9000,)

# %%
plot_proba(np.array(Y_comb1234), np.array(pred_class1), np.array(pred_class2), 'Super Antiferromagnetic', 'Paramagnetic')

# %%
plt.scatter(Y_comb1234, pred_class1, label='Antiferromagnetic')
plt.scatter(Y_comb1234, pred_class2, label='Paramagnetic')
plt.legend()

# %%
y_comb1234 = np.array([item[1] for item in combined_dataloader_wo_aug1234.dataset])

# %%
calculate_accuracy_np(np.column_stack((pred_class1, pred_class2)), y_comb1234)
# Out:
# 0.9558888888888889

# %% [markdown]
# #### Transfer learning on NNN R=+2 data, model pre-trained on Ferro NN

# %% [markdown]
# ##### Both weights not initialized:

# %%
import torch
import torch.nn as nn
import torch.optim as optim

# Load your pre-trained model
model2 = ConvNet2(Nx, Ny)  # or load from saved state
pretrained_model = ConvNet2(Nx, Ny)
state_dict = torch.load("CNN_anti.pth")
pretrained_model.load_state_dict(state_dict)
model2.conv1.weight.data = pretrained_model.conv1.weight.data
model2.conv1.bias.data = pretrained_model.conv1.bias.data
model2.conv2.weight.data = pretrained_model.conv2.weight.data
model2.conv2.bias.data = pretrained_model.conv2.bias.data
model2.conv3.weight.data = pretrained_model.conv3.weight.data
model2.conv3.bias.data = pretrained_model.conv3.bias.data
####
# model2.fc1.weight.data = pretrained_model.fc1.weight.data
# model2.fc1.bias.data = pretrained_model.fc1.bias.data

# model2.fc2.weight.data = pretrained_model.fc2.weight.data
# model2.fc2.bias.data = pretrained_model.fc2.bias.data

# Freeze all parameters in the model first
for param in model2.parameters():
    param.requires_grad = False

# Unfreeze the layers that you want to train (fc1 and fc2)
model2.fc1.weight.requires_grad = True
model2.fc1.bias.requires_grad = True
model2.fc2.weight.requires_grad = True
model2.fc2.bias.requires_grad = True
# model2.conv2.weight.requires_grad = True
# model2.conv2.bias.requires_grad = True
# model2.conv3.weight.requires_grad = True
# model2.conv3.bias.requires_grad = True

model2.to(device)

# Setup optimizer - only optimize the unfrozen parameters
optimizer = optim.Adam([
    {'params': model2.fc1.parameters()},
    {'params': model2.fc2.parameters()}
], lr=2*1e-5/3, betas=[0.9,0.999])
# optimizer = optim.Adam(model.parameters(), lr=1e-4, betas=[0.9,0.999])

# Define the loss function
criterion = nn.BCELoss()


# Example usage of the training function with dataloader8
train(model2, num_epochs=50, criterion=criterion, optimizer=optimizer, train_dataloader=combined_dataloader_wo_aug1234)
# Out:
# Loss: 0.669964075088501 ,Train accuracy: 0.6171875
# Loss: 0.8070818185806274 ,Train accuracy: 0.1796875
# Loss: 0.5867452025413513 ,Train accuracy: 0.828125
# Loss: 0.8134491443634033 ,Train accuracy: 0.078125
# Loss: 0.6873834133148193 ,Train accuracy: 0.5390625
# Loss: 0.871178388595581 ,Train accuracy: 0.0859375
# Loss: 0.684418797492981 ,Train accuracy: 0.546875
# Loss: 0.7639708518981934 ,Train accuracy: 0.2265625
# Loss: 0.6513229608535767 ,Train accuracy: 0.8359375
# Loss: 0.8792939186096191 ,Train accuracy: 0.03125
# Loss: 0.680832028388977 ,Train accuracy: 0.5546875
# Loss: 0.7599287033081055 ,Train accuracy: 0.1328125
# Loss: 0.6516740322113037 ,Train accuracy: 0.8125
# Loss: 0.8820439577102661 ,Train accuracy: 0.03125
# Loss: 0.7040258646011353 ,Train accuracy: 0.4296875
# Loss: 0.7459135055541992 ,Train accuracy: 0.140625
# Loss: 0.6488679051399231 ,Train accuracy: 0.84375
# Loss: 0.8664901256561279 ,Train accuracy: 0.015625
# Loss: 0.7143268585205078 ,Train accuracy: 0.421875
# Loss: 0.7338312864303589 ,Train accuracy: 0.2109375
# Loss: 0.6531581878662109 ,Train accuracy: 0.8984375
# Loss: 0.8511255979537964 ,Train accuracy: 0.015625
# Loss: 0.6813217401504517 ,Train accuracy: 0.6171875
# Loss: 0.7319543361663818 ,Train accuracy: 0.203125
# Loss: 0.664887011051178 ,Train accuracy: 0.7578125
# Loss: 0.8377302885055542 ,Train accuracy: 0.0234375
# Loss: 0.6899133324623108 ,Train accuracy: 0.5078125
# Loss: 0.7274171113967896 ,Train accuracy: 0.203125
# Loss: 0.6532427668571472 ,Train accuracy: 0.9296875
# Loss: 0.841174840927124 ,Train accuracy: 0.0078125
# Loss: 0.6958267092704773 ,Train accuracy: 0.4765625
# Loss: 0.7169997692108154 ,Train accuracy: 0.2265625
# Loss: 0.652199387550354 ,Train accuracy: 0.9296875
# Loss: 0.8310861587524414 ,Train accuracy: 0.015625
# Loss: 0.6888531446456909 ,Train accuracy: 0.4921875
# Loss: 0.7108497619628906 ,Train accuracy: 0.3359375
# Loss: 0.6523880958557129 ,Train accuracy: 0.9296875
# Loss: 0.8165462017059326 ,Train accuracy: 0.015625
# Loss: 0.6901223659515381 ,Train accuracy: 0.53125
# Loss: 0.7123042345046997 ,Train accuracy: 0.2734375
# Loss: 0.6635706424713135 ,Train accuracy: 0.8515625
# Loss: 0.8149408102035522 ,Train accuracy: 0.0234375
# Loss: 0.6730414628982544 ,Train accuracy: 0.703125
# Loss: 0.7053499221801758 ,Train accuracy: 0.3671875
# Loss: 0.6592428088188171 ,Train accuracy: 0.8515625
# Loss: 0.8205387592315674 ,Train accuracy: 0.0
# Loss: 0.6795969009399414 ,Train accuracy: 0.625
# Loss: 0.6968702077865601 ,Train accuracy: 0.5
# Loss: 0.6557777523994446 ,Train accuracy: 0.9140625
# Loss: 0.8164461851119995 ,Train accuracy: 0.015625
# Loss: 0.6845896244049072 ,Train accuracy: 0.5625
# Loss: 0.7026633024215698 ,Train accuracy: 0.4296875
# Loss: 0.6581326723098755 ,Train accuracy: 0.890625
# Loss: 0.8138365149497986 ,Train accuracy: 0.015625
# Loss: 0.6737267374992371 ,Train accuracy: 0.703125
# Loss: 0.6944947242736816 ,Train accuracy: 0.46875
# Loss: 0.653401255607605 ,Train accuracy: 0.9609375
# Loss: 0.8111644983291626 ,Train accuracy: 0.015625
# Loss: 0.6698020100593567 ,Train accuracy: 0.6875
# Loss: 0.7022426128387451 ,Train accuracy: 0.40625
# Loss: 0.6567835807800293 ,Train accuracy: 0.953125
# Loss: 0.8113681674003601 ,Train accuracy: 0.0
# Loss: 0.6698024272918701 ,Train accuracy: 0.71875
# Loss: 0.6948094964027405 ,Train accuracy: 0.484375
# Loss: 0.6553177237510681 ,Train accuracy: 0.9296875
# Loss: 0.8053817749023438 ,Train accuracy: 0.0234375
# Loss: 0.6706190705299377 ,Train accuracy: 0.703125
# Loss: 0.6912415027618408 ,Train accuracy: 0.5078125
# Loss: 0.6505745053291321 ,Train accuracy: 0.9375
# Loss: 0.8002268075942993 ,Train accuracy: 0.0234375
# Loss: 0.6673687696456909 ,Train accuracy: 0.6796875
# Loss: 0.6946477293968201 ,Train accuracy: 0.5
# Loss: 0.656593918800354 ,Train accuracy: 0.8828125
# Loss: 0.7981748580932617 ,Train accuracy: 0.078125
# Loss: 0.6687638163566589 ,Train accuracy: 0.71875
# Loss: 0.6815804243087769 ,Train accuracy: 0.65625
# Loss: 0.6487956643104553 ,Train accuracy: 0.9609375
# Loss: 0.8085088729858398 ,Train accuracy: 0.0
# Loss: 0.6684383153915405 ,Train accuracy: 0.75
# Loss: 0.6783725619316101 ,Train accuracy: 0.6484375
# Loss: 0.6485512256622314 ,Train accuracy: 0.96875
# Loss: 0.7891842126846313 ,Train accuracy: 0.0
# Loss: 0.6646469831466675 ,Train accuracy: 0.7109375
# Loss: 0.6812226176261902 ,Train accuracy: 0.6015625
# Loss: 0.6513172388076782 ,Train accuracy: 0.953125
# Loss: 0.7848268151283264 ,Train accuracy: 0.046875
# Loss: 0.6577426195144653 ,Train accuracy: 0.796875
# Loss: 0.6737987995147705 ,Train accuracy: 0.7578125
# Loss: 0.6494240164756775 ,Train accuracy: 0.9375
# Loss: 0.7998913526535034 ,Train accuracy: 0.03125
# Loss: 0.6610337495803833 ,Train accuracy: 0.734375
# Loss: 0.6703311204910278 ,Train accuracy: 0.7890625
# Loss: 0.6492007970809937 ,Train accuracy: 0.9609375
# Loss: 0.783703625202179 ,Train accuracy: 0.0546875
# Loss: 0.6507076025009155 ,Train accuracy: 0.796875
# Loss: 0.6772505044937134 ,Train accuracy: 0.6953125
# Loss: 0.6508998870849609 ,Train accuracy: 0.9375
# Loss: 0.7946098446846008 ,Train accuracy: 0.0234375
# Loss: 0.6570053100585938 ,Train accuracy: 0.78125
# Loss: 0.6599611043930054 ,Train accuracy: 0.8828125
# Loss: 0.6505350470542908 ,Train accuracy: 0.9453125
# Loss: 0.7875843048095703 ,Train accuracy: 0.03125
# Loss: 0.6561857461929321 ,Train accuracy: 0.765625
# Loss: 0.6619375944137573 ,Train accuracy: 0.828125
# Loss: 0.6439175009727478 ,Train accuracy: 0.9609375
# Loss: 0.7881473302841187 ,Train accuracy: 0.0625
# Loss: 0.6519176959991455 ,Train accuracy: 0.8046875
# Loss: 0.6565150022506714 ,Train accuracy: 0.8359375
# Loss: 0.6423490643501282 ,Train accuracy: 0.953125
# Loss: 0.7828530073165894 ,Train accuracy: 0.046875
# Loss: 0.6486270427703857 ,Train accuracy: 0.8125
# Loss: 0.6528559923171997 ,Train accuracy: 0.90625
# Loss: 0.6438315510749817 ,Train accuracy: 0.953125
# Loss: 0.7851022481918335 ,Train accuracy: 0.0703125
# Loss: 0.6412030458450317 ,Train accuracy: 0.84375
# Loss: 0.6564476490020752 ,Train accuracy: 0.8203125
# Loss: 0.6447715163230896 ,Train accuracy: 0.9375
# Loss: 0.7706942558288574 ,Train accuracy: 0.078125
# Loss: 0.6475038528442383 ,Train accuracy: 0.796875
# Loss: 0.6454782485961914 ,Train accuracy: 0.9140625
# Loss: 0.6377959847450256 ,Train accuracy: 0.96875
# Loss: 0.7889068126678467 ,Train accuracy: 0.046875
# Loss: 0.6464062929153442 ,Train accuracy: 0.796875
# Loss: 0.6483701467514038 ,Train accuracy: 0.9296875
# Loss: 0.6429882049560547 ,Train accuracy: 0.9453125
# Loss: 0.7739764451980591 ,Train accuracy: 0.0703125
# Loss: 0.6488769054412842 ,Train accuracy: 0.75
# Loss: 0.6377459168434143 ,Train accuracy: 0.96875
# Loss: 0.6363964080810547 ,Train accuracy: 0.9609375
# Loss: 0.7717959880828857 ,Train accuracy: 0.109375
# Loss: 0.6522204279899597 ,Train accuracy: 0.75
# Loss: 0.6402941942214966 ,Train accuracy: 0.921875
# Loss: 0.6405977010726929 ,Train accuracy: 0.953125
# Loss: 0.7822006344795227 ,Train accuracy: 0.0625
# Loss: 0.6385594606399536 ,Train accuracy: 0.875
# Loss: 0.6383010149002075 ,Train accuracy: 0.921875
# Loss: 0.6400901079177856 ,Train accuracy: 0.9921875
# Loss: 0.7640498876571655 ,Train accuracy: 0.1171875
# Loss: 0.6417614221572876 ,Train accuracy: 0.8125
# Loss: 0.6233794689178467 ,Train accuracy: 0.953125
# Loss: 0.6344907283782959 ,Train accuracy: 0.953125
# Loss: 0.7653887867927551 ,Train accuracy: 0.1328125
# Loss: 0.637273907661438 ,Train accuracy: 0.7890625
# Loss: 0.6312234401702881 ,Train accuracy: 0.9453125
# Loss: 0.6416773200035095 ,Train accuracy: 0.96875
# Loss: 0.7706022262573242 ,Train accuracy: 0.0859375
# Loss: 0.6401766538619995 ,Train accuracy: 0.828125
# Loss: 0.6298488974571228 ,Train accuracy: 0.9453125
# Loss: 0.6325042247772217 ,Train accuracy: 0.984375
# Loss: 0.7658371925354004 ,Train accuracy: 0.109375
# Loss: 0.6323692798614502 ,Train accuracy: 0.8828125
# Loss: 0.6253784894943237 ,Train accuracy: 0.953125
# Loss: 0.6343817710876465 ,Train accuracy: 0.9765625
# Loss: 0.7703216075897217 ,Train accuracy: 0.078125
# Loss: 0.634371817111969 ,Train accuracy: 0.8984375
# Loss: 0.6220166683197021 ,Train accuracy: 0.9765625
# Loss: 0.6322208642959595 ,Train accuracy: 0.96875
# Loss: 0.7608423233032227 ,Train accuracy: 0.140625
# Loss: 0.6233911514282227 ,Train accuracy: 0.859375
# Loss: 0.6177546381950378 ,Train accuracy: 0.96875
# Loss: 0.6325147151947021 ,Train accuracy: 0.96875
# Loss: 0.7539352774620056 ,Train accuracy: 0.15625
# Loss: 0.63129723072052 ,Train accuracy: 0.8125
# Loss: 0.6136631965637207 ,Train accuracy: 0.9609375
# Loss: 0.6255781650543213 ,Train accuracy: 0.9921875
# Loss: 0.7640707492828369 ,Train accuracy: 0.140625
# Loss: 0.6198055744171143 ,Train accuracy: 0.90625
# Loss: 0.6159693002700806 ,Train accuracy: 0.953125
# Loss: 0.631245493888855 ,Train accuracy: 0.96875
# Loss: 0.754044771194458 ,Train accuracy: 0.15625
# Loss: 0.6251983642578125 ,Train accuracy: 0.8828125
# Loss: 0.6044479012489319 ,Train accuracy: 0.9921875
# Loss: 0.6239089369773865 ,Train accuracy: 1.0
# Loss: 0.7537886500358582 ,Train accuracy: 0.234375
# Loss: 0.626206636428833 ,Train accuracy: 0.8671875
# Loss: 0.603724479675293 ,Train accuracy: 0.9921875
# Loss: 0.6246610879898071 ,Train accuracy: 0.984375
# Loss: 0.7487690448760986 ,Train accuracy: 0.1875
# Loss: 0.6192667484283447 ,Train accuracy: 0.953125
# Loss: 0.5978478789329529 ,Train accuracy: 0.96875
# Loss: 0.6267482042312622 ,Train accuracy: 0.984375
# Loss: 0.7535023093223572 ,Train accuracy: 0.1171875
# Loss: 0.6138187646865845 ,Train accuracy: 0.890625
# Loss: 0.60948246717453 ,Train accuracy: 0.984375
# Loss: 0.62098628282547 ,Train accuracy: 0.9921875
# Loss: 0.7525769472122192 ,Train accuracy: 0.1953125
# Loss: 0.6192123889923096 ,Train accuracy: 0.890625
# Loss: 0.6018275618553162 ,Train accuracy: 0.9765625
# Loss: 0.6208313703536987 ,Train accuracy: 0.9765625
# Loss: 0.7403644323348999 ,Train accuracy: 0.2734375
# Loss: 0.6080248355865479 ,Train accuracy: 0.9375
# Loss: 0.5910255908966064 ,Train accuracy: 0.984375
# Loss: 0.6243267059326172 ,Train accuracy: 0.96875
# Loss: 0.7440015077590942 ,Train accuracy: 0.21875
# Loss: 0.6119189262390137 ,Train accuracy: 0.8828125
# Loss: 0.5906676054000854 ,Train accuracy: 1.0
# Loss: 0.6203721761703491 ,Train accuracy: 0.9765625
# Loss: 0.7452632784843445 ,Train accuracy: 0.2421875
# Loss: 0.605673611164093 ,Train accuracy: 0.921875
# Loss: 0.5874577760696411 ,Train accuracy: 0.9921875

# %%
# test(model2, criterion, combined_dataloader_wo_aug123)

# %%
pred_class1, pred_class2 = get_predictions(combined_dataloader_wo_aug1234, model2)
Y_comb12 = np.append(Y1, Y2)
Y_comb1234 = np.append(Y_comb12, Y34)
Y_comb1234.shape
plt.scatter(Y_comb1234, pred_class1, label='Super Antiferromagnetic')
plt.scatter(Y_comb1234, pred_class2, label='Paramagnetic')
plt.legend()

# %%
plot_proba(np.array(Y_comb1234), np.array(pred_class1), np.array(pred_class2), 'Super Antiferromagnetic', 'Paramagnetic')

# %%
y_comb1234 = np.array([item[1] for item in combined_dataloader_wo_aug1234.dataset])

# %%
calculate_accuracy_np(np.column_stack((pred_class1, pred_class2)), y_comb1234)
# Out:
# 0.8647777777777778

# %% [markdown]
# ##### FC1 initialized:

# %%
import torch
import torch.nn as nn
import torch.optim as optim

# Load your pre-trained model
model2 = ConvNet2(Nx, Ny)  # or load from saved state
pretrained_model = ConvNet2(Nx, Ny)
state_dict = torch.load("CNN_anti.pth")
pretrained_model.load_state_dict(state_dict)
model2.conv1.weight.data = pretrained_model.conv1.weight.data
model2.conv1.bias.data = pretrained_model.conv1.bias.data
model2.conv2.weight.data = pretrained_model.conv2.weight.data
model2.conv2.bias.data = pretrained_model.conv2.bias.data
model2.conv3.weight.data = pretrained_model.conv3.weight.data
model2.conv3.bias.data = pretrained_model.conv3.bias.data
####
model2.fc1.weight.data = pretrained_model.fc1.weight.data
model2.fc1.bias.data = pretrained_model.fc1.bias.data

# model2.fc2.weight.data = pretrained_model.fc2.weight.data
# model2.fc2.bias.data = pretrained_model.fc2.bias.data

# Freeze all parameters in the model first
for param in model2.parameters():
    param.requires_grad = False

# Unfreeze the layers that you want to train (fc1 and fc2)
model2.fc1.weight.requires_grad = True
model2.fc1.bias.requires_grad = True
model2.fc2.weight.requires_grad = True
model2.fc2.bias.requires_grad = True
# model2.conv2.weight.requires_grad = True
# model2.conv2.bias.requires_grad = True
# model2.conv3.weight.requires_grad = True
# model2.conv3.bias.requires_grad = True

model2.to(device)

# Setup optimizer - only optimize the unfrozen parameters
optimizer = optim.Adam([
    {'params': model2.fc1.parameters()},
    {'params': model2.fc2.parameters()}
], lr=1e-5, betas=[0.9,0.999])
# optimizer = optim.Adam(model.parameters(), lr=1e-4, betas=[0.9,0.999])

# Define the loss function
criterion = nn.BCELoss()


# Example usage of the training function with dataloader8
train(model2, num_epochs=50, criterion=criterion, optimizer=optimizer, train_dataloader=combined_dataloader_wo_aug1234)
# Out:
# Loss: 0.3252193033695221 ,Train accuracy: 0.84375
# Loss: 6.728420257568359 ,Train accuracy: 0.15625
# Loss: 7.263208389282227 ,Train accuracy: 0.1796875
# Loss: 0.5315290093421936 ,Train accuracy: 0.8203125
# Loss: 0.30252623558044434 ,Train accuracy: 0.859375
# Loss: 5.411538124084473 ,Train accuracy: 0.1796875
# Loss: 6.523975372314453 ,Train accuracy: 0.125
# Loss: 0.5956862568855286 ,Train accuracy: 0.7421875
# Loss: 0.6886919736862183 ,Train accuracy: 0.703125
# Loss: 5.573484420776367 ,Train accuracy: 0.1875
# Loss: 4.682222366333008 ,Train accuracy: 0.265625
# Loss: 0.4567052721977234 ,Train accuracy: 0.828125
# Loss: 0.5727660059928894 ,Train accuracy: 0.7421875
# Loss: 4.162792205810547 ,Train accuracy: 0.28125
# Loss: 3.951272487640381 ,Train accuracy: 0.265625
# Loss: 0.8096939325332642 ,Train accuracy: 0.71875
# Loss: 0.6986503005027771 ,Train accuracy: 0.6875
# Loss: 3.5992417335510254 ,Train accuracy: 0.34375
# Loss: 3.619255542755127 ,Train accuracy: 0.328125
# Loss: 0.681533694267273 ,Train accuracy: 0.7578125
# Loss: 0.6294280290603638 ,Train accuracy: 0.734375
# Loss: 3.4813482761383057 ,Train accuracy: 0.3203125
# Loss: 4.576742172241211 ,Train accuracy: 0.2734375
# Loss: 0.8253359794616699 ,Train accuracy: 0.703125
# Loss: 0.8528014421463013 ,Train accuracy: 0.65625
# Loss: 3.4701972007751465 ,Train accuracy: 0.2734375
# Loss: 3.7931456565856934 ,Train accuracy: 0.265625
# Loss: 0.8296383619308472 ,Train accuracy: 0.6796875
# Loss: 0.7710263133049011 ,Train accuracy: 0.640625
# Loss: 3.8460447788238525 ,Train accuracy: 0.2578125
# Loss: 3.626758575439453 ,Train accuracy: 0.2734375
# Loss: 0.9874259829521179 ,Train accuracy: 0.6484375
# Loss: 0.6719893217086792 ,Train accuracy: 0.7109375
# Loss: 3.333059787750244 ,Train accuracy: 0.3515625
# Loss: 3.0801751613616943 ,Train accuracy: 0.40625
# Loss: 0.860537052154541 ,Train accuracy: 0.7265625
# Loss: 0.9470053315162659 ,Train accuracy: 0.609375
# Loss: 3.296747922897339 ,Train accuracy: 0.3515625
# Loss: 3.399867296218872 ,Train accuracy: 0.3203125
# Loss: 0.9763894081115723 ,Train accuracy: 0.6328125
# Loss: 0.7837859392166138 ,Train accuracy: 0.65625
# Loss: 3.846705913543701 ,Train accuracy: 0.2734375
# Loss: 2.8853962421417236 ,Train accuracy: 0.3671875
# Loss: 0.8797038793563843 ,Train accuracy: 0.671875
# Loss: 0.6593946814537048 ,Train accuracy: 0.703125
# Loss: 3.7722253799438477 ,Train accuracy: 0.3203125
# Loss: 3.1447832584381104 ,Train accuracy: 0.359375
# Loss: 1.0302460193634033 ,Train accuracy: 0.59375
# Loss: 0.8747889995574951 ,Train accuracy: 0.5859375
# Loss: 3.507504940032959 ,Train accuracy: 0.3125
# Loss: 3.615558385848999 ,Train accuracy: 0.3046875
# Loss: 1.0476384162902832 ,Train accuracy: 0.6328125
# Loss: 0.8677773475646973 ,Train accuracy: 0.6640625
# Loss: 2.869147300720215 ,Train accuracy: 0.390625
# Loss: 3.0858983993530273 ,Train accuracy: 0.40625
# Loss: 1.1698944568634033 ,Train accuracy: 0.5234375
# Loss: 1.0784595012664795 ,Train accuracy: 0.5546875
# Loss: 3.1507468223571777 ,Train accuracy: 0.359375
# Loss: 2.671712875366211 ,Train accuracy: 0.3515625
# Loss: 0.9285187125205994 ,Train accuracy: 0.6328125
# Loss: 0.7431291341781616 ,Train accuracy: 0.671875
# Loss: 3.421752691268921 ,Train accuracy: 0.3125
# Loss: 2.886965751647949 ,Train accuracy: 0.4140625
# Loss: 0.9320634603500366 ,Train accuracy: 0.6796875
# Loss: 0.7967719435691833 ,Train accuracy: 0.6796875
# Loss: 2.9836483001708984 ,Train accuracy: 0.4140625
# Loss: 2.461465358734131 ,Train accuracy: 0.359375
# Loss: 1.1883251667022705 ,Train accuracy: 0.5546875
# Loss: 0.8743689060211182 ,Train accuracy: 0.609375
# Loss: 2.535151481628418 ,Train accuracy: 0.3828125
# Loss: 2.899150848388672 ,Train accuracy: 0.4453125
# Loss: 1.0002113580703735 ,Train accuracy: 0.6484375
# Loss: 0.9059184789657593 ,Train accuracy: 0.640625
# Loss: 2.483607292175293 ,Train accuracy: 0.421875
# Loss: 2.483619213104248 ,Train accuracy: 0.453125
# Loss: 0.9646618366241455 ,Train accuracy: 0.5859375
# Loss: 0.9684435129165649 ,Train accuracy: 0.578125
# Loss: 2.6378886699676514 ,Train accuracy: 0.421875
# Loss: 2.7886972427368164 ,Train accuracy: 0.3828125
# Loss: 0.9508796334266663 ,Train accuracy: 0.640625
# Loss: 0.9946457147598267 ,Train accuracy: 0.578125
# Loss: 1.9762911796569824 ,Train accuracy: 0.46875
# Loss: 2.2320423126220703 ,Train accuracy: 0.4921875
# Loss: 1.3976337909698486 ,Train accuracy: 0.5234375
# Loss: 1.0502994060516357 ,Train accuracy: 0.5
# Loss: 2.5740981101989746 ,Train accuracy: 0.4375
# Loss: 2.0883491039276123 ,Train accuracy: 0.3984375
# Loss: 1.0611927509307861 ,Train accuracy: 0.609375
# Loss: 1.0294302701950073 ,Train accuracy: 0.6328125
# Loss: 2.545713424682617 ,Train accuracy: 0.390625
# Loss: 2.1596665382385254 ,Train accuracy: 0.4140625
# Loss: 1.2407810688018799 ,Train accuracy: 0.6015625
# Loss: 1.1416436433792114 ,Train accuracy: 0.515625
# Loss: 2.6688308715820312 ,Train accuracy: 0.4140625
# Loss: 2.5032596588134766 ,Train accuracy: 0.421875
# Loss: 1.0541764497756958 ,Train accuracy: 0.65625
# Loss: 0.8518123030662537 ,Train accuracy: 0.6171875
# Loss: 2.5196428298950195 ,Train accuracy: 0.421875
# Loss: 2.5586390495300293 ,Train accuracy: 0.4140625
# Loss: 1.0468182563781738 ,Train accuracy: 0.578125
# Loss: 0.7992468476295471 ,Train accuracy: 0.5859375
# Loss: 2.7823212146759033 ,Train accuracy: 0.40625
# Loss: 2.295602321624756 ,Train accuracy: 0.421875
# Loss: 1.2921468019485474 ,Train accuracy: 0.546875
# Loss: 1.0340096950531006 ,Train accuracy: 0.6015625
# Loss: 2.5549156665802 ,Train accuracy: 0.390625
# Loss: 2.3363726139068604 ,Train accuracy: 0.4609375
# Loss: 1.105747938156128 ,Train accuracy: 0.6328125
# Loss: 1.1701524257659912 ,Train accuracy: 0.515625
# Loss: 2.277700901031494 ,Train accuracy: 0.390625
# Loss: 2.780641794204712 ,Train accuracy: 0.3828125
# Loss: 0.8729013204574585 ,Train accuracy: 0.640625
# Loss: 0.8486160039901733 ,Train accuracy: 0.65625
# Loss: 2.336082935333252 ,Train accuracy: 0.390625
# Loss: 2.3348450660705566 ,Train accuracy: 0.453125
# Loss: 1.1427738666534424 ,Train accuracy: 0.5078125
# Loss: 0.9774681329727173 ,Train accuracy: 0.6015625
# Loss: 2.6339097023010254 ,Train accuracy: 0.390625
# Loss: 2.271817684173584 ,Train accuracy: 0.421875
# Loss: 1.07230806350708 ,Train accuracy: 0.5625
# Loss: 1.0212652683258057 ,Train accuracy: 0.5078125
# Loss: 2.0660240650177 ,Train accuracy: 0.4765625
# Loss: 2.448739528656006 ,Train accuracy: 0.3515625
# Loss: 1.1642794609069824 ,Train accuracy: 0.578125
# Loss: 0.9212095141410828 ,Train accuracy: 0.59375
# Loss: 2.443004608154297 ,Train accuracy: 0.4296875
# Loss: 2.270328998565674 ,Train accuracy: 0.3515625
# Loss: 0.9164032936096191 ,Train accuracy: 0.6328125
# Loss: 1.0862559080123901 ,Train accuracy: 0.546875
# Loss: 2.327932357788086 ,Train accuracy: 0.46875
# Loss: 2.4910964965820312 ,Train accuracy: 0.3671875
# Loss: 0.990293025970459 ,Train accuracy: 0.5546875
# Loss: 0.9876270890235901 ,Train accuracy: 0.6015625
# Loss: 1.9765167236328125 ,Train accuracy: 0.4453125
# Loss: 2.6938397884368896 ,Train accuracy: 0.375
# Loss: 0.8996216058731079 ,Train accuracy: 0.65625
# Loss: 0.8505818843841553 ,Train accuracy: 0.640625
# Loss: 2.40114164352417 ,Train accuracy: 0.359375
# Loss: 2.3585994243621826 ,Train accuracy: 0.4140625
# Loss: 1.0892560482025146 ,Train accuracy: 0.625
# Loss: 0.9484212398529053 ,Train accuracy: 0.578125
# Loss: 2.1541762351989746 ,Train accuracy: 0.4453125
# Loss: 2.42242431640625 ,Train accuracy: 0.421875
# Loss: 0.8666704297065735 ,Train accuracy: 0.6796875
# Loss: 0.9402899146080017 ,Train accuracy: 0.546875
# Loss: 2.145695924758911 ,Train accuracy: 0.3984375
# Loss: 2.017136335372925 ,Train accuracy: 0.5078125
# Loss: 1.0615025758743286 ,Train accuracy: 0.5625
# Loss: 1.0384173393249512 ,Train accuracy: 0.546875
# Loss: 2.338984966278076 ,Train accuracy: 0.3671875
# Loss: 2.621295690536499 ,Train accuracy: 0.453125
# Loss: 0.8408838510513306 ,Train accuracy: 0.6796875
# Loss: 0.7550082206726074 ,Train accuracy: 0.65625
# Loss: 2.0731358528137207 ,Train accuracy: 0.421875
# Loss: 2.2121195793151855 ,Train accuracy: 0.484375
# Loss: 0.9818458557128906 ,Train accuracy: 0.5546875
# Loss: 0.9207227230072021 ,Train accuracy: 0.6015625
# Loss: 2.314861297607422 ,Train accuracy: 0.4609375
# Loss: 2.238358497619629 ,Train accuracy: 0.421875
# Loss: 0.8732645511627197 ,Train accuracy: 0.6328125
# Loss: 0.873977541923523 ,Train accuracy: 0.5625
# Loss: 2.143645763397217 ,Train accuracy: 0.4375
# Loss: 2.2629756927490234 ,Train accuracy: 0.421875
# Loss: 1.0644173622131348 ,Train accuracy: 0.5625
# Loss: 0.6459923386573792 ,Train accuracy: 0.7109375
# Loss: 2.207700729370117 ,Train accuracy: 0.4765625
# Loss: 2.1880059242248535 ,Train accuracy: 0.46875
# Loss: 0.9347237348556519 ,Train accuracy: 0.65625
# Loss: 1.0655862092971802 ,Train accuracy: 0.5390625
# Loss: 2.7502384185791016 ,Train accuracy: 0.3125
# Loss: 2.1090810298919678 ,Train accuracy: 0.4609375
# Loss: 1.081269383430481 ,Train accuracy: 0.578125
# Loss: 0.7544761300086975 ,Train accuracy: 0.640625
# Loss: 1.8108642101287842 ,Train accuracy: 0.5
# Loss: 2.0467722415924072 ,Train accuracy: 0.5
# Loss: 1.073428988456726 ,Train accuracy: 0.5546875
# Loss: 0.8712155818939209 ,Train accuracy: 0.640625
# Loss: 2.7637758255004883 ,Train accuracy: 0.375
# Loss: 2.6282453536987305 ,Train accuracy: 0.3828125
# Loss: 0.91684889793396 ,Train accuracy: 0.6484375
# Loss: 0.8506377935409546 ,Train accuracy: 0.5703125
# Loss: 2.38608717918396 ,Train accuracy: 0.3515625
# Loss: 2.6273317337036133 ,Train accuracy: 0.40625
# Loss: 1.1235949993133545 ,Train accuracy: 0.5625
# Loss: 0.9475517272949219 ,Train accuracy: 0.5625
# Loss: 1.9868226051330566 ,Train accuracy: 0.4296875
# Loss: 2.220627784729004 ,Train accuracy: 0.3828125
# Loss: 1.0953738689422607 ,Train accuracy: 0.5390625
# Loss: 0.8902664184570312 ,Train accuracy: 0.6171875
# Loss: 2.0127112865448 ,Train accuracy: 0.484375
# Loss: 1.900561809539795 ,Train accuracy: 0.4921875
# Loss: 0.9927617907524109 ,Train accuracy: 0.625
# Loss: 0.8603571653366089 ,Train accuracy: 0.6796875
# Loss: 2.458702564239502 ,Train accuracy: 0.34375
# Loss: 2.395251750946045 ,Train accuracy: 0.390625
# Loss: 0.9367588758468628 ,Train accuracy: 0.6640625
# Loss: 0.7346793413162231 ,Train accuracy: 0.625
# Loss: 2.0092649459838867 ,Train accuracy: 0.46875
# Loss: 1.904226541519165 ,Train accuracy: 0.5078125
# Loss: 0.9503372311592102 ,Train accuracy: 0.59375

# %%
# test(model2, criterion, combined_dataloader_wo_aug123)

# %%
pred_class1, pred_class2 = get_predictions(combined_dataloader_wo_aug1234, model2)
Y_comb12 = np.append(Y1, Y2)
Y_comb1234 = np.append(Y_comb12, Y34)
Y_comb1234.shape
plt.scatter(Y_comb1234, pred_class1, label='Super Antiferromagnetic')
plt.scatter(Y_comb1234, pred_class2, label='Paramagnetic')
plt.legend()

# %%
plot_proba(np.array(Y_comb1234), np.array(pred_class1), np.array(pred_class2), 'Super Antiferromagnetic', 'Paramagnetic')

# %%
y_comb1234 = np.array([item[1] for item in combined_dataloader_wo_aug1234.dataset])

# %%
calculate_accuracy_np(np.column_stack((pred_class1, pred_class2)), y_comb1234)
# Out:
# 0.5282222222222223

# %% [markdown]
# ##### FC2 initialized:

# %%
import torch
import torch.nn as nn
import torch.optim as optim

# Load your pre-trained model
model2 = ConvNet2(Nx, Ny)  # or load from saved state
pretrained_model = ConvNet2(Nx, Ny)
state_dict = torch.load("CNN_anti.pth")
pretrained_model.load_state_dict(state_dict)
model2.conv1.weight.data = pretrained_model.conv1.weight.data
model2.conv1.bias.data = pretrained_model.conv1.bias.data
model2.conv2.weight.data = pretrained_model.conv2.weight.data
model2.conv2.bias.data = pretrained_model.conv2.bias.data
model2.conv3.weight.data = pretrained_model.conv3.weight.data
model2.conv3.bias.data = pretrained_model.conv3.bias.data
####
# model2.fc1.weight.data = pretrained_model.fc1.weight.data
# model2.fc1.bias.data = pretrained_model.fc1.bias.data

model2.fc2.weight.data = pretrained_model.fc2.weight.data
model2.fc2.bias.data = pretrained_model.fc2.bias.data

# Freeze all parameters in the model first
for param in model2.parameters():
    param.requires_grad = False

# Unfreeze the layers that you want to train (fc1 and fc2)
model2.fc1.weight.requires_grad = True
model2.fc1.bias.requires_grad = True
model2.fc2.weight.requires_grad = True
model2.fc2.bias.requires_grad = True
# model2.conv2.weight.requires_grad = True
# model2.conv2.bias.requires_grad = True
# model2.conv3.weight.requires_grad = True
# model2.conv3.bias.requires_grad = True

model2.to(device)

# Setup optimizer - only optimize the unfrozen parameters
optimizer = optim.Adam([
    {'params': model2.fc1.parameters()},
    {'params': model2.fc2.parameters()}
], lr=2*1e-5/3, betas=[0.9,0.999])
# optimizer = optim.Adam(model.parameters(), lr=1e-4, betas=[0.9,0.999])

# Define the loss function
criterion = nn.BCELoss()


# Example usage of the training function with dataloader8
train(model2, num_epochs=50, criterion=criterion, optimizer=optimizer, train_dataloader=combined_dataloader_wo_aug1234)
# Out:
# Loss: 0.6664539575576782 ,Train accuracy: 0.671875
# Loss: 0.7519176006317139 ,Train accuracy: 0.2890625
# Loss: 0.564228892326355 ,Train accuracy: 0.890625
# Loss: 0.7794514894485474 ,Train accuracy: 0.2109375
# Loss: 0.6863716244697571 ,Train accuracy: 0.5703125
# Loss: 0.7737933397293091 ,Train accuracy: 0.2109375
# Loss: 0.6873551607131958 ,Train accuracy: 0.5625
# Loss: 0.7264801263809204 ,Train accuracy: 0.296875
# Loss: 0.6476452350616455 ,Train accuracy: 0.8359375
# Loss: 0.8011503219604492 ,Train accuracy: 0.1171875
# Loss: 0.7029789686203003 ,Train accuracy: 0.4609375
# Loss: 0.7055481672286987 ,Train accuracy: 0.4140625
# Loss: 0.6415096521377563 ,Train accuracy: 0.890625
# Loss: 0.8187271952629089 ,Train accuracy: 0.0859375
# Loss: 0.7014957666397095 ,Train accuracy: 0.53125
# Loss: 0.6977579593658447 ,Train accuracy: 0.4765625
# Loss: 0.6426019668579102 ,Train accuracy: 0.9140625
# Loss: 0.7967057824134827 ,Train accuracy: 0.109375
# Loss: 0.6991418600082397 ,Train accuracy: 0.53125
# Loss: 0.6987473964691162 ,Train accuracy: 0.4609375
# Loss: 0.6362651586532593 ,Train accuracy: 0.96875
# Loss: 0.8137301206588745 ,Train accuracy: 0.046875
# Loss: 0.6914991140365601 ,Train accuracy: 0.4921875
# Loss: 0.6933895945549011 ,Train accuracy: 0.5078125
# Loss: 0.6322128772735596 ,Train accuracy: 0.9765625
# Loss: 0.8115584850311279 ,Train accuracy: 0.0234375
# Loss: 0.6994457244873047 ,Train accuracy: 0.484375
# Loss: 0.687594473361969 ,Train accuracy: 0.609375
# Loss: 0.6369329690933228 ,Train accuracy: 1.0
# Loss: 0.7960715889930725 ,Train accuracy: 0.0234375
# Loss: 0.7028402090072632 ,Train accuracy: 0.453125
# Loss: 0.6865562796592712 ,Train accuracy: 0.5703125
# Loss: 0.6375125646591187 ,Train accuracy: 0.9921875
# Loss: 0.8079851269721985 ,Train accuracy: 0.0078125
# Loss: 0.6948477029800415 ,Train accuracy: 0.515625
# Loss: 0.6810778379440308 ,Train accuracy: 0.609375
# Loss: 0.6329092979431152 ,Train accuracy: 1.0
# Loss: 0.804767370223999 ,Train accuracy: 0.0
# Loss: 0.6910495758056641 ,Train accuracy: 0.546875
# Loss: 0.6828619837760925 ,Train accuracy: 0.6015625
# Loss: 0.6320315599441528 ,Train accuracy: 1.0
# Loss: 0.8081698417663574 ,Train accuracy: 0.0
# Loss: 0.6923614740371704 ,Train accuracy: 0.5390625
# Loss: 0.6714650392532349 ,Train accuracy: 0.78125
# Loss: 0.6311609745025635 ,Train accuracy: 1.0
# Loss: 0.7955332398414612 ,Train accuracy: 0.015625
# Loss: 0.6868239045143127 ,Train accuracy: 0.5703125
# Loss: 0.674014687538147 ,Train accuracy: 0.7265625
# Loss: 0.6262408494949341 ,Train accuracy: 1.0
# Loss: 0.7944851517677307 ,Train accuracy: 0.015625
# Loss: 0.6890760660171509 ,Train accuracy: 0.53125
# Loss: 0.6748340129852295 ,Train accuracy: 0.7578125
# Loss: 0.6266083717346191 ,Train accuracy: 1.0
# Loss: 0.7979424595832825 ,Train accuracy: 0.0078125
# Loss: 0.683565616607666 ,Train accuracy: 0.609375
# Loss: 0.6700829267501831 ,Train accuracy: 0.75
# Loss: 0.6303019523620605 ,Train accuracy: 1.0
# Loss: 0.7959388494491577 ,Train accuracy: 0.0078125
# Loss: 0.6884749531745911 ,Train accuracy: 0.53125
# Loss: 0.663040041923523 ,Train accuracy: 0.8046875
# Loss: 0.6262454390525818 ,Train accuracy: 1.0
# Loss: 0.7964187264442444 ,Train accuracy: 0.0
# Loss: 0.6769540309906006 ,Train accuracy: 0.6875
# Loss: 0.6622000336647034 ,Train accuracy: 0.875
# Loss: 0.6257026195526123 ,Train accuracy: 1.0
# Loss: 0.7863831520080566 ,Train accuracy: 0.0078125
# Loss: 0.6763224601745605 ,Train accuracy: 0.65625
# Loss: 0.6612362861633301 ,Train accuracy: 0.8671875
# Loss: 0.625083327293396 ,Train accuracy: 1.0
# Loss: 0.7876764535903931 ,Train accuracy: 0.0234375
# Loss: 0.6832317113876343 ,Train accuracy: 0.609375
# Loss: 0.6567090153694153 ,Train accuracy: 0.90625
# Loss: 0.6232529878616333 ,Train accuracy: 1.0
# Loss: 0.794930100440979 ,Train accuracy: 0.015625
# Loss: 0.6796115636825562 ,Train accuracy: 0.625
# Loss: 0.6595810651779175 ,Train accuracy: 0.8828125
# Loss: 0.6263821125030518 ,Train accuracy: 1.0
# Loss: 0.7866962552070618 ,Train accuracy: 0.0234375
# Loss: 0.6797803640365601 ,Train accuracy: 0.59375
# Loss: 0.6502343416213989 ,Train accuracy: 0.96875
# Loss: 0.6226459741592407 ,Train accuracy: 1.0
# Loss: 0.7882651090621948 ,Train accuracy: 0.0234375
# Loss: 0.6748577356338501 ,Train accuracy: 0.703125
# Loss: 0.6526602506637573 ,Train accuracy: 0.9453125
# Loss: 0.6221904754638672 ,Train accuracy: 1.0
# Loss: 0.783114492893219 ,Train accuracy: 0.0234375
# Loss: 0.6831340789794922 ,Train accuracy: 0.5859375
# Loss: 0.6485888361930847 ,Train accuracy: 0.9453125
# Loss: 0.6218500137329102 ,Train accuracy: 1.0
# Loss: 0.7758945226669312 ,Train accuracy: 0.0078125
# Loss: 0.6724550127983093 ,Train accuracy: 0.6796875
# Loss: 0.6471392512321472 ,Train accuracy: 0.9375
# Loss: 0.6185187697410583 ,Train accuracy: 1.0
# Loss: 0.7811003923416138 ,Train accuracy: 0.03125
# Loss: 0.6819601655006409 ,Train accuracy: 0.6328125
# Loss: 0.6430697441101074 ,Train accuracy: 0.984375
# Loss: 0.6134591698646545 ,Train accuracy: 1.0
# Loss: 0.7856126427650452 ,Train accuracy: 0.03125
# Loss: 0.6805192232131958 ,Train accuracy: 0.640625
# Loss: 0.643360435962677 ,Train accuracy: 0.984375
# Loss: 0.6188462972640991 ,Train accuracy: 1.0
# Loss: 0.7768068313598633 ,Train accuracy: 0.0078125
# Loss: 0.6680346131324768 ,Train accuracy: 0.6484375
# Loss: 0.6330015659332275 ,Train accuracy: 0.984375
# Loss: 0.6163257360458374 ,Train accuracy: 1.0
# Loss: 0.7859315872192383 ,Train accuracy: 0.03125
# Loss: 0.6638829112052917 ,Train accuracy: 0.7109375
# Loss: 0.6338342428207397 ,Train accuracy: 0.9921875
# Loss: 0.6152493357658386 ,Train accuracy: 1.0
# Loss: 0.771310031414032 ,Train accuracy: 0.0625
# Loss: 0.6678389310836792 ,Train accuracy: 0.7109375
# Loss: 0.6339181661605835 ,Train accuracy: 1.0
# Loss: 0.6138846278190613 ,Train accuracy: 1.0
# Loss: 0.7673808336257935 ,Train accuracy: 0.046875
# Loss: 0.669319212436676 ,Train accuracy: 0.6796875
# Loss: 0.6304666996002197 ,Train accuracy: 0.984375
# Loss: 0.6139507293701172 ,Train accuracy: 1.0
# Loss: 0.7774739265441895 ,Train accuracy: 0.03125
# Loss: 0.6661120057106018 ,Train accuracy: 0.71875
# Loss: 0.6267564296722412 ,Train accuracy: 1.0
# Loss: 0.6127640604972839 ,Train accuracy: 1.0
# Loss: 0.7728376388549805 ,Train accuracy: 0.046875
# Loss: 0.6572667360305786 ,Train accuracy: 0.7265625
# Loss: 0.6197925806045532 ,Train accuracy: 1.0
# Loss: 0.6109381914138794 ,Train accuracy: 1.0
# Loss: 0.7760215997695923 ,Train accuracy: 0.0703125
# Loss: 0.6696107387542725 ,Train accuracy: 0.65625
# Loss: 0.6197140216827393 ,Train accuracy: 1.0
# Loss: 0.6167007684707642 ,Train accuracy: 1.0
# Loss: 0.7644853591918945 ,Train accuracy: 0.046875
# Loss: 0.6600174903869629 ,Train accuracy: 0.7734375
# Loss: 0.6202941536903381 ,Train accuracy: 1.0
# Loss: 0.6136072278022766 ,Train accuracy: 1.0
# Loss: 0.7619744539260864 ,Train accuracy: 0.0625
# Loss: 0.6647683382034302 ,Train accuracy: 0.71875
# Loss: 0.6142209768295288 ,Train accuracy: 1.0
# Loss: 0.6112473607063293 ,Train accuracy: 1.0
# Loss: 0.7831268310546875 ,Train accuracy: 0.0546875
# Loss: 0.6555197238922119 ,Train accuracy: 0.765625
# Loss: 0.6142643690109253 ,Train accuracy: 1.0
# Loss: 0.6105285286903381 ,Train accuracy: 1.0
# Loss: 0.7662994861602783 ,Train accuracy: 0.0859375
# Loss: 0.6578370332717896 ,Train accuracy: 0.7109375
# Loss: 0.6077780723571777 ,Train accuracy: 1.0
# Loss: 0.6038068532943726 ,Train accuracy: 1.0
# Loss: 0.7661714553833008 ,Train accuracy: 0.0390625
# Loss: 0.6546850204467773 ,Train accuracy: 0.765625
# Loss: 0.6146174073219299 ,Train accuracy: 1.0
# Loss: 0.6115766763687134 ,Train accuracy: 1.0
# Loss: 0.7626186609268188 ,Train accuracy: 0.09375
# Loss: 0.655798077583313 ,Train accuracy: 0.7265625
# Loss: 0.6044487357139587 ,Train accuracy: 1.0
# Loss: 0.6058865785598755 ,Train accuracy: 1.0
# Loss: 0.7691491842269897 ,Train accuracy: 0.0859375
# Loss: 0.6602483987808228 ,Train accuracy: 0.6953125
# Loss: 0.6015886068344116 ,Train accuracy: 1.0
# Loss: 0.6042155623435974 ,Train accuracy: 1.0
# Loss: 0.7591114044189453 ,Train accuracy: 0.1015625
# Loss: 0.6438627243041992 ,Train accuracy: 0.7578125
# Loss: 0.6038349866867065 ,Train accuracy: 1.0
# Loss: 0.603206217288971 ,Train accuracy: 1.0
# Loss: 0.7711585760116577 ,Train accuracy: 0.09375
# Loss: 0.6553083658218384 ,Train accuracy: 0.75
# Loss: 0.5985198616981506 ,Train accuracy: 1.0
# Loss: 0.6033099889755249 ,Train accuracy: 1.0
# Loss: 0.7638282775878906 ,Train accuracy: 0.1171875
# Loss: 0.6470449566841125 ,Train accuracy: 0.7734375
# Loss: 0.5935086011886597 ,Train accuracy: 1.0
# Loss: 0.6026608347892761 ,Train accuracy: 1.0
# Loss: 0.7621283531188965 ,Train accuracy: 0.0859375
# Loss: 0.6502920389175415 ,Train accuracy: 0.765625
# Loss: 0.5969547629356384 ,Train accuracy: 1.0
# Loss: 0.6048721075057983 ,Train accuracy: 1.0
# Loss: 0.7658960819244385 ,Train accuracy: 0.1015625
# Loss: 0.6455734968185425 ,Train accuracy: 0.8046875
# Loss: 0.5902304649353027 ,Train accuracy: 1.0
# Loss: 0.600767970085144 ,Train accuracy: 1.0
# Loss: 0.7584758400917053 ,Train accuracy: 0.1015625
# Loss: 0.642254114151001 ,Train accuracy: 0.7421875
# Loss: 0.589914858341217 ,Train accuracy: 1.0
# Loss: 0.5971351861953735 ,Train accuracy: 1.0
# Loss: 0.7530213594436646 ,Train accuracy: 0.15625
# Loss: 0.6356426477432251 ,Train accuracy: 0.7890625
# Loss: 0.5850678086280823 ,Train accuracy: 1.0
# Loss: 0.5948336720466614 ,Train accuracy: 1.0
# Loss: 0.7531482577323914 ,Train accuracy: 0.1328125
# Loss: 0.637881875038147 ,Train accuracy: 0.8203125
# Loss: 0.5785230398178101 ,Train accuracy: 1.0
# Loss: 0.5985867977142334 ,Train accuracy: 1.0
# Loss: 0.7519509196281433 ,Train accuracy: 0.1796875
# Loss: 0.6311087608337402 ,Train accuracy: 0.828125
# Loss: 0.5794001221656799 ,Train accuracy: 1.0
# Loss: 0.5962454080581665 ,Train accuracy: 1.0
# Loss: 0.7416019439697266 ,Train accuracy: 0.2109375
# Loss: 0.6435232162475586 ,Train accuracy: 0.765625
# Loss: 0.5768647789955139 ,Train accuracy: 1.0
# Loss: 0.599880576133728 ,Train accuracy: 1.0
# Loss: 0.74836665391922 ,Train accuracy: 0.234375
# Loss: 0.6264997720718384 ,Train accuracy: 0.84375
# Loss: 0.5721518993377686 ,Train accuracy: 1.0

# %%
# test(model2, criterion, combined_dataloader_wo_aug123)

# %%
pred_class1, pred_class2 = get_predictions(combined_dataloader_wo_aug1234, model2)
Y_comb12 = np.append(Y1, Y2)
Y_comb1234 = np.append(Y_comb12, Y34)
Y_comb1234.shape
plt.scatter(Y_comb1234, pred_class1, label='Super Antiferromagnetic')
plt.scatter(Y_comb1234, pred_class2, label='Paramagnetic')
plt.legend()

# %%
plot_proba(np.array(Y_comb1234), np.array(pred_class1), np.array(pred_class2), 'Super Antiferromagnetic', 'Paramagnetic')

# %%
y_comb1234 = np.array([item[1] for item in combined_dataloader_wo_aug1234.dataset])

# %%
calculate_accuracy_np(np.column_stack((pred_class1, pred_class2)), y_comb1234)
# Out:
# 0.8467777777777777

# %% [markdown]
# ##### Both weights initialized:

# %%
import torch
import torch.nn as nn
import torch.optim as optim

# Load your pre-trained model
model2 = ConvNet2(Nx, Ny)  # or load from saved state
pretrained_model = ConvNet2(Nx, Ny)
state_dict = torch.load("CNN_anti.pth")
pretrained_model.load_state_dict(state_dict)
model2.conv1.weight.data = pretrained_model.conv1.weight.data
model2.conv1.bias.data = pretrained_model.conv1.bias.data
model2.conv2.weight.data = pretrained_model.conv2.weight.data
model2.conv2.bias.data = pretrained_model.conv2.bias.data
model2.conv3.weight.data = pretrained_model.conv3.weight.data
model2.conv3.bias.data = pretrained_model.conv3.bias.data
####
model2.fc1.weight.data = pretrained_model.fc1.weight.data
model2.fc1.bias.data = pretrained_model.fc1.bias.data

model2.fc2.weight.data = pretrained_model.fc2.weight.data
model2.fc2.bias.data = pretrained_model.fc2.bias.data

# Freeze all parameters in the model first
for param in model2.parameters():
    param.requires_grad = False

# Unfreeze the layers that you want to train (fc1 and fc2)
model2.fc1.weight.requires_grad = True
model2.fc1.bias.requires_grad = True
model2.fc2.weight.requires_grad = True
model2.fc2.bias.requires_grad = True
# model2.conv2.weight.requires_grad = True
# model2.conv2.bias.requires_grad = True
# model2.conv3.weight.requires_grad = True
# model2.conv3.bias.requires_grad = True

model2.to(device)

# Setup optimizer - only optimize the unfrozen parameters
optimizer = optim.Adam([
    {'params': model2.fc1.parameters()},
    {'params': model2.fc2.parameters()}
], lr=1e-7, betas=[0.9,0.999])
# optimizer = optim.Adam(model.parameters(), lr=1e-4, betas=[0.9,0.999])

# Define the loss function
criterion = nn.BCELoss()


# Example usage of the training function with dataloader8
train(model2, num_epochs=50, criterion=criterion, optimizer=optimizer, train_dataloader=combined_dataloader_wo_aug1234)
# Out:
# Loss: 34.879730224609375 ,Train accuracy: 0.0
# Loss: 2.6891951776519818e-08 ,Train accuracy: 1.0
# Loss: 1.0518593107633478e-08 ,Train accuracy: 1.0
# Loss: 49.92720031738281 ,Train accuracy: 0.0
# Loss: 36.963623046875 ,Train accuracy: 0.0
# Loss: 7.690487358047449e-09 ,Train accuracy: 1.0
# Loss: 1.3905582463280552e-08 ,Train accuracy: 1.0
# Loss: 48.68603515625 ,Train accuracy: 0.0
# Loss: 33.277320861816406 ,Train accuracy: 0.0
# Loss: 1.338432724651284e-07 ,Train accuracy: 1.0
# Loss: 2.5409028125977784e-07 ,Train accuracy: 1.0
# Loss: 48.801605224609375 ,Train accuracy: 0.0
# Loss: 37.43778991699219 ,Train accuracy: 0.0
# Loss: 4.723554880570191e-09 ,Train accuracy: 1.0
# Loss: 2.4512096796769356e-09 ,Train accuracy: 1.0
# Loss: 48.42644500732422 ,Train accuracy: 0.0
# Loss: 36.893497467041016 ,Train accuracy: 0.0
# Loss: 1.7887636261093576e-08 ,Train accuracy: 1.0
# Loss: 4.5975173668111324e-10 ,Train accuracy: 1.0
# Loss: 46.302181243896484 ,Train accuracy: 0.0
# Loss: 35.03947067260742 ,Train accuracy: 0.0
# Loss: 4.173939771590085e-08 ,Train accuracy: 1.0
# Loss: 1.291961093663474e-09 ,Train accuracy: 1.0
# Loss: 48.607444763183594 ,Train accuracy: 0.0
# Loss: 34.24192810058594 ,Train accuracy: 0.0
# Loss: 1.8847384097853137e-08 ,Train accuracy: 1.0
# Loss: 1.3478418381396295e-08 ,Train accuracy: 1.0
# Loss: 47.636260986328125 ,Train accuracy: 0.0
# Loss: 35.58966064453125 ,Train accuracy: 0.0
# Loss: 9.43748901249819e-08 ,Train accuracy: 1.0
# Loss: 1.9207260781861635e-10 ,Train accuracy: 1.0
# Loss: 48.259864807128906 ,Train accuracy: 0.0
# Loss: 35.97481155395508 ,Train accuracy: 0.0
# Loss: 1.1176986447480886e-07 ,Train accuracy: 1.0
# Loss: 6.708062549876104e-09 ,Train accuracy: 1.0
# Loss: 49.7675666809082 ,Train accuracy: 0.0
# Loss: 34.396724700927734 ,Train accuracy: 0.0
# Loss: 2.0205650486104787e-09 ,Train accuracy: 1.0
# Loss: 1.2576841790234994e-08 ,Train accuracy: 1.0
# Loss: 46.9849967956543 ,Train accuracy: 0.0
# Loss: 33.5184211730957 ,Train accuracy: 0.0
# Loss: 3.3685005007555446e-08 ,Train accuracy: 1.0
# Loss: 1.6719750917104648e-08 ,Train accuracy: 1.0
# Loss: 47.83929443359375 ,Train accuracy: 0.0
# Loss: 33.56159591674805 ,Train accuracy: 0.0
# Loss: 6.813215946976925e-08 ,Train accuracy: 1.0
# Loss: 9.817712864901296e-09 ,Train accuracy: 1.0
# Loss: 46.87222671508789 ,Train accuracy: 0.0
# Loss: 33.69086456298828 ,Train accuracy: 0.0
# Loss: 1.8221073538882138e-09 ,Train accuracy: 1.0
# Loss: 1.2434989926646267e-08 ,Train accuracy: 1.0
# Loss: 48.53970718383789 ,Train accuracy: 0.0
# Loss: 32.38282775878906 ,Train accuracy: 0.0
# Loss: 3.646239221666292e-08 ,Train accuracy: 1.0
# Loss: 7.91131878941087e-06 ,Train accuracy: 1.0
# Loss: 47.02033233642578 ,Train accuracy: 0.0
# Loss: 33.70085906982422 ,Train accuracy: 0.0
# Loss: 1.3185846192698136e-08 ,Train accuracy: 1.0
# Loss: 2.7378586509030356e-08 ,Train accuracy: 1.0
# Loss: 44.52630615234375 ,Train accuracy: 0.0
# Loss: 35.672523498535156 ,Train accuracy: 0.0
# Loss: 1.6230252697368996e-08 ,Train accuracy: 1.0
# Loss: 2.2154336698498867e-10 ,Train accuracy: 1.0
# Loss: 46.149227142333984 ,Train accuracy: 0.0
# Loss: 31.417097091674805 ,Train accuracy: 0.0
# Loss: 4.416927268380277e-09 ,Train accuracy: 1.0
# Loss: 1.1366046237526461e-07 ,Train accuracy: 1.0
# Loss: 48.13716506958008 ,Train accuracy: 0.0
# Loss: 34.94799041748047 ,Train accuracy: 0.0
# Loss: 1.416993278269274e-08 ,Train accuracy: 1.0
# Loss: 2.9791920042043785e-09 ,Train accuracy: 1.0
# Loss: 49.690887451171875 ,Train accuracy: 0.0
# Loss: 33.89911651611328 ,Train accuracy: 0.0
# Loss: 2.0594457250666665e-09 ,Train accuracy: 1.0
# Loss: 4.239206674583329e-08 ,Train accuracy: 1.0
# Loss: 47.423866271972656 ,Train accuracy: 0.0
# Loss: 32.805091857910156 ,Train accuracy: 0.0
# Loss: 2.3687789507675916e-08 ,Train accuracy: 1.0
# Loss: 2.368236273753155e-09 ,Train accuracy: 1.0
# Loss: 45.89848327636719 ,Train accuracy: 0.0
# Loss: 32.793025970458984 ,Train accuracy: 0.0
# Loss: 6.868654978120503e-09 ,Train accuracy: 1.0
# Loss: 2.849951385996974e-09 ,Train accuracy: 1.0
# Loss: 49.928977966308594 ,Train accuracy: 0.0
# Loss: 33.08721160888672 ,Train accuracy: 0.0
# Loss: 2.665203524543358e-08 ,Train accuracy: 1.0
# Loss: 9.41083211358773e-09 ,Train accuracy: 1.0
# Loss: 49.5734977722168 ,Train accuracy: 0.0
# Loss: 30.110872268676758 ,Train accuracy: 0.0
# Loss: 1.2788182734979614e-09 ,Train accuracy: 1.0
# Loss: 8.449876354177377e-09 ,Train accuracy: 1.0
# Loss: 46.41019058227539 ,Train accuracy: 0.0
# Loss: 32.37089920043945 ,Train accuracy: 0.0
# Loss: 3.600103681833389e-08 ,Train accuracy: 1.0
# Loss: 8.87368095670027e-11 ,Train accuracy: 1.0
# Loss: 49.20597457885742 ,Train accuracy: 0.0
# Loss: 29.322938919067383 ,Train accuracy: 0.0
# Loss: 1.1149317913350387e-08 ,Train accuracy: 1.0
# Loss: 3.1290087187940685e-10 ,Train accuracy: 1.0
# Loss: 49.066627502441406 ,Train accuracy: 0.0
# Loss: 34.815223693847656 ,Train accuracy: 0.0
# Loss: 3.0580590504314387e-08 ,Train accuracy: 1.0
# Loss: 5.7360405314454965e-09 ,Train accuracy: 1.0
# Loss: 45.59965515136719 ,Train accuracy: 0.0
# Loss: 33.5701904296875 ,Train accuracy: 0.0
# Loss: 1.0656806104236693e-08 ,Train accuracy: 1.0
# Loss: 1.128694826491028e-08 ,Train accuracy: 1.0
# Loss: 47.16080856323242 ,Train accuracy: 0.0
# Loss: 35.817893981933594 ,Train accuracy: 0.0
# Loss: 1.590089624414759e-07 ,Train accuracy: 1.0
# Loss: 3.1023801305707366e-09 ,Train accuracy: 1.0
# Loss: 47.72187423706055 ,Train accuracy: 0.0
# Loss: 30.06805419921875 ,Train accuracy: 0.0
# Loss: 6.537163699249504e-08 ,Train accuracy: 1.0
# Loss: 6.98912714369726e-08 ,Train accuracy: 1.0
# Loss: 43.44606018066406 ,Train accuracy: 0.0
# Loss: 33.631805419921875 ,Train accuracy: 0.0
# Loss: 1.405596350423366e-07 ,Train accuracy: 1.0
# Loss: 1.3633629336595732e-08 ,Train accuracy: 1.0
# Loss: 46.71394729614258 ,Train accuracy: 0.0
# Loss: 34.49714279174805 ,Train accuracy: 0.0
# Loss: 1.2908806468203693e-07 ,Train accuracy: 1.0
# Loss: 1.1488787521329868e-07 ,Train accuracy: 1.0
# Loss: 48.20378112792969 ,Train accuracy: 0.0
# Loss: 31.764108657836914 ,Train accuracy: 0.0
# Loss: 2.432458927614789e-07 ,Train accuracy: 1.0
# Loss: 8.118097980513994e-07 ,Train accuracy: 1.0
# Loss: 47.532684326171875 ,Train accuracy: 0.0
# Loss: 31.25248908996582 ,Train accuracy: 0.0
# Loss: 2.2804018229294343e-08 ,Train accuracy: 1.0
# Loss: 3.7296574162404283e-10 ,Train accuracy: 1.0
# Loss: 43.589256286621094 ,Train accuracy: 0.0
# Loss: 30.885011672973633 ,Train accuracy: 0.0
# Loss: 1.444023212116008e-08 ,Train accuracy: 1.0
# Loss: 7.138987179189371e-09 ,Train accuracy: 1.0
# Loss: 46.39689636230469 ,Train accuracy: 0.0
# Loss: 34.12705612182617 ,Train accuracy: 0.0
# Loss: 1.8287922287640868e-08 ,Train accuracy: 1.0
# Loss: 1.2110991320923858e-08 ,Train accuracy: 1.0
# Loss: 45.167266845703125 ,Train accuracy: 0.0
# Loss: 33.939781188964844 ,Train accuracy: 0.0
# Loss: 8.845884025276973e-08 ,Train accuracy: 1.0
# Loss: 1.4030694384103981e-09 ,Train accuracy: 1.0
# Loss: 44.954345703125 ,Train accuracy: 0.0
# Loss: 34.75361633300781 ,Train accuracy: 0.0
# Loss: 3.3283020783869688e-09 ,Train accuracy: 1.0
# Loss: 2.4732884185141302e-08 ,Train accuracy: 1.0
# Loss: 47.626808166503906 ,Train accuracy: 0.0
# Loss: 34.97014617919922 ,Train accuracy: 0.0
# Loss: 3.599646092311559e-08 ,Train accuracy: 1.0
# Loss: 9.472698181411943e-09 ,Train accuracy: 1.0
# Loss: 47.817726135253906 ,Train accuracy: 0.0
# Loss: 27.13106918334961 ,Train accuracy: 0.0
# Loss: 6.44524167370264e-09 ,Train accuracy: 1.0
# Loss: 1.1472121741462615e-07 ,Train accuracy: 1.0
# Loss: 45.11669158935547 ,Train accuracy: 0.0
# Loss: 31.112079620361328 ,Train accuracy: 0.0
# Loss: 2.573700363939224e-09 ,Train accuracy: 1.0
# Loss: 4.057017832792553e-08 ,Train accuracy: 1.0
# Loss: 48.658302307128906 ,Train accuracy: 0.0
# Loss: 30.241485595703125 ,Train accuracy: 0.0
# Loss: 5.116888956990806e-08 ,Train accuracy: 1.0
# Loss: 1.799436510907526e-08 ,Train accuracy: 1.0
# Loss: 46.792022705078125 ,Train accuracy: 0.0
# Loss: 28.99551010131836 ,Train accuracy: 0.0
# Loss: 9.4276879636368e-09 ,Train accuracy: 1.0
# Loss: 8.419076635846068e-08 ,Train accuracy: 1.0
# Loss: 41.74896240234375 ,Train accuracy: 0.0
# Loss: 30.665348052978516 ,Train accuracy: 0.0
# Loss: 6.222360866559029e-07 ,Train accuracy: 1.0
# Loss: 1.3080645455687545e-09 ,Train accuracy: 1.0
# Loss: 42.48198318481445 ,Train accuracy: 0.0
# Loss: 28.847667694091797 ,Train accuracy: 0.0
# Loss: 5.799640348413959e-06 ,Train accuracy: 1.0
# Loss: 2.554983495883789e-07 ,Train accuracy: 1.0
# Loss: 44.030067443847656 ,Train accuracy: 0.0
# Loss: 30.997591018676758 ,Train accuracy: 0.0
# Loss: 2.0259141031431227e-09 ,Train accuracy: 1.0
# Loss: 4.756910598757713e-08 ,Train accuracy: 1.0
# Loss: 44.80994415283203 ,Train accuracy: 0.0
# Loss: 30.496337890625 ,Train accuracy: 0.0
# Loss: 2.140284394158698e-08 ,Train accuracy: 1.0
# Loss: 1.917927594519142e-09 ,Train accuracy: 1.0
# Loss: 46.72747802734375 ,Train accuracy: 0.0
# Loss: 27.715354919433594 ,Train accuracy: 0.0
# Loss: 7.057836626245262e-08 ,Train accuracy: 1.0
# Loss: 1.431994967049377e-09 ,Train accuracy: 1.0
# Loss: 44.464447021484375 ,Train accuracy: 0.0
# Loss: 27.91952133178711 ,Train accuracy: 0.0
# Loss: 1.9070000689680455e-08 ,Train accuracy: 1.0
# Loss: 1.5610053694103954e-08 ,Train accuracy: 1.0
# Loss: 47.24684524536133 ,Train accuracy: 0.0
# Loss: 28.828414916992188 ,Train accuracy: 0.0
# Loss: 1.458603264836711e-07 ,Train accuracy: 1.0
# Loss: 2.56173554591399e-10 ,Train accuracy: 1.0
# Loss: 43.93772888183594 ,Train accuracy: 0.0
# Loss: 28.6938419342041 ,Train accuracy: 0.0
# Loss: 2.245562624736408e-09 ,Train accuracy: 1.0
# Loss: 3.6486924592793457e-09 ,Train accuracy: 1.0
# Loss: 42.79196548461914 ,Train accuracy: 0.0

# %%
# test(model2, criterion, combined_dataloader_wo_aug123)

# %%
pred_class1, pred_class2 = get_predictions(combined_dataloader_wo_aug1234, model2)
Y_comb12 = np.append(Y1, Y2)
Y_comb1234 = np.append(Y_comb12, Y34)
Y_comb1234.shape
plt.scatter(Y_comb1234, pred_class1, label='Super Antiferromagnetic')
plt.scatter(Y_comb1234, pred_class2, label='Paramagnetic')
plt.legend()

# %%
plot_proba(np.array(Y_comb1234), np.array(pred_class1), np.array(pred_class2), 'Super Antiferromagnetic', 'Paramagnetic')

# %%
y_comb1234 = np.array([item[1] for item in combined_dataloader_wo_aug1234.dataset])

# %%
calculate_accuracy_np(np.column_stack((pred_class1, pred_class2)), y_comb1234)
# Out:
# 0.3888888888888889

# %% [markdown]
# #### Transfer learning on NNN R=+2 data, model pre-trained on anti-ferro NN

# %% [markdown]
# ##### Both weights not initialized:

# %%
import torch
import torch.nn as nn
import torch.optim as optim

# Load your pre-trained model
model2 = ConvNet2(Nx, Ny)  # or load from saved state
pretrained_model = ConvNet2(Nx, Ny)
state_dict = torch.load("CNN_anti.pth")
pretrained_model.load_state_dict(state_dict)
model2.conv1.weight.data = pretrained_model.conv1.weight.data
model2.conv1.bias.data = pretrained_model.conv1.bias.data
model2.conv2.weight.data = pretrained_model.conv2.weight.data
model2.conv2.bias.data = pretrained_model.conv2.bias.data
model2.conv3.weight.data = pretrained_model.conv3.weight.data
model2.conv3.bias.data = pretrained_model.conv3.bias.data
####
# model2.fc1.weight.data = pretrained_model.fc1.weight.data
# model2.fc1.bias.data = pretrained_model.fc1.bias.data

# model2.fc2.weight.data = pretrained_model.fc2.weight.data
# model2.fc2.bias.data = pretrained_model.fc2.bias.data

# Freeze all parameters in the model first
for param in model2.parameters():
    param.requires_grad = False

# Unfreeze the layers that you want to train (fc1 and fc2)
model2.fc1.weight.requires_grad = True
model2.fc1.bias.requires_grad = True
model2.fc2.weight.requires_grad = True
model2.fc2.bias.requires_grad = True
# model2.conv2.weight.requires_grad = True
# model2.conv2.bias.requires_grad = True
# model2.conv3.weight.requires_grad = True
# model2.conv3.bias.requires_grad = True

model2.to(device)

# Setup optimizer - only optimize the unfrozen parameters
optimizer = optim.Adam([
    {'params': model2.fc1.parameters()},
    {'params': model2.fc2.parameters()}
], lr=1e-5, betas=[0.9,0.999])
# optimizer = optim.Adam(model.parameters(), lr=1e-4, betas=[0.9,0.999])

# Define the loss function
criterion = nn.BCELoss()


# Example usage of the training function with dataloader8
train(model2, num_epochs=50, criterion=criterion, optimizer=optimizer, train_dataloader=combined_dataloader_wo_aug1234)
# Out:
# Loss: 0.8589515686035156 ,Train accuracy: 0.0
# Loss: 0.5537881851196289 ,Train accuracy: 0.96875
# Loss: 0.364601194858551 ,Train accuracy: 1.0
# Loss: 0.934319257736206 ,Train accuracy: 0.0
# Loss: 0.7066973447799683 ,Train accuracy: 0.3828125
# Loss: 0.8212700486183167 ,Train accuracy: 0.1640625
# Loss: 0.7348287105560303 ,Train accuracy: 0.265625
# Loss: 0.7046307921409607 ,Train accuracy: 0.375
# Loss: 0.7060668468475342 ,Train accuracy: 0.3515625
# Loss: 0.8048971891403198 ,Train accuracy: 0.0703125
# Loss: 0.7224994897842407 ,Train accuracy: 0.25
# Loss: 0.7107723355293274 ,Train accuracy: 0.203125
# Loss: 0.7113320827484131 ,Train accuracy: 0.25
# Loss: 0.7770602703094482 ,Train accuracy: 0.1328125
# Loss: 0.7164524793624878 ,Train accuracy: 0.28125
# Loss: 0.7125269174575806 ,Train accuracy: 0.21875
# Loss: 0.7118133902549744 ,Train accuracy: 0.21875
# Loss: 0.768667459487915 ,Train accuracy: 0.1640625
# Loss: 0.7112504243850708 ,Train accuracy: 0.390625
# Loss: 0.71834397315979 ,Train accuracy: 0.1171875
# Loss: 0.7109965085983276 ,Train accuracy: 0.1640625
# Loss: 0.769944965839386 ,Train accuracy: 0.1015625
# Loss: 0.6983478665351868 ,Train accuracy: 0.5078125
# Loss: 0.7184752821922302 ,Train accuracy: 0.125
# Loss: 0.7130002975463867 ,Train accuracy: 0.1328125
# Loss: 0.7778135538101196 ,Train accuracy: 0.1171875
# Loss: 0.704121470451355 ,Train accuracy: 0.4375
# Loss: 0.7157552242279053 ,Train accuracy: 0.1640625
# Loss: 0.7170557379722595 ,Train accuracy: 0.1015625
# Loss: 0.7633886337280273 ,Train accuracy: 0.125
# Loss: 0.7071439027786255 ,Train accuracy: 0.4453125
# Loss: 0.7184985280036926 ,Train accuracy: 0.078125
# Loss: 0.7156022787094116 ,Train accuracy: 0.1484375
# Loss: 0.7491487264633179 ,Train accuracy: 0.15625
# Loss: 0.7034047842025757 ,Train accuracy: 0.46875
# Loss: 0.7157784104347229 ,Train accuracy: 0.109375
# Loss: 0.7148566246032715 ,Train accuracy: 0.1328125
# Loss: 0.7687320709228516 ,Train accuracy: 0.109375
# Loss: 0.7011605501174927 ,Train accuracy: 0.4921875
# Loss: 0.7188757658004761 ,Train accuracy: 0.109375
# Loss: 0.7142881751060486 ,Train accuracy: 0.125
# Loss: 0.7610998749732971 ,Train accuracy: 0.1328125
# Loss: 0.6977905035018921 ,Train accuracy: 0.5234375
# Loss: 0.7164420485496521 ,Train accuracy: 0.125
# Loss: 0.7118355631828308 ,Train accuracy: 0.140625
# Loss: 0.7547537088394165 ,Train accuracy: 0.140625
# Loss: 0.6962729692459106 ,Train accuracy: 0.515625
# Loss: 0.7199182510375977 ,Train accuracy: 0.0859375
# Loss: 0.7206419706344604 ,Train accuracy: 0.09375
# Loss: 0.7515546083450317 ,Train accuracy: 0.109375
# Loss: 0.691868245601654 ,Train accuracy: 0.4921875
# Loss: 0.7215715050697327 ,Train accuracy: 0.0
# Loss: 0.7264770269393921 ,Train accuracy: 0.0
# Loss: 0.7140390872955322 ,Train accuracy: 0.2265625
# Loss: 0.6933898329734802 ,Train accuracy: 0.5078125
# Loss: 0.7194220423698425 ,Train accuracy: 0.09375
# Loss: 0.7256799936294556 ,Train accuracy: 0.0
# Loss: 0.7198814153671265 ,Train accuracy: 0.265625
# Loss: 0.6856468915939331 ,Train accuracy: 0.625
# Loss: 0.6978168487548828 ,Train accuracy: 0.4453125
# Loss: 0.7066569328308105 ,Train accuracy: 0.3203125
# Loss: 0.776228129863739 ,Train accuracy: 0.140625
# Loss: 0.7220796346664429 ,Train accuracy: 0.2734375
# Loss: 0.7036495208740234 ,Train accuracy: 0.3359375
# Loss: 0.7059639692306519 ,Train accuracy: 0.3671875
# Loss: 0.7787156105041504 ,Train accuracy: 0.1328125
# Loss: 0.7099012136459351 ,Train accuracy: 0.40625
# Loss: 0.7064100503921509 ,Train accuracy: 0.2734375
# Loss: 0.7087084054946899 ,Train accuracy: 0.2265625
# Loss: 0.7666689157485962 ,Train accuracy: 0.171875
# Loss: 0.704459011554718 ,Train accuracy: 0.34375
# Loss: 0.7101799249649048 ,Train accuracy: 0.2109375
# Loss: 0.71236252784729 ,Train accuracy: 0.203125
# Loss: 0.7664532661437988 ,Train accuracy: 0.15625
# Loss: 0.699916422367096 ,Train accuracy: 0.4296875
# Loss: 0.7073483467102051 ,Train accuracy: 0.25
# Loss: 0.7060938477516174 ,Train accuracy: 0.2734375
# Loss: 0.7648608684539795 ,Train accuracy: 0.1640625
# Loss: 0.7016083002090454 ,Train accuracy: 0.3828125
# Loss: 0.7088548541069031 ,Train accuracy: 0.2578125
# Loss: 0.7132084369659424 ,Train accuracy: 0.1484375
# Loss: 0.7598600387573242 ,Train accuracy: 0.109375
# Loss: 0.6972531080245972 ,Train accuracy: 0.3984375
# Loss: 0.7070990800857544 ,Train accuracy: 0.3203125
# Loss: 0.7081407904624939 ,Train accuracy: 0.2734375
# Loss: 0.7529277205467224 ,Train accuracy: 0.15625
# Loss: 0.7010461091995239 ,Train accuracy: 0.4453125
# Loss: 0.7107810974121094 ,Train accuracy: 0.2734375
# Loss: 0.687227189540863 ,Train accuracy: 0.5390625
# Loss: 0.8765273094177246 ,Train accuracy: 0.0390625
# Loss: 0.6822011470794678 ,Train accuracy: 0.6640625
# Loss: 0.7239158153533936 ,Train accuracy: 0.0
# Loss: 0.7262307405471802 ,Train accuracy: 0.0
# Loss: 0.703486442565918 ,Train accuracy: 0.390625
# Loss: 0.6826368570327759 ,Train accuracy: 0.6015625
# Loss: 0.715383768081665 ,Train accuracy: 0.1640625
# Loss: 0.7248893976211548 ,Train accuracy: 0.0
# Loss: 0.7069279551506042 ,Train accuracy: 0.2890625
# Loss: 0.6886221170425415 ,Train accuracy: 0.59375
# Loss: 0.7155324816703796 ,Train accuracy: 0.203125
# Loss: 0.722305417060852 ,Train accuracy: 0.0078125
# Loss: 0.7127186059951782 ,Train accuracy: 0.2734375
# Loss: 0.6930009722709656 ,Train accuracy: 0.546875
# Loss: 0.6966753005981445 ,Train accuracy: 0.4765625
# Loss: 0.7014355659484863 ,Train accuracy: 0.3984375
# Loss: 0.7786864042282104 ,Train accuracy: 0.1328125
# Loss: 0.7124125957489014 ,Train accuracy: 0.34375
# Loss: 0.6986551284790039 ,Train accuracy: 0.3828125
# Loss: 0.7068161964416504 ,Train accuracy: 0.3046875
# Loss: 0.7730629444122314 ,Train accuracy: 0.1171875
# Loss: 0.7030245661735535 ,Train accuracy: 0.390625
# Loss: 0.7044376730918884 ,Train accuracy: 0.328125
# Loss: 0.7094746828079224 ,Train accuracy: 0.2265625
# Loss: 0.7682960033416748 ,Train accuracy: 0.1015625
# Loss: 0.6983188390731812 ,Train accuracy: 0.4140625
# Loss: 0.7072374820709229 ,Train accuracy: 0.2578125
# Loss: 0.7091043591499329 ,Train accuracy: 0.234375
# Loss: 0.769773006439209 ,Train accuracy: 0.0390625
# Loss: 0.6954203248023987 ,Train accuracy: 0.46875
# Loss: 0.7081136703491211 ,Train accuracy: 0.2421875
# Loss: 0.7091538906097412 ,Train accuracy: 0.25
# Loss: 0.7592053413391113 ,Train accuracy: 0.1796875
# Loss: 0.7008419036865234 ,Train accuracy: 0.3984375
# Loss: 0.7073306441307068 ,Train accuracy: 0.2421875
# Loss: 0.7090964317321777 ,Train accuracy: 0.234375
# Loss: 0.7654668688774109 ,Train accuracy: 0.0546875
# Loss: 0.6947704553604126 ,Train accuracy: 0.484375
# Loss: 0.7051856517791748 ,Train accuracy: 0.3125
# Loss: 0.7069991827011108 ,Train accuracy: 0.28125
# Loss: 0.7668213844299316 ,Train accuracy: 0.109375
# Loss: 0.6941282749176025 ,Train accuracy: 0.515625
# Loss: 0.70461106300354 ,Train accuracy: 0.3125
# Loss: 0.7093899250030518 ,Train accuracy: 0.25
# Loss: 0.7464300394058228 ,Train accuracy: 0.1015625
# Loss: 0.6953434348106384 ,Train accuracy: 0.4609375
# Loss: 0.701422929763794 ,Train accuracy: 0.34375
# Loss: 0.7061203718185425 ,Train accuracy: 0.3125
# Loss: 0.7522627115249634 ,Train accuracy: 0.1171875
# Loss: 0.6969574093818665 ,Train accuracy: 0.4609375
# Loss: 0.6978946924209595 ,Train accuracy: 0.4453125
# Loss: 0.7043658494949341 ,Train accuracy: 0.3203125
# Loss: 0.7742723226547241 ,Train accuracy: 0.046875
# Loss: 0.7030385732650757 ,Train accuracy: 0.3828125
# Loss: 0.6966498494148254 ,Train accuracy: 0.5234375
# Loss: 0.7059285640716553 ,Train accuracy: 0.3203125
# Loss: 0.7661329507827759 ,Train accuracy: 0.1328125
# Loss: 0.7047064304351807 ,Train accuracy: 0.3828125
# Loss: 0.7045707702636719 ,Train accuracy: 0.3203125
# Loss: 0.7039557099342346 ,Train accuracy: 0.359375
# Loss: 0.7579631805419922 ,Train accuracy: 0.125
# Loss: 0.6976553201675415 ,Train accuracy: 0.4765625
# Loss: 0.6983507871627808 ,Train accuracy: 0.4140625
# Loss: 0.7075071334838867 ,Train accuracy: 0.234375
# Loss: 0.7516453266143799 ,Train accuracy: 0.09375
# Loss: 0.7007795572280884 ,Train accuracy: 0.34375
# Loss: 0.6975030899047852 ,Train accuracy: 0.421875
# Loss: 0.7063331007957458 ,Train accuracy: 0.3203125
# Loss: 0.7447717189788818 ,Train accuracy: 0.1640625
# Loss: 0.701364278793335 ,Train accuracy: 0.4140625
# Loss: 0.7019760608673096 ,Train accuracy: 0.34375
# Loss: 0.7086770534515381 ,Train accuracy: 0.28125
# Loss: 0.7568446397781372 ,Train accuracy: 0.125
# Loss: 0.6940368413925171 ,Train accuracy: 0.5
# Loss: 0.7070133686065674 ,Train accuracy: 0.2578125
# Loss: 0.708256185054779 ,Train accuracy: 0.203125
# Loss: 0.7476019859313965 ,Train accuracy: 0.1484375
# Loss: 0.6933729648590088 ,Train accuracy: 0.4921875
# Loss: 0.6970564126968384 ,Train accuracy: 0.4375
# Loss: 0.7061330080032349 ,Train accuracy: 0.3046875
# Loss: 0.7411558628082275 ,Train accuracy: 0.1953125
# Loss: 0.6953098773956299 ,Train accuracy: 0.5
# Loss: 0.7019487619400024 ,Train accuracy: 0.421875
# Loss: 0.7073005437850952 ,Train accuracy: 0.265625
# Loss: 0.7532364130020142 ,Train accuracy: 0.1484375
# Loss: 0.6919450759887695 ,Train accuracy: 0.5546875
# Loss: 0.6942803263664246 ,Train accuracy: 0.4765625
# Loss: 0.7079724073410034 ,Train accuracy: 0.2578125
# Loss: 0.7650003433227539 ,Train accuracy: 0.0703125
# Loss: 0.6922617554664612 ,Train accuracy: 0.5
# Loss: 0.7007562518119812 ,Train accuracy: 0.359375
# Loss: 0.7089178562164307 ,Train accuracy: 0.2265625
# Loss: 0.7511128187179565 ,Train accuracy: 0.1640625
# Loss: 0.6902490854263306 ,Train accuracy: 0.5546875
# Loss: 0.6951844692230225 ,Train accuracy: 0.4609375
# Loss: 0.7074755430221558 ,Train accuracy: 0.2578125
# Loss: 0.7491403222084045 ,Train accuracy: 0.1875
# Loss: 0.7020168304443359 ,Train accuracy: 0.3359375
# Loss: 0.6953070163726807 ,Train accuracy: 0.390625
# Loss: 0.7051310539245605 ,Train accuracy: 0.3046875
# Loss: 0.7428455352783203 ,Train accuracy: 0.1953125
# Loss: 0.6910251975059509 ,Train accuracy: 0.546875
# Loss: 0.7009589672088623 ,Train accuracy: 0.3515625
# Loss: 0.7070680856704712 ,Train accuracy: 0.296875
# Loss: 0.7453408241271973 ,Train accuracy: 0.1875
# Loss: 0.6920559406280518 ,Train accuracy: 0.515625
# Loss: 0.6962591409683228 ,Train accuracy: 0.46875
# Loss: 0.7052902579307556 ,Train accuracy: 0.28125
# Loss: 0.7513453364372253 ,Train accuracy: 0.15625
# Loss: 0.6884159445762634 ,Train accuracy: 0.59375
# Loss: 0.6956879496574402 ,Train accuracy: 0.5078125

# %%
# test(model2, criterion, combined_dataloader_wo_aug123)

# %%
pred_class1, pred_class2 = get_predictions(combined_dataloader_wo_aug1234, model2)
Y_comb12 = np.append(Y1, Y2)
Y_comb1234 = np.append(Y_comb12, Y34)
Y_comb1234.shape
plt.scatter(Y_comb1234, pred_class1, label='Super Antiferromagnetic')
plt.scatter(Y_comb1234, pred_class2, label='Paramagnetic')
plt.legend()

# %%
plot_proba(np.array(Y_comb1234), np.array(pred_class1), np.array(pred_class2), 'Super Antiferromagnetic', 'Paramagnetic')

# %%
y_comb1234 = np.array([item[1] for item in combined_dataloader_wo_aug1234.dataset])
calculate_accuracy_np(np.column_stack((pred_class1, pred_class2)), y_comb1234)
# Out:
# 0.48966666666666664

# %% [markdown]
# ##### FC1 initialized:

# %%
import torch
import torch.nn as nn
import torch.optim as optim

# Load your pre-trained model
model2 = ConvNet2(Nx, Ny)  # or load from saved state
pretrained_model = ConvNet2(Nx, Ny)
state_dict = torch.load("CNN_anti.pth")
pretrained_model.load_state_dict(state_dict)
model2.conv1.weight.data = pretrained_model.conv1.weight.data
model2.conv1.bias.data = pretrained_model.conv1.bias.data
model2.conv2.weight.data = pretrained_model.conv2.weight.data
model2.conv2.bias.data = pretrained_model.conv2.bias.data
model2.conv3.weight.data = pretrained_model.conv3.weight.data
model2.conv3.bias.data = pretrained_model.conv3.bias.data
####
model2.fc1.weight.data = pretrained_model.fc1.weight.data
model2.fc1.bias.data = pretrained_model.fc1.bias.data

# model2.fc2.weight.data = pretrained_model.fc2.weight.data
# model2.fc2.bias.data = pretrained_model.fc2.bias.data

# Freeze all parameters in the model first
for param in model2.parameters():
    param.requires_grad = False

# Unfreeze the layers that you want to train (fc1 and fc2)
model2.fc1.weight.requires_grad = True
model2.fc1.bias.requires_grad = True
model2.fc2.weight.requires_grad = True
model2.fc2.bias.requires_grad = True
# model2.conv2.weight.requires_grad = True
# model2.conv2.bias.requires_grad = True
# model2.conv3.weight.requires_grad = True
# model2.conv3.bias.requires_grad = True

model2.to(device)

# Setup optimizer - only optimize the unfrozen parameters
optimizer = optim.Adam([
    {'params': model2.fc1.parameters()},
    {'params': model2.fc2.parameters()}
], lr=1e-5, betas=[0.9,0.999])
# optimizer = optim.Adam(model.parameters(), lr=1e-4, betas=[0.9,0.999])

# Define the loss function
criterion = nn.BCELoss()


# Example usage of the training function with dataloader8
train(model2, num_epochs=50, criterion=criterion, optimizer=optimizer, train_dataloader=combined_dataloader_wo_aug1234)
# Out:
# Loss: 1.7577176094055176 ,Train accuracy: 0.3984375
# Loss: 3.3432605266571045 ,Train accuracy: 0.5546875
# Loss: 4.520652770996094 ,Train accuracy: 0.5625
# Loss: 3.794935703277588 ,Train accuracy: 0.46875
# Loss: 1.5295745134353638 ,Train accuracy: 0.4453125
# Loss: 4.0857391357421875 ,Train accuracy: 0.5234375
# Loss: 4.849842071533203 ,Train accuracy: 0.46875
# Loss: 2.5328986644744873 ,Train accuracy: 0.4921875
# Loss: 1.2486519813537598 ,Train accuracy: 0.5078125
# Loss: 6.347267150878906 ,Train accuracy: 0.46875
# Loss: 7.1332879066467285 ,Train accuracy: 0.421875
# Loss: 3.043121337890625 ,Train accuracy: 0.484375
# Loss: 0.999308168888092 ,Train accuracy: 0.59375
# Loss: 5.3627166748046875 ,Train accuracy: 0.4609375
# Loss: 6.105401992797852 ,Train accuracy: 0.421875
# Loss: 2.3451988697052 ,Train accuracy: 0.578125
# Loss: 1.2522830963134766 ,Train accuracy: 0.578125
# Loss: 6.421718597412109 ,Train accuracy: 0.359375
# Loss: 5.777164459228516 ,Train accuracy: 0.40625
# Loss: 1.979531168937683 ,Train accuracy: 0.671875
# Loss: 1.0642521381378174 ,Train accuracy: 0.5390625
# Loss: 5.623985767364502 ,Train accuracy: 0.4375
# Loss: 6.354219436645508 ,Train accuracy: 0.4140625
# Loss: 1.8100364208221436 ,Train accuracy: 0.6328125
# Loss: 0.9750004410743713 ,Train accuracy: 0.625
# Loss: 7.4546966552734375 ,Train accuracy: 0.390625
# Loss: 10.480603218078613 ,Train accuracy: 0.3046875
# Loss: 1.7365899085998535 ,Train accuracy: 0.6484375
# Loss: 1.2450261116027832 ,Train accuracy: 0.5859375
# Loss: 9.9534912109375 ,Train accuracy: 0.3046875
# Loss: 9.374683380126953 ,Train accuracy: 0.328125
# Loss: 1.8782850503921509 ,Train accuracy: 0.640625
# Loss: 0.800683856010437 ,Train accuracy: 0.625
# Loss: 10.909454345703125 ,Train accuracy: 0.3515625
# Loss: 11.785116195678711 ,Train accuracy: 0.390625
# Loss: 2.6163434982299805 ,Train accuracy: 0.578125
# Loss: 1.0613569021224976 ,Train accuracy: 0.6484375
# Loss: 8.34744930267334 ,Train accuracy: 0.390625
# Loss: 8.799161911010742 ,Train accuracy: 0.40625
# Loss: 1.9689078330993652 ,Train accuracy: 0.6875
# Loss: 1.0985603332519531 ,Train accuracy: 0.6640625
# Loss: 11.68387222290039 ,Train accuracy: 0.3203125
# Loss: 13.612739562988281 ,Train accuracy: 0.265625
# Loss: 3.1389431953430176 ,Train accuracy: 0.6171875
# Loss: 1.0923548936843872 ,Train accuracy: 0.6015625
# Loss: 14.424888610839844 ,Train accuracy: 0.3125
# Loss: 12.417867660522461 ,Train accuracy: 0.375
# Loss: 2.3813223838806152 ,Train accuracy: 0.6328125
# Loss: 1.109780192375183 ,Train accuracy: 0.65625
# Loss: 11.927234649658203 ,Train accuracy: 0.34375
# Loss: 17.56586456298828 ,Train accuracy: 0.296875
# Loss: 2.323366641998291 ,Train accuracy: 0.6015625
# Loss: 1.4219861030578613 ,Train accuracy: 0.5859375
# Loss: 13.436612129211426 ,Train accuracy: 0.34375
# Loss: 13.768928527832031 ,Train accuracy: 0.40625
# Loss: 3.919607639312744 ,Train accuracy: 0.5625
# Loss: 1.2185068130493164 ,Train accuracy: 0.65625
# Loss: 17.52457618713379 ,Train accuracy: 0.34375
# Loss: 13.872537612915039 ,Train accuracy: 0.34375
# Loss: 4.2247467041015625 ,Train accuracy: 0.6015625
# Loss: 0.9509611129760742 ,Train accuracy: 0.6875
# Loss: 15.786893844604492 ,Train accuracy: 0.3359375
# Loss: 15.993179321289062 ,Train accuracy: 0.3828125
# Loss: 2.9298136234283447 ,Train accuracy: 0.6484375
# Loss: 1.5091201066970825 ,Train accuracy: 0.5859375
# Loss: 15.999476432800293 ,Train accuracy: 0.3125
# Loss: 15.581575393676758 ,Train accuracy: 0.3359375
# Loss: 3.599868059158325 ,Train accuracy: 0.65625
# Loss: 1.1908962726593018 ,Train accuracy: 0.6171875
# Loss: 18.422258377075195 ,Train accuracy: 0.359375
# Loss: 23.45997428894043 ,Train accuracy: 0.3515625
# Loss: 3.2205541133880615 ,Train accuracy: 0.7109375
# Loss: 1.0355833768844604 ,Train accuracy: 0.671875
# Loss: 24.06777572631836 ,Train accuracy: 0.3359375
# Loss: 23.70660400390625 ,Train accuracy: 0.28125
# Loss: 3.554589033126831 ,Train accuracy: 0.640625
# Loss: 1.4870442152023315 ,Train accuracy: 0.65625
# Loss: 19.464889526367188 ,Train accuracy: 0.3046875
# Loss: 23.26323699951172 ,Train accuracy: 0.328125
# Loss: 2.5208475589752197 ,Train accuracy: 0.671875
# Loss: 1.3501172065734863 ,Train accuracy: 0.640625
# Loss: 22.12575912475586 ,Train accuracy: 0.3359375
# Loss: 21.38140869140625 ,Train accuracy: 0.3828125
# Loss: 4.257363796234131 ,Train accuracy: 0.6484375
# Loss: 1.596465826034546 ,Train accuracy: 0.6171875
# Loss: 26.580028533935547 ,Train accuracy: 0.296875
# Loss: 24.869918823242188 ,Train accuracy: 0.3203125
# Loss: 5.4783759117126465 ,Train accuracy: 0.6484375
# Loss: 1.2224044799804688 ,Train accuracy: 0.7421875
# Loss: 24.961261749267578 ,Train accuracy: 0.3203125
# Loss: 27.569332122802734 ,Train accuracy: 0.234375
# Loss: 3.8028879165649414 ,Train accuracy: 0.7421875
# Loss: 1.4399261474609375 ,Train accuracy: 0.65625
# Loss: 27.595951080322266 ,Train accuracy: 0.2890625
# Loss: 29.433061599731445 ,Train accuracy: 0.2890625
# Loss: 4.092835903167725 ,Train accuracy: 0.6640625
# Loss: 1.0945298671722412 ,Train accuracy: 0.71875
# Loss: 25.138893127441406 ,Train accuracy: 0.375
# Loss: 30.600433349609375 ,Train accuracy: 0.28125
# Loss: 5.0457377433776855 ,Train accuracy: 0.71875
# Loss: 1.1191298961639404 ,Train accuracy: 0.7109375
# Loss: 31.169002532958984 ,Train accuracy: 0.265625
# Loss: 29.47653579711914 ,Train accuracy: 0.3203125
# Loss: 4.065203666687012 ,Train accuracy: 0.6796875
# Loss: 1.4877831935882568 ,Train accuracy: 0.6640625
# Loss: 33.924102783203125 ,Train accuracy: 0.2421875
# Loss: 27.605926513671875 ,Train accuracy: 0.2578125
# Loss: 5.046777248382568 ,Train accuracy: 0.6875
# Loss: 1.4359140396118164 ,Train accuracy: 0.6875
# Loss: 27.652477264404297 ,Train accuracy: 0.328125
# Loss: 28.63855743408203 ,Train accuracy: 0.2421875
# Loss: 7.138460636138916 ,Train accuracy: 0.6640625
# Loss: 1.488046646118164 ,Train accuracy: 0.640625
# Loss: 31.760133743286133 ,Train accuracy: 0.3046875
# Loss: 26.653779983520508 ,Train accuracy: 0.3046875
# Loss: 4.292100429534912 ,Train accuracy: 0.7421875
# Loss: 1.2273375988006592 ,Train accuracy: 0.7109375
# Loss: 27.98141860961914 ,Train accuracy: 0.3125
# Loss: 32.620826721191406 ,Train accuracy: 0.2421875
# Loss: 3.980936050415039 ,Train accuracy: 0.7265625
# Loss: 1.1225330829620361 ,Train accuracy: 0.765625
# Loss: 31.450119018554688 ,Train accuracy: 0.265625
# Loss: 35.974021911621094 ,Train accuracy: 0.2265625
# Loss: 4.560832500457764 ,Train accuracy: 0.6953125
# Loss: 1.190490484237671 ,Train accuracy: 0.7578125
# Loss: 28.389602661132812 ,Train accuracy: 0.3359375
# Loss: 32.71366882324219 ,Train accuracy: 0.3046875
# Loss: 4.469418525695801 ,Train accuracy: 0.75
# Loss: 1.0346623659133911 ,Train accuracy: 0.7578125
# Loss: 34.65626525878906 ,Train accuracy: 0.2578125
# Loss: 35.82640838623047 ,Train accuracy: 0.3046875
# Loss: 4.322551250457764 ,Train accuracy: 0.6953125
# Loss: 1.487792730331421 ,Train accuracy: 0.7421875
# Loss: 32.726470947265625 ,Train accuracy: 0.2265625
# Loss: 34.012210845947266 ,Train accuracy: 0.2734375
# Loss: 3.9523890018463135 ,Train accuracy: 0.7578125
# Loss: 2.5343832969665527 ,Train accuracy: 0.671875
# Loss: 28.105865478515625 ,Train accuracy: 0.3125
# Loss: 36.917091369628906 ,Train accuracy: 0.265625
# Loss: 4.534011363983154 ,Train accuracy: 0.71875
# Loss: 1.1447577476501465 ,Train accuracy: 0.7109375
# Loss: 34.875125885009766 ,Train accuracy: 0.28125
# Loss: 37.298065185546875 ,Train accuracy: 0.28125
# Loss: 6.628115653991699 ,Train accuracy: 0.703125
# Loss: 1.3872485160827637 ,Train accuracy: 0.7578125
# Loss: 35.750274658203125 ,Train accuracy: 0.265625
# Loss: 33.63159942626953 ,Train accuracy: 0.2578125
# Loss: 4.063745498657227 ,Train accuracy: 0.78125
# Loss: 1.3959296941757202 ,Train accuracy: 0.7265625
# Loss: 37.06520462036133 ,Train accuracy: 0.234375
# Loss: 40.84796142578125 ,Train accuracy: 0.21875
# Loss: 7.218008995056152 ,Train accuracy: 0.75
# Loss: 1.6677043437957764 ,Train accuracy: 0.7578125
# Loss: 39.81836700439453 ,Train accuracy: 0.2109375
# Loss: 31.09255599975586 ,Train accuracy: 0.359375
# Loss: 5.4984331130981445 ,Train accuracy: 0.6953125
# Loss: 1.605393886566162 ,Train accuracy: 0.671875
# Loss: 39.03028869628906 ,Train accuracy: 0.2265625
# Loss: 39.49637985229492 ,Train accuracy: 0.2890625
# Loss: 7.203330039978027 ,Train accuracy: 0.75
# Loss: 1.6053321361541748 ,Train accuracy: 0.671875
# Loss: 35.222198486328125 ,Train accuracy: 0.3046875
# Loss: 39.69316864013672 ,Train accuracy: 0.28125
# Loss: 4.884495735168457 ,Train accuracy: 0.734375
# Loss: 2.1131129264831543 ,Train accuracy: 0.7265625
# Loss: 45.20359420776367 ,Train accuracy: 0.2421875
# Loss: 42.93049621582031 ,Train accuracy: 0.2109375
# Loss: 6.189541816711426 ,Train accuracy: 0.7734375
# Loss: 2.8562684059143066 ,Train accuracy: 0.6875
# Loss: 37.54002380371094 ,Train accuracy: 0.359375
# Loss: 35.29817199707031 ,Train accuracy: 0.34375
# Loss: 6.735377311706543 ,Train accuracy: 0.7109375
# Loss: 2.739166021347046 ,Train accuracy: 0.75
# Loss: 39.51066970825195 ,Train accuracy: 0.2421875
# Loss: 39.068878173828125 ,Train accuracy: 0.265625
# Loss: 6.661520481109619 ,Train accuracy: 0.765625
# Loss: 1.9832515716552734 ,Train accuracy: 0.734375
# Loss: 38.820953369140625 ,Train accuracy: 0.2578125
# Loss: 43.078372955322266 ,Train accuracy: 0.2578125
# Loss: 8.49644660949707 ,Train accuracy: 0.7578125
# Loss: 2.240328311920166 ,Train accuracy: 0.7109375
# Loss: 40.492713928222656 ,Train accuracy: 0.25
# Loss: 43.46404266357422 ,Train accuracy: 0.1953125
# Loss: 7.427891254425049 ,Train accuracy: 0.734375
# Loss: 1.8991787433624268 ,Train accuracy: 0.6328125
# Loss: 42.018272399902344 ,Train accuracy: 0.296875
# Loss: 38.009925842285156 ,Train accuracy: 0.28125
# Loss: 6.647100448608398 ,Train accuracy: 0.703125
# Loss: 1.6263923645019531 ,Train accuracy: 0.71875
# Loss: 41.27085876464844 ,Train accuracy: 0.2421875
# Loss: 38.58255386352539 ,Train accuracy: 0.25
# Loss: 7.9753007888793945 ,Train accuracy: 0.734375
# Loss: 2.7666890621185303 ,Train accuracy: 0.75
# Loss: 41.139244079589844 ,Train accuracy: 0.2578125
# Loss: 42.624542236328125 ,Train accuracy: 0.2578125
# Loss: 6.716683387756348 ,Train accuracy: 0.7421875
# Loss: 2.733102321624756 ,Train accuracy: 0.7109375
# Loss: 39.367984771728516 ,Train accuracy: 0.2890625
# Loss: 47.357147216796875 ,Train accuracy: 0.203125
# Loss: 5.092013835906982 ,Train accuracy: 0.7421875

# %%
# test(model2, criterion, combined_dataloader_wo_aug123)

# %%
pred_class1, pred_class2 = get_predictions(combined_dataloader_wo_aug1234, model2)
Y_comb12 = np.append(Y1, Y2)
Y_comb1234 = np.append(Y_comb12, Y34)
Y_comb1234.shape
plt.scatter(Y_comb1234, pred_class1, label='Super Antiferromagnetic')
plt.scatter(Y_comb1234, pred_class2, label='Paramagnetic')
plt.legend()

# %%
plot_proba(np.array(Y_comb1234), np.array(pred_class1), np.array(pred_class2), 'Super Antiferromagnetic', 'Paramagnetic')

# %%
y_comb1234 = np.array([item[1] for item in combined_dataloader_wo_aug1234.dataset])
calculate_accuracy_np(np.column_stack((pred_class1, pred_class2)), y_comb1234)
# Out:
# 0.558

# %% [markdown]
# ##### FC2 initialized:

# %%
import torch
import torch.nn as nn
import torch.optim as optim

# Load your pre-trained model
model2 = ConvNet2(Nx, Ny)  # or load from saved state
pretrained_model = ConvNet2(Nx, Ny)
state_dict = torch.load("CNN_anti.pth")
pretrained_model.load_state_dict(state_dict)
model2.conv1.weight.data = pretrained_model.conv1.weight.data
model2.conv1.bias.data = pretrained_model.conv1.bias.data
model2.conv2.weight.data = pretrained_model.conv2.weight.data
model2.conv2.bias.data = pretrained_model.conv2.bias.data
model2.conv3.weight.data = pretrained_model.conv3.weight.data
model2.conv3.bias.data = pretrained_model.conv3.bias.data
####
# model2.fc1.weight.data = pretrained_model.fc1.weight.data
# model2.fc1.bias.data = pretrained_model.fc1.bias.data

model2.fc2.weight.data = pretrained_model.fc2.weight.data
model2.fc2.bias.data = pretrained_model.fc2.bias.data

# Freeze all parameters in the model first
for param in model2.parameters():
    param.requires_grad = False

# Unfreeze the layers that you want to train (fc1 and fc2)
model2.fc1.weight.requires_grad = True
model2.fc1.bias.requires_grad = True
model2.fc2.weight.requires_grad = True
model2.fc2.bias.requires_grad = True
# model2.conv2.weight.requires_grad = True
# model2.conv2.bias.requires_grad = True
# model2.conv3.weight.requires_grad = True
# model2.conv3.bias.requires_grad = True

model2.to(device)

# Setup optimizer - only optimize the unfrozen parameters
optimizer = optim.Adam([
    {'params': model2.fc1.parameters()},
    {'params': model2.fc2.parameters()}
], lr=1e-5/3, betas=[0.9,0.999])
# optimizer = optim.Adam(model.parameters(), lr=1e-4, betas=[0.9,0.999])

# Define the loss function
criterion = nn.BCELoss()


# Example usage of the training function with dataloader8
train(model2, num_epochs=70, criterion=criterion, optimizer=optimizer, train_dataloader=combined_dataloader_wo_aug1234)
# Out:
# Loss: 0.5062700510025024 ,Train accuracy: 0.9921875
# Loss: 1.1867932081222534 ,Train accuracy: 0.0546875
# Loss: 0.7735477685928345 ,Train accuracy: 0.40625
# Loss: 0.7219667434692383 ,Train accuracy: 0.4453125
# Loss: 0.5950598120689392 ,Train accuracy: 0.921875
# Loss: 0.9013221263885498 ,Train accuracy: 0.2109375
# Loss: 0.6648874878883362 ,Train accuracy: 0.640625
# Loss: 0.7592564225196838 ,Train accuracy: 0.390625
# Loss: 0.6206308603286743 ,Train accuracy: 0.8359375
# Loss: 0.9252510070800781 ,Train accuracy: 0.1640625
# Loss: 0.7077924013137817 ,Train accuracy: 0.5
# Loss: 0.7433850169181824 ,Train accuracy: 0.3515625
# Loss: 0.61122727394104 ,Train accuracy: 0.9296875
# Loss: 0.9026467800140381 ,Train accuracy: 0.171875
# Loss: 0.6752005815505981 ,Train accuracy: 0.6015625
# Loss: 0.7286418676376343 ,Train accuracy: 0.3984375
# Loss: 0.6207410097122192 ,Train accuracy: 0.8984375
# Loss: 0.8594921827316284 ,Train accuracy: 0.21875
# Loss: 0.6550908088684082 ,Train accuracy: 0.6328125
# Loss: 0.7447348833084106 ,Train accuracy: 0.3984375
# Loss: 0.6192349195480347 ,Train accuracy: 0.8984375
# Loss: 0.8760135173797607 ,Train accuracy: 0.171875
# Loss: 0.67190021276474 ,Train accuracy: 0.6015625
# Loss: 0.7262420654296875 ,Train accuracy: 0.3984375
# Loss: 0.6130067110061646 ,Train accuracy: 0.921875
# Loss: 0.8513387441635132 ,Train accuracy: 0.171875
# Loss: 0.6669832468032837 ,Train accuracy: 0.5703125
# Loss: 0.741911768913269 ,Train accuracy: 0.390625
# Loss: 0.6142019033432007 ,Train accuracy: 0.953125
# Loss: 0.8520232439041138 ,Train accuracy: 0.1484375
# Loss: 0.6557000875473022 ,Train accuracy: 0.6640625
# Loss: 0.7296411991119385 ,Train accuracy: 0.40625
# Loss: 0.6097160577774048 ,Train accuracy: 0.9765625
# Loss: 0.8655201196670532 ,Train accuracy: 0.1171875
# Loss: 0.6695733070373535 ,Train accuracy: 0.6015625
# Loss: 0.7240419387817383 ,Train accuracy: 0.390625
# Loss: 0.6137410998344421 ,Train accuracy: 0.9765625
# Loss: 0.8370702266693115 ,Train accuracy: 0.1171875
# Loss: 0.6635348796844482 ,Train accuracy: 0.6328125
# Loss: 0.7385193705558777 ,Train accuracy: 0.3125
# Loss: 0.6177835464477539 ,Train accuracy: 0.9765625
# Loss: 0.8557515144348145 ,Train accuracy: 0.0859375
# Loss: 0.6628807783126831 ,Train accuracy: 0.59375
# Loss: 0.7306622862815857 ,Train accuracy: 0.3515625
# Loss: 0.6115257143974304 ,Train accuracy: 1.0
# Loss: 0.8473330736160278 ,Train accuracy: 0.0859375
# Loss: 0.6523247957229614 ,Train accuracy: 0.6796875
# Loss: 0.7252182364463806 ,Train accuracy: 0.3125
# Loss: 0.605237603187561 ,Train accuracy: 1.0
# Loss: 0.8467925786972046 ,Train accuracy: 0.0703125
# Loss: 0.6757258176803589 ,Train accuracy: 0.6171875
# Loss: 0.7224376797676086 ,Train accuracy: 0.2734375
# Loss: 0.6075409650802612 ,Train accuracy: 1.0
# Loss: 0.8555149435997009 ,Train accuracy: 0.0390625
# Loss: 0.6615976095199585 ,Train accuracy: 0.671875
# Loss: 0.714792013168335 ,Train accuracy: 0.3828125
# Loss: 0.6133121252059937 ,Train accuracy: 1.0
# Loss: 0.8479336500167847 ,Train accuracy: 0.0546875
# Loss: 0.6776846647262573 ,Train accuracy: 0.6015625
# Loss: 0.7145143747329712 ,Train accuracy: 0.390625
# Loss: 0.6119588613510132 ,Train accuracy: 1.0
# Loss: 0.8333886861801147 ,Train accuracy: 0.0234375
# Loss: 0.6482192277908325 ,Train accuracy: 0.75
# Loss: 0.714789867401123 ,Train accuracy: 0.3828125
# Loss: 0.6045386791229248 ,Train accuracy: 1.0
# Loss: 0.8289782404899597 ,Train accuracy: 0.03125
# Loss: 0.6491937637329102 ,Train accuracy: 0.7265625
# Loss: 0.7065622806549072 ,Train accuracy: 0.4375
# Loss: 0.6096553802490234 ,Train accuracy: 1.0
# Loss: 0.8322643041610718 ,Train accuracy: 0.046875
# Loss: 0.6559375524520874 ,Train accuracy: 0.65625
# Loss: 0.7112565040588379 ,Train accuracy: 0.3828125
# Loss: 0.6087828874588013 ,Train accuracy: 1.0
# Loss: 0.827075719833374 ,Train accuracy: 0.03125
# Loss: 0.6545259952545166 ,Train accuracy: 0.71875
# Loss: 0.70733642578125 ,Train accuracy: 0.3984375
# Loss: 0.6062979698181152 ,Train accuracy: 1.0
# Loss: 0.8207723498344421 ,Train accuracy: 0.0078125
# Loss: 0.6650404930114746 ,Train accuracy: 0.640625
# Loss: 0.6972902417182922 ,Train accuracy: 0.46875
# Loss: 0.6059209108352661 ,Train accuracy: 1.0
# Loss: 0.8171558380126953 ,Train accuracy: 0.0234375
# Loss: 0.6496052145957947 ,Train accuracy: 0.7109375
# Loss: 0.705229640007019 ,Train accuracy: 0.3984375
# Loss: 0.6083855032920837 ,Train accuracy: 1.0
# Loss: 0.8180522918701172 ,Train accuracy: 0.015625
# Loss: 0.6467508673667908 ,Train accuracy: 0.765625
# Loss: 0.7005607485771179 ,Train accuracy: 0.40625
# Loss: 0.6112103462219238 ,Train accuracy: 1.0
# Loss: 0.835978090763092 ,Train accuracy: 0.015625
# Loss: 0.6574361324310303 ,Train accuracy: 0.6875
# Loss: 0.6990309953689575 ,Train accuracy: 0.4296875
# Loss: 0.6073763966560364 ,Train accuracy: 1.0
# Loss: 0.8099226355552673 ,Train accuracy: 0.0390625
# Loss: 0.6611977815628052 ,Train accuracy: 0.6875
# Loss: 0.6975423097610474 ,Train accuracy: 0.4765625
# Loss: 0.6078792214393616 ,Train accuracy: 1.0
# Loss: 0.8239350318908691 ,Train accuracy: 0.0546875
# Loss: 0.655025839805603 ,Train accuracy: 0.7265625
# Loss: 0.6947012543678284 ,Train accuracy: 0.4765625
# Loss: 0.601294755935669 ,Train accuracy: 1.0
# Loss: 0.8285298347473145 ,Train accuracy: 0.0
# Loss: 0.653668999671936 ,Train accuracy: 0.71875
# Loss: 0.6925958395004272 ,Train accuracy: 0.5234375
# Loss: 0.6085241436958313 ,Train accuracy: 1.0
# Loss: 0.8274344205856323 ,Train accuracy: 0.0
# Loss: 0.6621750593185425 ,Train accuracy: 0.7421875
# Loss: 0.6844354867935181 ,Train accuracy: 0.5859375
# Loss: 0.6074907779693604 ,Train accuracy: 1.0
# Loss: 0.8278459906578064 ,Train accuracy: 0.0078125
# Loss: 0.6547421216964722 ,Train accuracy: 0.71875
# Loss: 0.6866240501403809 ,Train accuracy: 0.5703125
# Loss: 0.6068448424339294 ,Train accuracy: 1.0
# Loss: 0.8260788917541504 ,Train accuracy: 0.0390625
# Loss: 0.6487666368484497 ,Train accuracy: 0.7890625
# Loss: 0.6790057420730591 ,Train accuracy: 0.59375
# Loss: 0.6047406196594238 ,Train accuracy: 1.0
# Loss: 0.8302990198135376 ,Train accuracy: 0.015625
# Loss: 0.6561451554298401 ,Train accuracy: 0.7265625
# Loss: 0.6844748258590698 ,Train accuracy: 0.5703125
# Loss: 0.6047074198722839 ,Train accuracy: 1.0
# Loss: 0.8188568353652954 ,Train accuracy: 0.0390625
# Loss: 0.6445599794387817 ,Train accuracy: 0.7890625
# Loss: 0.6801164150238037 ,Train accuracy: 0.6171875
# Loss: 0.6037790775299072 ,Train accuracy: 1.0
# Loss: 0.8138749003410339 ,Train accuracy: 0.0390625
# Loss: 0.6511744856834412 ,Train accuracy: 0.8046875
# Loss: 0.6822813749313354 ,Train accuracy: 0.59375
# Loss: 0.6032288670539856 ,Train accuracy: 1.0
# Loss: 0.8207592368125916 ,Train accuracy: 0.03125
# Loss: 0.6476267576217651 ,Train accuracy: 0.78125
# Loss: 0.6805281639099121 ,Train accuracy: 0.578125
# Loss: 0.6022659540176392 ,Train accuracy: 1.0
# Loss: 0.8177943229675293 ,Train accuracy: 0.0390625
# Loss: 0.6548470854759216 ,Train accuracy: 0.78125
# Loss: 0.6715776324272156 ,Train accuracy: 0.6875
# Loss: 0.6035330295562744 ,Train accuracy: 1.0
# Loss: 0.823805570602417 ,Train accuracy: 0.0078125
# Loss: 0.6547343134880066 ,Train accuracy: 0.8046875
# Loss: 0.6802412867546082 ,Train accuracy: 0.5859375
# Loss: 0.5972513556480408 ,Train accuracy: 1.0
# Loss: 0.8300842642784119 ,Train accuracy: 0.0234375
# Loss: 0.6391831636428833 ,Train accuracy: 0.78125
# Loss: 0.6704994440078735 ,Train accuracy: 0.6640625
# Loss: 0.5980798006057739 ,Train accuracy: 1.0
# Loss: 0.8373315930366516 ,Train accuracy: 0.046875
# Loss: 0.6432497501373291 ,Train accuracy: 0.8046875
# Loss: 0.6646777391433716 ,Train accuracy: 0.7734375
# Loss: 0.5990308523178101 ,Train accuracy: 1.0
# Loss: 0.8236366510391235 ,Train accuracy: 0.0234375
# Loss: 0.6482154130935669 ,Train accuracy: 0.7890625
# Loss: 0.665854811668396 ,Train accuracy: 0.6953125
# Loss: 0.6020644903182983 ,Train accuracy: 1.0
# Loss: 0.8252107501029968 ,Train accuracy: 0.015625
# Loss: 0.640188992023468 ,Train accuracy: 0.8046875
# Loss: 0.670515775680542 ,Train accuracy: 0.7109375
# Loss: 0.6013447046279907 ,Train accuracy: 1.0
# Loss: 0.8218346834182739 ,Train accuracy: 0.015625
# Loss: 0.6438207030296326 ,Train accuracy: 0.7890625
# Loss: 0.6713083386421204 ,Train accuracy: 0.734375
# Loss: 0.6015546321868896 ,Train accuracy: 1.0
# Loss: 0.8120228052139282 ,Train accuracy: 0.03125
# Loss: 0.6381429433822632 ,Train accuracy: 0.828125
# Loss: 0.6697454452514648 ,Train accuracy: 0.6796875
# Loss: 0.6008211970329285 ,Train accuracy: 1.0
# Loss: 0.8183876872062683 ,Train accuracy: 0.015625
# Loss: 0.6462955474853516 ,Train accuracy: 0.765625
# Loss: 0.6706400513648987 ,Train accuracy: 0.671875
# Loss: 0.6012024879455566 ,Train accuracy: 1.0
# Loss: 0.8302819132804871 ,Train accuracy: 0.03125
# Loss: 0.6435956954956055 ,Train accuracy: 0.7734375
# Loss: 0.6594796776771545 ,Train accuracy: 0.71875
# Loss: 0.5963009595870972 ,Train accuracy: 1.0
# Loss: 0.8237637877464294 ,Train accuracy: 0.0
# Loss: 0.6498662829399109 ,Train accuracy: 0.75
# Loss: 0.6588956713676453 ,Train accuracy: 0.75
# Loss: 0.5963974595069885 ,Train accuracy: 1.0
# Loss: 0.824643611907959 ,Train accuracy: 0.0078125
# Loss: 0.6455525159835815 ,Train accuracy: 0.7890625
# Loss: 0.6653343439102173 ,Train accuracy: 0.71875
# Loss: 0.594710111618042 ,Train accuracy: 1.0
# Loss: 0.823544979095459 ,Train accuracy: 0.015625
# Loss: 0.647343635559082 ,Train accuracy: 0.8125
# Loss: 0.6616652607917786 ,Train accuracy: 0.7421875
# Loss: 0.6016750335693359 ,Train accuracy: 1.0
# Loss: 0.8106635808944702 ,Train accuracy: 0.0390625
# Loss: 0.6498792171478271 ,Train accuracy: 0.765625
# Loss: 0.6529353857040405 ,Train accuracy: 0.78125
# Loss: 0.5974607467651367 ,Train accuracy: 1.0
# Loss: 0.8143833875656128 ,Train accuracy: 0.03125
# Loss: 0.6452944278717041 ,Train accuracy: 0.7890625
# Loss: 0.6578677892684937 ,Train accuracy: 0.8125
# Loss: 0.5999681949615479 ,Train accuracy: 1.0
# Loss: 0.8060312271118164 ,Train accuracy: 0.03125
# Loss: 0.629770040512085 ,Train accuracy: 0.875
# Loss: 0.6618613600730896 ,Train accuracy: 0.7265625
# Loss: 0.5968894958496094 ,Train accuracy: 1.0
# Loss: 0.8054632544517517 ,Train accuracy: 0.046875
# Loss: 0.6349431276321411 ,Train accuracy: 0.7890625
# Loss: 0.6550588011741638 ,Train accuracy: 0.7734375
# Loss: 0.5968112349510193 ,Train accuracy: 1.0
# Loss: 0.8079143762588501 ,Train accuracy: 0.0390625
# Loss: 0.6379022598266602 ,Train accuracy: 0.828125
# Loss: 0.6552119851112366 ,Train accuracy: 0.765625
# Loss: 0.5993244647979736 ,Train accuracy: 1.0
# Loss: 0.8190181255340576 ,Train accuracy: 0.015625
# Loss: 0.648910641670227 ,Train accuracy: 0.7578125
# Loss: 0.6596337556838989 ,Train accuracy: 0.7890625
# Loss: 0.59829181432724 ,Train accuracy: 1.0
# Loss: 0.8161730766296387 ,Train accuracy: 0.046875
# Loss: 0.6367840766906738 ,Train accuracy: 0.859375
# Loss: 0.6519308090209961 ,Train accuracy: 0.7890625
# Loss: 0.6010937690734863 ,Train accuracy: 1.0
# Loss: 0.8105048537254333 ,Train accuracy: 0.0234375
# Loss: 0.6322561502456665 ,Train accuracy: 0.875
# Loss: 0.6574602127075195 ,Train accuracy: 0.7734375
# Loss: 0.6001671552658081 ,Train accuracy: 1.0
# Loss: 0.8062154650688171 ,Train accuracy: 0.0390625
# Loss: 0.6354267597198486 ,Train accuracy: 0.828125
# Loss: 0.6465490460395813 ,Train accuracy: 0.8046875
# Loss: 0.596622109413147 ,Train accuracy: 1.0
# Loss: 0.819746732711792 ,Train accuracy: 0.0234375
# Loss: 0.6377406120300293 ,Train accuracy: 0.8046875
# Loss: 0.653363823890686 ,Train accuracy: 0.78125
# Loss: 0.5954210162162781 ,Train accuracy: 1.0
# Loss: 0.8130971193313599 ,Train accuracy: 0.0234375
# Loss: 0.6233046054840088 ,Train accuracy: 0.8984375
# Loss: 0.6550850868225098 ,Train accuracy: 0.7734375
# Loss: 0.5961164236068726 ,Train accuracy: 1.0
# Loss: 0.8134787082672119 ,Train accuracy: 0.0625
# Loss: 0.6408789157867432 ,Train accuracy: 0.7890625
# Loss: 0.6412109136581421 ,Train accuracy: 0.859375
# Loss: 0.5941128730773926 ,Train accuracy: 1.0
# Loss: 0.8019535541534424 ,Train accuracy: 0.015625
# Loss: 0.6219772100448608 ,Train accuracy: 0.8828125
# Loss: 0.6516491770744324 ,Train accuracy: 0.8046875
# Loss: 0.5916273593902588 ,Train accuracy: 1.0
# Loss: 0.8022992610931396 ,Train accuracy: 0.09375
# Loss: 0.6292992830276489 ,Train accuracy: 0.84375
# Loss: 0.6423963904380798 ,Train accuracy: 0.8671875
# Loss: 0.5918563604354858 ,Train accuracy: 1.0
# Loss: 0.8175338506698608 ,Train accuracy: 0.03125
# Loss: 0.6222212314605713 ,Train accuracy: 0.90625
# Loss: 0.6390097737312317 ,Train accuracy: 0.8359375
# Loss: 0.5948292016983032 ,Train accuracy: 1.0
# Loss: 0.8095227479934692 ,Train accuracy: 0.0546875
# Loss: 0.6282526850700378 ,Train accuracy: 0.8125
# Loss: 0.6432352066040039 ,Train accuracy: 0.828125
# Loss: 0.592927098274231 ,Train accuracy: 1.0
# Loss: 0.7999918460845947 ,Train accuracy: 0.0546875
# Loss: 0.62467360496521 ,Train accuracy: 0.90625
# Loss: 0.6376463770866394 ,Train accuracy: 0.8828125
# Loss: 0.5889624953269958 ,Train accuracy: 1.0
# Loss: 0.8052691221237183 ,Train accuracy: 0.0390625
# Loss: 0.6311204433441162 ,Train accuracy: 0.84375
# Loss: 0.6391845345497131 ,Train accuracy: 0.890625
# Loss: 0.5917463898658752 ,Train accuracy: 1.0
# Loss: 0.8071311712265015 ,Train accuracy: 0.0390625
# Loss: 0.6392290592193604 ,Train accuracy: 0.796875
# Loss: 0.6319952607154846 ,Train accuracy: 0.890625
# Loss: 0.5901705026626587 ,Train accuracy: 1.0
# Loss: 0.806609034538269 ,Train accuracy: 0.03125
# Loss: 0.6277987957000732 ,Train accuracy: 0.8359375
# Loss: 0.6291587352752686 ,Train accuracy: 0.90625
# Loss: 0.5930010676383972 ,Train accuracy: 1.0
# Loss: 0.8012641072273254 ,Train accuracy: 0.03125
# Loss: 0.6335658431053162 ,Train accuracy: 0.8359375
# Loss: 0.6416443586349487 ,Train accuracy: 0.828125
# Loss: 0.5924971103668213 ,Train accuracy: 1.0
# Loss: 0.8019542694091797 ,Train accuracy: 0.0546875
# Loss: 0.6326517462730408 ,Train accuracy: 0.8359375
# Loss: 0.636672854423523 ,Train accuracy: 0.8671875
# Loss: 0.5900454521179199 ,Train accuracy: 1.0
# Loss: 0.8030029535293579 ,Train accuracy: 0.046875
# Loss: 0.6281040906906128 ,Train accuracy: 0.8203125
# Loss: 0.6369181275367737 ,Train accuracy: 0.890625
# Loss: 0.5913305878639221 ,Train accuracy: 1.0
# Loss: 0.7977522611618042 ,Train accuracy: 0.0625
# Loss: 0.6190110445022583 ,Train accuracy: 0.859375
# Loss: 0.6360095739364624 ,Train accuracy: 0.859375

# %%
# test(model2, criterion, combined_dataloader_wo_aug123)

# %%
pred_class1, pred_class2 = get_predictions(combined_dataloader_wo_aug1234, model2)
Y_comb12 = np.append(Y1, Y2)
Y_comb1234 = np.append(Y_comb12, Y34)
Y_comb1234.shape
plt.scatter(Y_comb1234, pred_class1, label='Super Antiferromagnetic')
plt.scatter(Y_comb1234, pred_class2, label='Paramagnetic')
plt.legend()

# %%
plot_proba(np.array(Y_comb1234), np.array(pred_class1), np.array(pred_class2), 'Super Antiferromagnetic', 'Paramagnetic')

# %%
y_comb1234 = np.array([item[1] for item in combined_dataloader_wo_aug1234.dataset])
calculate_accuracy_np(np.column_stack((pred_class1, pred_class2)), y_comb1234)
# Out:
# 0.748

# %% [markdown]
# ##### Both weights initialized:

# %%
import torch
import torch.nn as nn
import torch.optim as optim

# Load your pre-trained model
model2 = ConvNet2(Nx, Ny)  # or load from saved state
pretrained_model = ConvNet2(Nx, Ny)
state_dict = torch.load("CNN_anti.pth")
pretrained_model.load_state_dict(state_dict)
model2.conv1.weight.data = pretrained_model.conv1.weight.data
model2.conv1.bias.data = pretrained_model.conv1.bias.data
model2.conv2.weight.data = pretrained_model.conv2.weight.data
model2.conv2.bias.data = pretrained_model.conv2.bias.data
model2.conv3.weight.data = pretrained_model.conv3.weight.data
model2.conv3.bias.data = pretrained_model.conv3.bias.data
####
model2.fc1.weight.data = pretrained_model.fc1.weight.data
model2.fc1.bias.data = pretrained_model.fc1.bias.data

model2.fc2.weight.data = pretrained_model.fc2.weight.data
model2.fc2.bias.data = pretrained_model.fc2.bias.data

# Freeze all parameters in the model first
for param in model2.parameters():
    param.requires_grad = False

# Unfreeze the layers that you want to train (fc1 and fc2)
model2.fc1.weight.requires_grad = True
model2.fc1.bias.requires_grad = True
model2.fc2.weight.requires_grad = True
model2.fc2.bias.requires_grad = True
# model2.conv2.weight.requires_grad = True
# model2.conv2.bias.requires_grad = True
# model2.conv3.weight.requires_grad = True
# model2.conv3.bias.requires_grad = True

model2.to(device)

# Setup optimizer - only optimize the unfrozen parameters
optimizer = optim.Adam([
    {'params': model2.fc1.parameters()},
    {'params': model2.fc2.parameters()}
], lr=1e-5, betas=[0.9,0.999])
# optimizer = optim.Adam(model.parameters(), lr=1e-4, betas=[0.9,0.999])

# Define the loss function
criterion = nn.BCELoss()


# Example usage of the training function with dataloader8
train(model2, num_epochs=50, criterion=criterion, optimizer=optimizer, train_dataloader=combined_dataloader_wo_aug1234)
# Out:
# Loss: 16.381052017211914 ,Train accuracy: 0.0
# Loss: 1.912575792184512e-10 ,Train accuracy: 1.0
# Loss: 3.5055245461990125e-07 ,Train accuracy: 1.0
# Loss: 58.75845718383789 ,Train accuracy: 0.0
# Loss: 11.420127868652344 ,Train accuracy: 0.0
# Loss: 5.454712592722899e-08 ,Train accuracy: 1.0
# Loss: 1.7557391629452468e-07 ,Train accuracy: 1.0
# Loss: 55.37006378173828 ,Train accuracy: 0.0
# Loss: 9.237685203552246 ,Train accuracy: 0.0
# Loss: 1.3476367257680977e-06 ,Train accuracy: 1.0
# Loss: 2.0384179322263662e-07 ,Train accuracy: 1.0
# Loss: 40.89344787597656 ,Train accuracy: 0.0
# Loss: 7.355626106262207 ,Train accuracy: 0.0
# Loss: 1.5650766727048904e-06 ,Train accuracy: 1.0
# Loss: 1.129943143496348e-06 ,Train accuracy: 1.0
# Loss: 26.180572509765625 ,Train accuracy: 0.0
# Loss: 5.39231014251709 ,Train accuracy: 0.0
# Loss: 0.00031172711169347167 ,Train accuracy: 1.0
# Loss: 0.0005997316329739988 ,Train accuracy: 1.0
# Loss: 14.727703094482422 ,Train accuracy: 0.0
# Loss: 4.651775360107422 ,Train accuracy: 0.0
# Loss: 0.0024616557639092207 ,Train accuracy: 1.0
# Loss: 0.0019471675623208284 ,Train accuracy: 1.0
# Loss: 10.694778442382812 ,Train accuracy: 0.0
# Loss: 4.3261823654174805 ,Train accuracy: 0.0
# Loss: 0.006457563955336809 ,Train accuracy: 1.0
# Loss: 0.00305358087643981 ,Train accuracy: 1.0
# Loss: 11.001238822937012 ,Train accuracy: 0.0
# Loss: 4.078917503356934 ,Train accuracy: 0.0
# Loss: 0.0010928204283118248 ,Train accuracy: 1.0
# Loss: 0.015050694346427917 ,Train accuracy: 0.9921875
# Loss: 10.460395812988281 ,Train accuracy: 0.0
# Loss: 3.8013617992401123 ,Train accuracy: 0.0
# Loss: 0.011078128591179848 ,Train accuracy: 1.0
# Loss: 0.007741812616586685 ,Train accuracy: 1.0
# Loss: 8.546343803405762 ,Train accuracy: 0.0
# Loss: 3.7518296241760254 ,Train accuracy: 0.0
# Loss: 0.012086931616067886 ,Train accuracy: 1.0
# Loss: 0.006450599990785122 ,Train accuracy: 1.0
# Loss: 9.348073959350586 ,Train accuracy: 0.0
# Loss: 3.8155083656311035 ,Train accuracy: 0.015625
# Loss: 0.027888484299182892 ,Train accuracy: 1.0
# Loss: 0.014958515763282776 ,Train accuracy: 0.9921875
# Loss: 8.56513786315918 ,Train accuracy: 0.0
# Loss: 3.846072196960449 ,Train accuracy: 0.0078125
# Loss: 0.021175678819417953 ,Train accuracy: 0.9921875
# Loss: 0.013314937241375446 ,Train accuracy: 0.9921875
# Loss: 8.10788345336914 ,Train accuracy: 0.0
# Loss: 3.613844871520996 ,Train accuracy: 0.0
# Loss: 0.032640308141708374 ,Train accuracy: 0.9921875
# Loss: 0.01113043911755085 ,Train accuracy: 1.0
# Loss: 8.040730476379395 ,Train accuracy: 0.0
# Loss: 3.608247756958008 ,Train accuracy: 0.0078125
# Loss: 0.03418533504009247 ,Train accuracy: 0.9921875
# Loss: 0.010887570679187775 ,Train accuracy: 1.0
# Loss: 7.956557750701904 ,Train accuracy: 0.0
# Loss: 3.7765259742736816 ,Train accuracy: 0.015625
# Loss: 0.016883287578821182 ,Train accuracy: 1.0
# Loss: 0.0334017314016819 ,Train accuracy: 0.9921875
# Loss: 7.691446781158447 ,Train accuracy: 0.0078125
# Loss: 3.611300468444824 ,Train accuracy: 0.0234375
# Loss: 0.021462664008140564 ,Train accuracy: 1.0
# Loss: 0.029089435935020447 ,Train accuracy: 0.984375
# Loss: 8.024076461791992 ,Train accuracy: 0.0
# Loss: 3.611891984939575 ,Train accuracy: 0.0078125
# Loss: 0.019418641924858093 ,Train accuracy: 0.9921875
# Loss: 0.02217736840248108 ,Train accuracy: 1.0
# Loss: 8.417766571044922 ,Train accuracy: 0.0
# Loss: 3.3489012718200684 ,Train accuracy: 0.0
# Loss: 0.024833451956510544 ,Train accuracy: 1.0
# Loss: 0.03626649081707001 ,Train accuracy: 0.984375
# Loss: 8.012089729309082 ,Train accuracy: 0.0078125
# Loss: 3.1935555934906006 ,Train accuracy: 0.015625
# Loss: 0.033049799501895905 ,Train accuracy: 1.0
# Loss: 0.020085368305444717 ,Train accuracy: 0.9921875
# Loss: 7.401329040527344 ,Train accuracy: 0.0078125
# Loss: 3.292754888534546 ,Train accuracy: 0.0234375
# Loss: 0.026571551337838173 ,Train accuracy: 1.0
# Loss: 0.04130890592932701 ,Train accuracy: 1.0
# Loss: 7.783333778381348 ,Train accuracy: 0.0234375
# Loss: 3.331531047821045 ,Train accuracy: 0.015625
# Loss: 0.03623151034116745 ,Train accuracy: 0.984375
# Loss: 0.02695518732070923 ,Train accuracy: 0.9921875
# Loss: 7.632730007171631 ,Train accuracy: 0.0078125
# Loss: 3.5586013793945312 ,Train accuracy: 0.0234375
# Loss: 0.05399966984987259 ,Train accuracy: 1.0
# Loss: 0.07222281396389008 ,Train accuracy: 0.96875
# Loss: 7.1847825050354 ,Train accuracy: 0.046875
# Loss: 3.1673057079315186 ,Train accuracy: 0.03125
# Loss: 0.04259643703699112 ,Train accuracy: 0.984375
# Loss: 0.06738007813692093 ,Train accuracy: 0.96875
# Loss: 7.281498908996582 ,Train accuracy: 0.03125
# Loss: 3.283926486968994 ,Train accuracy: 0.03125
# Loss: 0.040637992322444916 ,Train accuracy: 0.9921875
# Loss: 0.04138658940792084 ,Train accuracy: 0.984375
# Loss: 7.195377349853516 ,Train accuracy: 0.046875
# Loss: 3.110678195953369 ,Train accuracy: 0.0546875
# Loss: 0.04058140143752098 ,Train accuracy: 0.984375
# Loss: 0.06993725150823593 ,Train accuracy: 0.953125
# Loss: 7.5131120681762695 ,Train accuracy: 0.015625
# Loss: 3.1327009201049805 ,Train accuracy: 0.0546875
# Loss: 0.041928425431251526 ,Train accuracy: 0.984375
# Loss: 0.0379519946873188 ,Train accuracy: 0.984375
# Loss: 6.896877288818359 ,Train accuracy: 0.03125
# Loss: 3.005258560180664 ,Train accuracy: 0.078125
# Loss: 0.06613484770059586 ,Train accuracy: 0.9609375
# Loss: 0.052886929363012314 ,Train accuracy: 0.96875
# Loss: 7.06715726852417 ,Train accuracy: 0.0234375
# Loss: 2.9548816680908203 ,Train accuracy: 0.0859375
# Loss: 0.04607366397976875 ,Train accuracy: 0.96875
# Loss: 0.04015830159187317 ,Train accuracy: 0.96875
# Loss: 6.808377742767334 ,Train accuracy: 0.015625
# Loss: 2.926828384399414 ,Train accuracy: 0.078125
# Loss: 0.0577738881111145 ,Train accuracy: 0.953125
# Loss: 0.02327665500342846 ,Train accuracy: 0.9921875
# Loss: 6.408785820007324 ,Train accuracy: 0.0234375
# Loss: 2.8945388793945312 ,Train accuracy: 0.0859375
# Loss: 0.05414285510778427 ,Train accuracy: 0.9765625
# Loss: 0.06222943961620331 ,Train accuracy: 0.953125
# Loss: 6.704049587249756 ,Train accuracy: 0.0390625
# Loss: 2.847963809967041 ,Train accuracy: 0.078125
# Loss: 0.061737850308418274 ,Train accuracy: 0.9609375
# Loss: 0.055938731878995895 ,Train accuracy: 0.9609375
# Loss: 6.634191513061523 ,Train accuracy: 0.046875
# Loss: 2.67673397064209 ,Train accuracy: 0.109375
# Loss: 0.07680344581604004 ,Train accuracy: 0.9453125
# Loss: 0.04711426794528961 ,Train accuracy: 0.96875
# Loss: 5.861233234405518 ,Train accuracy: 0.0390625
# Loss: 2.9329445362091064 ,Train accuracy: 0.046875
# Loss: 0.053218334913253784 ,Train accuracy: 0.953125
# Loss: 0.05623602494597435 ,Train accuracy: 0.96875
# Loss: 6.486603260040283 ,Train accuracy: 0.03125
# Loss: 2.7932589054107666 ,Train accuracy: 0.0546875
# Loss: 0.03792110085487366 ,Train accuracy: 0.9609375
# Loss: 0.08145099878311157 ,Train accuracy: 0.9296875
# Loss: 6.012499809265137 ,Train accuracy: 0.03125
# Loss: 2.7334136962890625 ,Train accuracy: 0.0625
# Loss: 0.04914824664592743 ,Train accuracy: 0.9609375
# Loss: 0.037171803414821625 ,Train accuracy: 0.9765625
# Loss: 6.1051530838012695 ,Train accuracy: 0.0390625
# Loss: 2.577768087387085 ,Train accuracy: 0.0625
# Loss: 0.043522581458091736 ,Train accuracy: 0.96875
# Loss: 0.041506025940179825 ,Train accuracy: 0.984375
# Loss: 5.546567440032959 ,Train accuracy: 0.0390625
# Loss: 2.548065185546875 ,Train accuracy: 0.0546875
# Loss: 0.05805904418230057 ,Train accuracy: 0.96875
# Loss: 0.04683498293161392 ,Train accuracy: 0.953125
# Loss: 5.985616683959961 ,Train accuracy: 0.0390625
# Loss: 2.438328266143799 ,Train accuracy: 0.09375
# Loss: 0.04326499626040459 ,Train accuracy: 0.96875
# Loss: 0.04124712944030762 ,Train accuracy: 0.9609375
# Loss: 5.670916557312012 ,Train accuracy: 0.0625
# Loss: 2.501910448074341 ,Train accuracy: 0.0625
# Loss: 0.0345001146197319 ,Train accuracy: 0.984375
# Loss: 0.06947839260101318 ,Train accuracy: 0.96875
# Loss: 5.655325412750244 ,Train accuracy: 0.0234375
# Loss: 2.5179810523986816 ,Train accuracy: 0.0625
# Loss: 0.05842021107673645 ,Train accuracy: 0.9609375
# Loss: 0.062387824058532715 ,Train accuracy: 0.9609375
# Loss: 5.412221908569336 ,Train accuracy: 0.0625
# Loss: 2.4521405696868896 ,Train accuracy: 0.0703125
# Loss: 0.05479918420314789 ,Train accuracy: 0.96875
# Loss: 0.06233209744095802 ,Train accuracy: 0.9609375
# Loss: 5.370067596435547 ,Train accuracy: 0.0390625
# Loss: 2.307042360305786 ,Train accuracy: 0.0703125
# Loss: 0.07899518311023712 ,Train accuracy: 0.9609375
# Loss: 0.04386230930685997 ,Train accuracy: 0.984375
# Loss: 5.235788345336914 ,Train accuracy: 0.0546875
# Loss: 2.312164783477783 ,Train accuracy: 0.078125
# Loss: 0.04036957025527954 ,Train accuracy: 0.9765625
# Loss: 0.030084097757935524 ,Train accuracy: 0.9921875
# Loss: 4.820121765136719 ,Train accuracy: 0.0703125
# Loss: 2.337406873703003 ,Train accuracy: 0.0390625
# Loss: 0.04277341067790985 ,Train accuracy: 0.984375
# Loss: 0.06280592083930969 ,Train accuracy: 0.984375
# Loss: 5.012187957763672 ,Train accuracy: 0.078125
# Loss: 2.333873748779297 ,Train accuracy: 0.046875
# Loss: 0.047800831496715546 ,Train accuracy: 0.96875
# Loss: 0.05518414452672005 ,Train accuracy: 0.9765625
# Loss: 5.029719352722168 ,Train accuracy: 0.0234375
# Loss: 2.2256271839141846 ,Train accuracy: 0.0703125
# Loss: 0.05390714854001999 ,Train accuracy: 0.953125
# Loss: 0.04424978792667389 ,Train accuracy: 0.9765625
# Loss: 4.597977638244629 ,Train accuracy: 0.03125
# Loss: 2.1038167476654053 ,Train accuracy: 0.0859375
# Loss: 0.06528960913419724 ,Train accuracy: 0.9609375
# Loss: 0.04604949429631233 ,Train accuracy: 0.9765625
# Loss: 4.889700889587402 ,Train accuracy: 0.0390625
# Loss: 2.1491751670837402 ,Train accuracy: 0.1015625
# Loss: 0.06823717802762985 ,Train accuracy: 0.953125
# Loss: 0.03607228025794029 ,Train accuracy: 0.9765625
# Loss: 4.366887092590332 ,Train accuracy: 0.0390625
# Loss: 2.063520908355713 ,Train accuracy: 0.0390625
# Loss: 0.0538463220000267 ,Train accuracy: 0.9921875
# Loss: 0.037337906658649445 ,Train accuracy: 0.9765625
# Loss: 4.345698356628418 ,Train accuracy: 0.03125
# Loss: 2.2069501876831055 ,Train accuracy: 0.03125
# Loss: 0.0706544816493988 ,Train accuracy: 0.96875
# Loss: 0.06798427551984787 ,Train accuracy: 0.96875
# Loss: 4.416736602783203 ,Train accuracy: 0.015625

# %%
# test(model2, criterion, combined_dataloader_wo_aug123)

# %%
pred_class1, pred_class2 = get_predictions(combined_dataloader_wo_aug1234, model2)
Y_comb12 = np.append(Y1, Y2)
Y_comb1234 = np.append(Y_comb12, Y34)
Y_comb1234.shape
plt.scatter(Y_comb1234, pred_class1, label='Super Antiferromagnetic')
plt.scatter(Y_comb1234, pred_class2, label='Paramagnetic')
plt.legend()

# %%
plot_proba(np.array(Y_comb1234), np.array(pred_class1), np.array(pred_class2), 'Super Antiferromagnetic', 'Paramagnetic')

# %%
y_comb1234 = np.array([item[1] for item in combined_dataloader_wo_aug1234.dataset])
calculate_accuracy_np(np.column_stack((pred_class1, pred_class2)), y_comb1234)
# Out:
# 0.4037777777777778
